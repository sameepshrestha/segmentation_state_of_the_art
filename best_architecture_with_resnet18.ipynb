# %% [markdown]
# <a href="https://colab.research.google.com/github/sameepshrestha/segmentation_state_of_the_art/blob/main/best_architecture_with_resnet18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Fri Jul  2 02:59:11 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.27       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   69C    P8    10W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip install tensorflow==2.4.1
# Out:
# Requirement already satisfied: tensorflow==2.4.1 in /usr/local/lib/python3.7/dist-packages (2.4.1)
# Requirement already satisfied: six~=1.15.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (1.15.0)
# Requirement already satisfied: wheel~=0.35 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (0.36.2)
# Requirement already satisfied: grpcio~=1.32.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (1.32.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (3.12.4)
# Requirement already satisfied: astunparse~=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (1.6.3)
# Requirement already satisfied: h5py~=2.10.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (2.10.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (1.12)
# Requirement already satisfied: numpy~=1.19.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (1.19.5)
# Requirement already satisfied: termcolor~=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (1.1.0)
# Requirement already satisfied: tensorflow-estimator<2.5.0,>=2.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (2.4.0)
# Requirement already satisfied: gast==0.3.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (0.3.3)
# Requirement already satisfied: tensorboard~=2.4 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (2.5.0)
# Requirement already satisfied: opt-einsum~=3.3.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (3.3.0)
# Requirement already satisfied: wrapt~=1.12.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (1.12.1)
# Requirement already satisfied: absl-py~=0.10 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (0.12.0)
# Requirement already satisfied: google-pasta~=0.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (0.2.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (1.1.2)
# Requirement already satisfied: typing-extensions~=3.7.4 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (3.7.4.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from protobuf>=3.9.2->tensorflow==2.4.1) (57.0.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow==2.4.1) (1.8.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow==2.4.1) (3.3.4)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow==2.4.1) (1.0.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow==2.4.1) (0.6.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow==2.4.1) (1.31.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow==2.4.1) (2.23.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow==2.4.1) (0.4.4)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard~=2.4->tensorflow==2.4.1) (4.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow==2.4.1) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow==2.4.1) (4.2.2)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow==2.4.1) (4.7.2)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow==2.4.1) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow==2.4.1) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow==2.4.1) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow==2.4.1) (2021.5.30)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow==2.4.1) (1.3.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard~=2.4->tensorflow==2.4.1) (3.4.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow==2.4.1) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow==2.4.1) (3.1.1)

# %%
# !pip install git+https://github.com/qubvel/classification_models.git
# Out:
# Collecting git+https://github.com/qubvel/classification_models.git
#   Cloning https://github.com/qubvel/classification_models.git to /tmp/pip-req-build-fifzlwvc
#   Running command git clone -q https://github.com/qubvel/classification_models.git /tmp/pip-req-build-fifzlwvc
#   Running command git submodule update --init --recursive -q
# Requirement already satisfied (use --upgrade to upgrade): image-classifiers==1.0.0 from git+https://github.com/qubvel/classification_models.git in /usr/local/lib/python3.7/dist-packages
# Requirement already satisfied: keras_applications<=1.0.8,>=1.0.7 in /usr/local/lib/python3.7/dist-packages (from image-classifiers==1.0.0) (1.0.8)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.7/dist-packages (from keras_applications<=1.0.8,>=1.0.7->image-classifiers==1.0.0) (1.19.5)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras_applications<=1.0.8,>=1.0.7->image-classifiers==1.0.0) (2.10.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from h5py->keras_applications<=1.0.8,>=1.0.7->image-classifiers==1.0.0) (1.15.0)
# Building wheels for collected packages: image-classifiers
#   Building wheel for image-classifiers (setup.py) ... done
#   Created wheel for image-classifiers: filename=image_classifiers-1.0.0-cp37-none-any.whl size=20049 sha256=10694a3eac9cf981c8a91365350a6b204225d7231657d5acfd3d9730901f0857
#   Stored in directory: /tmp/pip-ephem-wheel-cache-epwfmvfs/wheels/de/2b/fd/29a6d33edb8c28bc7d94e95ea1d39c9a218ac500a3cfb1b197
# Successfully built image-classifiers

# %%
import matplotlib.pyplot as plt 
import numpy as np 
import cv2 as cv 
from PIL import Image, ImageDraw
import json 
import os 
import glob 
import re 
from tqdm import tqdm
import tensorflow as tf 
from tensorflow import keras 
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense, Conv2D, Reshape, Concatenate,MaxPooling2D, AveragePooling2D,Input, BatchNormalization, Activation, UpSampling2D, Concatenate, LeakyReLU,Reshape
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D,Multiply,SpatialDropout2D,Add
from tensorflow.keras.optimizers import Adam, SGD
#using tensorflow backend 16 so keras backend still 32bytes so no keras to be used
# from keras.layers.merge import concatenate,Concatenate
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications.resnet import ResNet50
import gc
import psutil
from classification_models.tfkeras import Classifiers
ResNet18, preprocess_input = Classifiers.get('resnet18')

# %%
# model.summary()
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
def Augmentation(images,mask):
    def _transform(image,mask):
        transform=A.Compose([
         A.HorizontalFlip(p=0.5),
         A.Rotate([-20,20],p=.25),
    ])
        aug=transform(image=image,mask=mask)
        img=aug['image']
        img=tf.cast(img,tf.float32)
        msk=aug['mask']
        msk=tf.cast(msk,tf.float32)
        return img,msk
    image,mask=tf.numpy_function(_transform,[images,mask],[tf.float32,tf.float32])
    image.set_shape([IMAGE_SIZE, IMAGE_SIZE, 3])
    mask.set_shape([IMAGE_SIZE, IMAGE_SIZE, 38])
    
    return image,mask
AUTO = tf.data.experimental.AUTOTUNE
Image_width = 640 
Image_height = 480 
no_classes =38
def load_data(path, split=0.2):
    images = sorted(glob.glob(os.path.join(path, "image/*")))
    print(len(images))
    masks = sorted(glob.glob(os.path.join(path, "mask2/*")))
    print(len(masks))
    total_size = 7990
    test_size = 1705
    valid_size=1000
    training_x, test_x = train_test_split(images[:7990], test_size=test_size, random_state=42)
    training_y, test_y = train_test_split(masks[:7990], test_size=test_size, random_state=42)
    train_x, valid_x = train_test_split(training_x, test_size=valid_size, random_state=50)
    train_y, valid_y = train_test_split(training_y, test_size=valid_size, random_state=50)
    return (train_x, train_y), (valid_x, valid_y),(test_x, test_y)
(train_x,train_y),(valid_x,valid_y),(test_x, test_y)=load_data('/content/drive/MyDrive/depth')
train_size=len(train_x)
valid_size=len(valid_x)

def read_image(path):
    path = path.decode()
    x = cv.imread(path, cv.IMREAD_COLOR)
    x = cv.resize(x,(640,480),interpolation=cv.INTER_AREA)
    x = x/255.0
    x=tf.cast(x,dtype=tf.float32)
    return x

def read_mask(path):
    path = path.decode()
    x = cv.imread(path, cv.IMREAD_GRAYSCALE)
    x = cv.resize(x,(640,480),interpolation=cv.INTER_NEAREST)
  
    x = to_categorical(x,num_classes=no_classes)
    x = x[:,:,:]
    x=tf.cast(x,dtype=tf.float32)
    return x
# read_mask('/content/drive/MyDrive/depth/mask100/mask1.png')
def parser(x,y):
    def _parse(x,y):
        x=read_image(x)
        y=read_mask(y)
        return x,y
    x,y = tf.numpy_function(_parse, [x,y], [tf.float32,tf.float32])
    x.set_shape([Image_height, Image_width, 3])
    y.set_shape([Image_height, Image_width, no_classes])
    return x,y
    
def tf_dataset(x, y, batch):
    dataset = tf.data.Dataset.from_tensor_slices((x, y))
    dataset = dataset.map(parser)

    dataset = dataset.repeat()
    dataset = dataset.shuffle(128, seed =0)
    dataset = dataset.batch(batch)
    dataset = dataset.prefetch(AUTO)
    return dataset
train_dataset=tf_dataset(train_x,train_y,batch=8)
valid_dataset=tf_dataset(valid_x,valid_y,batch=8)
valid_dataset
# Out:
# 8033
# 8033
# <PrefetchDataset shapes: ((None, 480, 640, 3), (None, 480, 640, 38)), types: (tf.float32, tf.float32)>

# %%
def encoder(inputs):
    skip_layers = []
    model2 = ResNet18(include_top=False,weights='imagenet',input_tensor=inputs)
    x = model2.get_layer('relu1').output
    # names = ['conv1_bn','conv2_block3_add','conv3_block4_add','conv4_block6_add']
    # for name in names:
    #     layer = model2.get_layer(name).output
    #     print(layer.shape)
    #     skip_layers.append(layer)
    return x
def transistion_conv(x,filter=256):
    x = Conv2D(filter,(1,1), padding="same")(x)
    x = BatchNormalization()(x)
    x = UpSampling2D((2,2))(x)
    y_1=x
    x= Activation('relu')(x)
    return x ,y_1
def decoder_conv(x,y_1,filters = 64):
    print(x.shape)
    y = Conv2D(filters,(3,3), padding="same")(x)
    y = BatchNormalization()(y)
    y = Activation('relu')(y)
    y = Conv2D(filters,(3,3), padding="same")(y)
    y = BatchNormalization()(y)
    y = Add()([y_1,y])
    y_1 = y
    y = Activation('relu')(y)
    return y,y_1
def decoder(x,y_1):
    filters  = [256,128,64,64,64]
    for i in range(len(filters)-1):
        x,y_1 = decoder_conv(x,y_1,filters[i])
        x,y_1 = decoder_conv(x,y_1,filters[i])
        x,y_1 = transistion_conv(x,filters[i+1])
    return x
def outputs(input):
    x = Conv2D(64,(3,3), padding="same")(input)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(38,(1,1), padding="same")(x)
    return x 
def main_model(shape):
    inputs = Input(shape)
    encoded = encoder(inputs)
    transistioned,y_1 = transistion_conv(encoded) 
    decoded = decoder(transistioned,y_1)
    output = outputs(decoded)
    model = Model(inputs,output)
    return model 
shape = (480,640,3)
model = main_model(shape)
model.summary()
# Out:
# (None, 30, 40, 256)
# (None, 30, 40, 256)
# (None, 60, 80, 128)
# (None, 60, 80, 128)
# (None, 120, 160, 64)
# (None, 120, 160, 64)
# (None, 240, 320, 64)
# (None, 240, 320, 64)
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 480, 640, 3) 0
# __________________________________________________________________________________________________
# bn_data (BatchNormalization)    (None, 480, 640, 3)  9           input_1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 486, 646, 3)  0           bn_data[0][0]
# __________________________________________________________________________________________________
# conv0 (Conv2D)                  (None, 240, 320, 64) 9408        zero_padding2d[0][0]
# __________________________________________________________________________________________________
# bn0 (BatchNormalization)        (None, 240, 320, 64) 256         conv0[0][0]
# __________________________________________________________________________________________________
# relu0 (Activation)              (None, 240, 320, 64) 0           bn0[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 242, 322, 64) 0           relu0[0][0]
# __________________________________________________________________________________________________
# pooling0 (MaxPooling2D)         (None, 120, 160, 64) 0           zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_bn1 (BatchNormaliz (None, 120, 160, 64) 256         pooling0[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_relu1 (Activation) (None, 120, 160, 64) 0           stage1_unit1_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_2 (ZeroPadding2D (None, 122, 162, 64) 0           stage1_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_conv1 (Conv2D)     (None, 120, 160, 64) 36864       zero_padding2d_2[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_bn2 (BatchNormaliz (None, 120, 160, 64) 256         stage1_unit1_conv1[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_relu2 (Activation) (None, 120, 160, 64) 0           stage1_unit1_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_3 (ZeroPadding2D (None, 122, 162, 64) 0           stage1_unit1_relu2[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_conv2 (Conv2D)     (None, 120, 160, 64) 36864       zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_sc (Conv2D)        (None, 120, 160, 64) 4096        stage1_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 120, 160, 64) 0           stage1_unit1_conv2[0][0]
#                                                                  stage1_unit1_sc[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_bn1 (BatchNormaliz (None, 120, 160, 64) 256         add[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_relu1 (Activation) (None, 120, 160, 64) 0           stage1_unit2_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_4 (ZeroPadding2D (None, 122, 162, 64) 0           stage1_unit2_relu1[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_conv1 (Conv2D)     (None, 120, 160, 64) 36864       zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_bn2 (BatchNormaliz (None, 120, 160, 64) 256         stage1_unit2_conv1[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_relu2 (Activation) (None, 120, 160, 64) 0           stage1_unit2_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_5 (ZeroPadding2D (None, 122, 162, 64) 0           stage1_unit2_relu2[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_conv2 (Conv2D)     (None, 120, 160, 64) 36864       zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 120, 160, 64) 0           stage1_unit2_conv2[0][0]
#                                                                  add[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_bn1 (BatchNormaliz (None, 120, 160, 64) 256         add_1[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_relu1 (Activation) (None, 120, 160, 64) 0           stage2_unit1_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_6 (ZeroPadding2D (None, 122, 162, 64) 0           stage2_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_conv1 (Conv2D)     (None, 60, 80, 128)  73728       zero_padding2d_6[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_bn2 (BatchNormaliz (None, 60, 80, 128)  512         stage2_unit1_conv1[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_relu2 (Activation) (None, 60, 80, 128)  0           stage2_unit1_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_7 (ZeroPadding2D (None, 62, 82, 128)  0           stage2_unit1_relu2[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_conv2 (Conv2D)     (None, 60, 80, 128)  147456      zero_padding2d_7[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_sc (Conv2D)        (None, 60, 80, 128)  8192        stage2_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 60, 80, 128)  0           stage2_unit1_conv2[0][0]
#                                                                  stage2_unit1_sc[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_bn1 (BatchNormaliz (None, 60, 80, 128)  512         add_2[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_relu1 (Activation) (None, 60, 80, 128)  0           stage2_unit2_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_8 (ZeroPadding2D (None, 62, 82, 128)  0           stage2_unit2_relu1[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_conv1 (Conv2D)     (None, 60, 80, 128)  147456      zero_padding2d_8[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_bn2 (BatchNormaliz (None, 60, 80, 128)  512         stage2_unit2_conv1[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_relu2 (Activation) (None, 60, 80, 128)  0           stage2_unit2_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_9 (ZeroPadding2D (None, 62, 82, 128)  0           stage2_unit2_relu2[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_conv2 (Conv2D)     (None, 60, 80, 128)  147456      zero_padding2d_9[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 60, 80, 128)  0           stage2_unit2_conv2[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_bn1 (BatchNormaliz (None, 60, 80, 128)  512         add_3[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_relu1 (Activation) (None, 60, 80, 128)  0           stage3_unit1_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_10 (ZeroPadding2 (None, 62, 82, 128)  0           stage3_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_conv1 (Conv2D)     (None, 30, 40, 256)  294912      zero_padding2d_10[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_bn2 (BatchNormaliz (None, 30, 40, 256)  1024        stage3_unit1_conv1[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_relu2 (Activation) (None, 30, 40, 256)  0           stage3_unit1_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_11 (ZeroPadding2 (None, 32, 42, 256)  0           stage3_unit1_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_conv2 (Conv2D)     (None, 30, 40, 256)  589824      zero_padding2d_11[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_sc (Conv2D)        (None, 30, 40, 256)  32768       stage3_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 30, 40, 256)  0           stage3_unit1_conv2[0][0]
#                                                                  stage3_unit1_sc[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_bn1 (BatchNormaliz (None, 30, 40, 256)  1024        add_4[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_relu1 (Activation) (None, 30, 40, 256)  0           stage3_unit2_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_12 (ZeroPadding2 (None, 32, 42, 256)  0           stage3_unit2_relu1[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_conv1 (Conv2D)     (None, 30, 40, 256)  589824      zero_padding2d_12[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_bn2 (BatchNormaliz (None, 30, 40, 256)  1024        stage3_unit2_conv1[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_relu2 (Activation) (None, 30, 40, 256)  0           stage3_unit2_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_13 (ZeroPadding2 (None, 32, 42, 256)  0           stage3_unit2_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_conv2 (Conv2D)     (None, 30, 40, 256)  589824      zero_padding2d_13[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 30, 40, 256)  0           stage3_unit2_conv2[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_bn1 (BatchNormaliz (None, 30, 40, 256)  1024        add_5[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_relu1 (Activation) (None, 30, 40, 256)  0           stage4_unit1_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_14 (ZeroPadding2 (None, 32, 42, 256)  0           stage4_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_conv1 (Conv2D)     (None, 15, 20, 512)  1179648     zero_padding2d_14[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_bn2 (BatchNormaliz (None, 15, 20, 512)  2048        stage4_unit1_conv1[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_relu2 (Activation) (None, 15, 20, 512)  0           stage4_unit1_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_15 (ZeroPadding2 (None, 17, 22, 512)  0           stage4_unit1_relu2[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_conv2 (Conv2D)     (None, 15, 20, 512)  2359296     zero_padding2d_15[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_sc (Conv2D)        (None, 15, 20, 512)  131072      stage4_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 15, 20, 512)  0           stage4_unit1_conv2[0][0]
#                                                                  stage4_unit1_sc[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_bn1 (BatchNormaliz (None, 15, 20, 512)  2048        add_6[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_relu1 (Activation) (None, 15, 20, 512)  0           stage4_unit2_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_16 (ZeroPadding2 (None, 17, 22, 512)  0           stage4_unit2_relu1[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_conv1 (Conv2D)     (None, 15, 20, 512)  2359296     zero_padding2d_16[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_bn2 (BatchNormaliz (None, 15, 20, 512)  2048        stage4_unit2_conv1[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_relu2 (Activation) (None, 15, 20, 512)  0           stage4_unit2_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_17 (ZeroPadding2 (None, 17, 22, 512)  0           stage4_unit2_relu2[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_conv2 (Conv2D)     (None, 15, 20, 512)  2359296     zero_padding2d_17[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 15, 20, 512)  0           stage4_unit2_conv2[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# bn1 (BatchNormalization)        (None, 15, 20, 512)  2048        add_7[0][0]
# __________________________________________________________________________________________________
# relu1 (Activation)              (None, 15, 20, 512)  0           bn1[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 15, 20, 256)  131328      relu1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 15, 20, 256)  1024        conv2d[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 30, 40, 256)  0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 30, 40, 256)  0           up_sampling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 30, 40, 256)  590080      activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 30, 40, 256)  1024        conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 30, 40, 256)  0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 30, 40, 256)  590080      activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 30, 40, 256)  1024        conv2d_2[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 30, 40, 256)  0           up_sampling2d[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 30, 40, 256)  0           add_8[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 30, 40, 256)  590080      activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 30, 40, 256)  1024        conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 30, 40, 256)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 30, 40, 256)  590080      activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 30, 40, 256)  1024        conv2d_4[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 30, 40, 256)  0           add_8[0][0]
#                                                                  batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 30, 40, 256)  0           add_9[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 30, 40, 128)  32896       activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 30, 40, 128)  512         conv2d_5[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 60, 80, 128)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 60, 80, 128)  0           up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 60, 80, 128)  147584      activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 60, 80, 128)  512         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 60, 80, 128)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 60, 80, 128)  147584      activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 60, 80, 128)  512         conv2d_7[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 60, 80, 128)  0           up_sampling2d_1[0][0]
#                                                                  batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 60, 80, 128)  0           add_10[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 60, 80, 128)  147584      activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 60, 80, 128)  512         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 60, 80, 128)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 60, 80, 128)  147584      activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 60, 80, 128)  512         conv2d_9[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 60, 80, 128)  0           add_10[0][0]
#                                                                  batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 60, 80, 128)  0           add_11[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 60, 80, 64)   8256        activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 60, 80, 64)   256         conv2d_10[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 120, 160, 64) 0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 120, 160, 64) 0           up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 120, 160, 64) 36928       activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 120, 160, 64) 256         conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 120, 160, 64) 0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 120, 160, 64) 36928       activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 120, 160, 64) 256         conv2d_12[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 120, 160, 64) 0           up_sampling2d_2[0][0]
#                                                                  batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 120, 160, 64) 0           add_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 120, 160, 64) 36928       activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 120, 160, 64) 256         conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 120, 160, 64) 0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 120, 160, 64) 36928       activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 120, 160, 64) 256         conv2d_14[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 120, 160, 64) 0           add_12[0][0]
#                                                                  batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 120, 160, 64) 0           add_13[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 120, 160, 64) 4160        activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 120, 160, 64) 256         conv2d_15[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 240, 320, 64) 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 240, 320, 64) 0           up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 240, 320, 64) 36928       activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 240, 320, 64) 256         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 240, 320, 64) 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 240, 320, 64) 36928       activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 240, 320, 64) 256         conv2d_17[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 240, 320, 64) 0           up_sampling2d_3[0][0]
#                                                                  batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 240, 320, 64) 0           add_14[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 240, 320, 64) 36928       activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 240, 320, 64) 256         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 240, 320, 64) 0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 240, 320, 64) 36928       activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 240, 320, 64) 256         conv2d_19[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 240, 320, 64) 0           add_14[0][0]
#                                                                  batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 240, 320, 64) 0           add_15[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 240, 320, 64) 4160        activation_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 240, 320, 64) 256         conv2d_20[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 480, 640, 64) 0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 480, 640, 64) 0           up_sampling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 480, 640, 64) 36928       activation_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 480, 640, 64) 256         conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 480, 640, 64) 0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 480, 640, 38) 2470        activation_21[0][0]
# ==================================================================================================
# Total params: 14,663,919
# Trainable params: 14,650,601
# Non-trainable params: 13,318
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(model, show_shapes=True, dpi=64)

# %%
#loss function 
import gc 
from tensorflow.keras.losses import binary_crossentropy
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import CSVLogger ,LearningRateScheduler,Callback
class CustomLearningRateScheduler(tf.keras.callbacks.Callback):
    def __init__(self, schedule):
        super(CustomLearningRateScheduler, self).__init__()
        self.schedule = schedule
    def on_train_batch_end(self, batch, logs=None):
        if not hasattr(self.model.optimizer, "lr"):
            raise ValueError('Optimizer must have a "lr" attribute.')
        lr = float(tf.keras.backend.get_value(self.model.optimizer.learning_rate))
        scheduled_lr = self.schedule(batch, lr)
        tf.keras.backend.set_value(self.model.optimizer.lr, scheduled_lr)
        print("\nbatch %05d: Learning rate is %8f." % (batch, scheduled_lr))
def lr_scheduler(batch,lr):
      t_steps = train_size//8
      
    #   if (i+13+12+6)> 30:
    #     lr =0.00000025347102
    #     return lr
      batch = (i+22)*t_steps+batch
      lr = .001 *((1- (batch/(t_steps*50)))**.9)
      return lr
def lr_schedule(i):
      t_steps = train_size//8
      batch = (i+22)*t_steps+1
      lr = .001 *((1- (batch/(t_steps*50)))**.9)
      return lr
def binary_loss(y_true, y_pred):
    loss = binary_crossentropy(y_true, y_pred,from_logits=True)
    loss_value = tf.math.reduce_mean(loss,axis=[0])
    return loss_value

def cross_entropy_loss(y_true,y_pred):
    loss = tf.nn.softmax_cross_entropy_with_logits(
    y_true, y_pred, axis=-1, name=None)
    return loss

def custom_metrics(y_true,y_pred,smooth=1):
    y_pred = tf.math.argmax(y_pred, axis=-1)
    # y_pred = tf.expand_dims(y_pred,axis=-1)
    y_pred = tf.one_hot(y_pred,38)
    y_true = y_true[:,:,:,1:38]
    y_pred= y_pred[:,:,:,1:38]
    intersection  = tf.math.reduce_sum((y_true*y_pred),axis = [1,2,3])
    union = (tf.math.reduce_sum(y_true,axis=[1,2,3])+tf.math.reduce_sum(y_pred,axis = [1,2,3])) - intersection
    return tf.math.reduce_mean((intersection+smooth)/(union+smooth),axis=0)
metrics = tf.keras.metrics.MeanIoU(
    37
)
def custom_metrics2(y_true,y_pred):
    y_pred = tf.math.argmax(y_pred, axis=-1)
    y_pred = tf.one_hot(y_pred,38)
    y_pred = tf.reshape(y_pred,[-1,38])
    y_true = tf.reshape(y_true,[-1,38])
    return metrics(y_true,y_pred)

smooth = 1
def dice_coef(y_true, y_pred):
    y_true = tf.keras.layers.Flatten()(y_true)
    y_pred = tf.keras.layers.Flatten()(y_pred)
    intersection = tf.reduce_sum(y_true * y_pred)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)
model=tf.keras.models.load_model( '/content/drive/MyDrive/new_architecture/best-architecture-june38/Resnet50withoutchanges/Resnet18_withoutchanges/all/',custom_objects={
        'cross_entropy_loss': cross_entropy_loss,'custom_metrics':custom_metrics })

# %%
lr =.001
# model.compile(loss = cross_entropy_loss,optimizer = Adam(learning_rate =lr,beta_1= 0.9),metrics = [custom_metrics])
epoch=24
t_steps = train_size//8
v_steps=valid_size//8
val_custom_metrics = 0.4086
val_metrics =[]
for i in range(epoch):
  print('epoch =',i+1)
  lr = lr_schedule(i)
  model.compile(loss = cross_entropy_loss,optimizer=SGD(learning_rate =lr,momentum= 0.9),metrics=[custom_metrics])
  model.fit(train_dataset,epochs= 1,steps_per_epoch=t_steps,callbacks=[CustomLearningRateScheduler(lr_scheduler)])
#   model.fit(train_dataset,epochs= 1,steps_per_epoch=t_steps,callbacks=[CustomLearningRateScheduler(lr_scheduler)])
  loss = model.evaluate(valid_dataset,steps=v_steps)
  model.save('/content/drive/MyDrive/new_architecture/best-architecture-june38/Resnet50withoutchanges/Resnet18_withoutchanges/all/',save_format='tf')
  if loss[1]>=val_custom_metrics:
    val_custom_metrics = loss[1]
    model.save('/content/drive/MyDrive/new_architecture/best-architecture-june38/Resnet50withoutchanges/Resnet18_withoutchanges/best/',save_format='tf')
  tf.keras.backend.clear_session()
  gc.collect()
# Out:
# epoch = 1
#   1/660 [..............................] - ETA: 9:07:05 - loss: 1.1349 - custom_metrics: 0.5040
# batch 00000: Learning rate is 0.000593.
#   2/660 [..............................] - ETA: 10:07 - loss: 1.1112 - custom_metrics: 0.5175
# batch 00001: Learning rate is 0.000593.
#   3/660 [..............................] - ETA: 12:07 - loss: 1.0877 - custom_metrics: 0.5280
# batch 00002: Learning rate is 0.000593.
#   4/660 [..............................] - ETA: 12:47 - loss: 1.0849 - custom_metrics: 0.5328
# batch 00003: Learning rate is 0.000593.
#   5/660 [..............................] - ETA: 13:16 - loss: 1.0848 - custom_metrics: 0.5349
# batch 00004: Learning rate is 0.000593.
#   6/660 [..............................] - ETA: 13:24 - loss: 1.0931 - custom_metrics: 0.5314
# batch 00005: Learning rate is 0.000593.
#   7/660 [..............................] - ETA: 13:51 - loss: 1.1031 - custom_metrics: 0.5259
# batch 00006: Learning rate is 0.000593.
#   8/660 [..............................] - ETA: 13:54 - loss: 1.1056 - custom_metrics: 0.5220
# batch 00007: Learning rate is 0.000593.
#   9/660 [..............................] - ETA: 13:52 - loss: 1.1057 - custom_metrics: 0.5194
# batch 00008: Learning rate is 0.000593.
#  10/660 [..............................] - ETA: 13:50 - loss: 1.1049 - custom_metrics: 0.5177
# batch 00009: Learning rate is 0.000593.
#  11/660 [..............................] - ETA: 13:48 - loss: 1.1031 - custom_metrics: 0.5164
# batch 00010: Learning rate is 0.000593.
#  12/660 [..............................] - ETA: 13:46 - loss: 1.1018 - custom_metrics: 0.5155
# batch 00011: Learning rate is 0.000593.
#  13/660 [..............................] - ETA: 13:45 - loss: 1.1008 - custom_metrics: 0.5147
# batch 00012: Learning rate is 0.000593.
#  14/660 [..............................] - ETA: 13:44 - loss: 1.0997 - custom_metrics: 0.5141
# batch 00013: Learning rate is 0.000593.
#  15/660 [..............................] - ETA: 13:42 - loss: 1.0979 - custom_metrics: 0.5137
# batch 00014: Learning rate is 0.000593.
#  16/660 [..............................] - ETA: 13:40 - loss: 1.0961 - custom_metrics: 0.5133
# batch 00015: Learning rate is 0.000593.
#  17/660 [..............................] - ETA: 13:39 - loss: 1.0937 - custom_metrics: 0.5130
# batch 00016: Learning rate is 0.000593.
#  18/660 [..............................] - ETA: 13:39 - loss: 1.0923 - custom_metrics: 0.5126
# batch 00017: Learning rate is 0.000593.
#  19/660 [..............................] - ETA: 13:38 - loss: 1.0904 - custom_metrics: 0.5127
# batch 00018: Learning rate is 0.000593.
#  20/660 [..............................] - ETA: 13:36 - loss: 1.0887 - custom_metrics: 0.5126
# batch 00019: Learning rate is 0.000593.
#  21/660 [..............................] - ETA: 13:36 - loss: 1.0872 - custom_metrics: 0.5124
# batch 00020: Learning rate is 0.000593.
#  22/660 [>.............................] - ETA: 13:35 - loss: 1.0861 - custom_metrics: 0.5120
# batch 00021: Learning rate is 0.000593.
#  23/660 [>.............................] - ETA: 13:34 - loss: 1.0855 - custom_metrics: 0.5114
# batch 00022: Learning rate is 0.000593.
#  24/660 [>.............................] - ETA: 13:31 - loss: 1.0858 - custom_metrics: 0.5108
# batch 00023: Learning rate is 0.000593.
#  25/660 [>.............................] - ETA: 13:30 - loss: 1.0858 - custom_metrics: 0.5102
# batch 00024: Learning rate is 0.000593.
#  26/660 [>.............................] - ETA: 13:28 - loss: 1.0862 - custom_metrics: 0.5097
# batch 00025: Learning rate is 0.000593.
#  27/660 [>.............................] - ETA: 13:27 - loss: 1.0865 - custom_metrics: 0.5092
# batch 00026: Learning rate is 0.000593.
#  28/660 [>.............................] - ETA: 13:26 - loss: 1.0870 - custom_metrics: 0.5087
# batch 00027: Learning rate is 0.000593.
#  29/660 [>.............................] - ETA: 13:26 - loss: 1.0873 - custom_metrics: 0.5083
# batch 00028: Learning rate is 0.000593.
#  30/660 [>.............................] - ETA: 13:24 - loss: 1.0874 - custom_metrics: 0.5080
# batch 00029: Learning rate is 0.000593.
#  31/660 [>.............................] - ETA: 13:23 - loss: 1.0876 - custom_metrics: 0.5077
# batch 00030: Learning rate is 0.000593.
#  32/660 [>.............................] - ETA: 13:20 - loss: 1.0879 - custom_metrics: 0.5074
# batch 00031: Learning rate is 0.000593.
#  33/660 [>.............................] - ETA: 13:18 - loss: 1.0882 - custom_metrics: 0.5071
# batch 00032: Learning rate is 0.000593.
#  34/660 [>.............................] - ETA: 13:17 - loss: 1.0888 - custom_metrics: 0.5067
# batch 00033: Learning rate is 0.000592.
#  35/660 [>.............................] - ETA: 13:16 - loss: 1.0896 - custom_metrics: 0.5062
# batch 00034: Learning rate is 0.000592.
#  36/660 [>.............................] - ETA: 13:14 - loss: 1.0904 - custom_metrics: 0.5058
# batch 00035: Learning rate is 0.000592.
#  37/660 [>.............................] - ETA: 13:12 - loss: 1.0910 - custom_metrics: 0.5054
# batch 00036: Learning rate is 0.000592.
#  38/660 [>.............................] - ETA: 13:10 - loss: 1.0918 - custom_metrics: 0.5050
# batch 00037: Learning rate is 0.000592.
#  39/660 [>.............................] - ETA: 13:09 - loss: 1.0928 - custom_metrics: 0.5046
# batch 00038: Learning rate is 0.000592.
#  40/660 [>.............................] - ETA: 13:07 - loss: 1.0937 - custom_metrics: 0.5041
# batch 00039: Learning rate is 0.000592.
#  41/660 [>.............................] - ETA: 13:06 - loss: 1.0946 - custom_metrics: 0.5037
# batch 00040: Learning rate is 0.000592.
#  42/660 [>.............................] - ETA: 13:04 - loss: 1.0955 - custom_metrics: 0.5033
# batch 00041: Learning rate is 0.000592.
#  43/660 [>.............................] - ETA: 13:03 - loss: 1.0964 - custom_metrics: 0.5029
# batch 00042: Learning rate is 0.000592.
#  44/660 [=>............................] - ETA: 13:01 - loss: 1.0972 - custom_metrics: 0.5025
# batch 00043: Learning rate is 0.000592.
#  45/660 [=>............................] - ETA: 12:59 - loss: 1.0980 - custom_metrics: 0.5022
# batch 00044: Learning rate is 0.000592.
#  46/660 [=>............................] - ETA: 12:58 - loss: 1.0987 - custom_metrics: 0.5019
# batch 00045: Learning rate is 0.000592.
#  47/660 [=>............................] - ETA: 12:56 - loss: 1.0995 - custom_metrics: 0.5015
# batch 00046: Learning rate is 0.000592.
#  48/660 [=>............................] - ETA: 12:55 - loss: 1.1001 - custom_metrics: 0.5012
# batch 00047: Learning rate is 0.000592.
#  49/660 [=>............................] - ETA: 12:53 - loss: 1.1008 - custom_metrics: 0.5010
# batch 00048: Learning rate is 0.000592.
#  50/660 [=>............................] - ETA: 12:52 - loss: 1.1013 - custom_metrics: 0.5008
# batch 00049: Learning rate is 0.000592.
#  51/660 [=>............................] - ETA: 12:50 - loss: 1.1018 - custom_metrics: 0.5006
# batch 00050: Learning rate is 0.000592.
#  52/660 [=>............................] - ETA: 12:49 - loss: 1.1023 - custom_metrics: 0.5004
# batch 00051: Learning rate is 0.000592.
#  53/660 [=>............................] - ETA: 12:47 - loss: 1.1027 - custom_metrics: 0.5002
# batch 00052: Learning rate is 0.000592.
#  54/660 [=>............................] - ETA: 12:45 - loss: 1.1031 - custom_metrics: 0.5000
# batch 00053: Learning rate is 0.000592.
#  55/660 [=>............................] - ETA: 12:44 - loss: 1.1035 - custom_metrics: 0.4997
# batch 00054: Learning rate is 0.000592.
#  56/660 [=>............................] - ETA: 12:42 - loss: 1.1041 - custom_metrics: 0.4995
# batch 00055: Learning rate is 0.000592.
#  57/660 [=>............................] - ETA: 12:41 - loss: 1.1047 - custom_metrics: 0.4992
# batch 00056: Learning rate is 0.000592.
#  58/660 [=>............................] - ETA: 12:39 - loss: 1.1053 - custom_metrics: 0.4990
# batch 00057: Learning rate is 0.000592.
#  59/660 [=>............................] - ETA: 12:38 - loss: 1.1058 - custom_metrics: 0.4987
# batch 00058: Learning rate is 0.000592.
#  60/660 [=>............................] - ETA: 12:36 - loss: 1.1063 - custom_metrics: 0.4985
# batch 00059: Learning rate is 0.000592.
#  61/660 [=>............................] - ETA: 12:35 - loss: 1.1068 - custom_metrics: 0.4983
# batch 00060: Learning rate is 0.000592.
#  62/660 [=>............................] - ETA: 12:33 - loss: 1.1072 - custom_metrics: 0.4981
# batch 00061: Learning rate is 0.000592.
#  63/660 [=>............................] - ETA: 12:32 - loss: 1.1077 - custom_metrics: 0.4978
# batch 00062: Learning rate is 0.000592.
#  64/660 [=>............................] - ETA: 12:31 - loss: 1.1082 - custom_metrics: 0.4976
# batch 00063: Learning rate is 0.000592.
#  65/660 [=>............................] - ETA: 12:29 - loss: 1.1086 - custom_metrics: 0.4974
# batch 00064: Learning rate is 0.000592.
#  66/660 [==>...........................] - ETA: 12:28 - loss: 1.1091 - custom_metrics: 0.4972
# batch 00065: Learning rate is 0.000592.
#  67/660 [==>...........................] - ETA: 12:26 - loss: 1.1095 - custom_metrics: 0.4970
# batch 00066: Learning rate is 0.000592.
#  68/660 [==>...........................] - ETA: 12:24 - loss: 1.1100 - custom_metrics: 0.4968
# batch 00067: Learning rate is 0.000591.
#  69/660 [==>...........................] - ETA: 12:23 - loss: 1.1105 - custom_metrics: 0.4966
# batch 00068: Learning rate is 0.000591.
#  70/660 [==>...........................] - ETA: 12:21 - loss: 1.1111 - custom_metrics: 0.4963
# batch 00069: Learning rate is 0.000591.
#  71/660 [==>...........................] - ETA: 12:20 - loss: 1.1116 - custom_metrics: 0.4961
# batch 00070: Learning rate is 0.000591.
#  72/660 [==>...........................] - ETA: 12:18 - loss: 1.1121 - custom_metrics: 0.4959
# batch 00071: Learning rate is 0.000591.
#  73/660 [==>...........................] - ETA: 12:17 - loss: 1.1125 - custom_metrics: 0.4958
# batch 00072: Learning rate is 0.000591.
#  74/660 [==>...........................] - ETA: 12:16 - loss: 1.1129 - custom_metrics: 0.4956
# batch 00073: Learning rate is 0.000591.
#  75/660 [==>...........................] - ETA: 12:14 - loss: 1.1134 - custom_metrics: 0.4954
# batch 00074: Learning rate is 0.000591.
#  76/660 [==>...........................] - ETA: 12:13 - loss: 1.1137 - custom_metrics: 0.4953
# batch 00075: Learning rate is 0.000591.
#  77/660 [==>...........................] - ETA: 12:12 - loss: 1.1141 - custom_metrics: 0.4951
# batch 00076: Learning rate is 0.000591.
#  78/660 [==>...........................] - ETA: 12:10 - loss: 1.1145 - custom_metrics: 0.4949
# batch 00077: Learning rate is 0.000591.
#  79/660 [==>...........................] - ETA: 12:09 - loss: 1.1149 - custom_metrics: 0.4948
# batch 00078: Learning rate is 0.000591.
#  80/660 [==>...........................] - ETA: 12:08 - loss: 1.1153 - custom_metrics: 0.4946
# batch 00079: Learning rate is 0.000591.
#  81/660 [==>...........................] - ETA: 12:06 - loss: 1.1157 - custom_metrics: 0.4944
# batch 00080: Learning rate is 0.000591.
#  82/660 [==>...........................] - ETA: 12:05 - loss: 1.1161 - custom_metrics: 0.4942
# batch 00081: Learning rate is 0.000591.
#  83/660 [==>...........................] - ETA: 12:04 - loss: 1.1164 - custom_metrics: 0.4941
# batch 00082: Learning rate is 0.000591.
#  84/660 [==>...........................] - ETA: 12:02 - loss: 1.1167 - custom_metrics: 0.4939
# batch 00083: Learning rate is 0.000591.
#  85/660 [==>...........................] - ETA: 12:01 - loss: 1.1170 - custom_metrics: 0.4938
# batch 00084: Learning rate is 0.000591.
#  86/660 [==>...........................] - ETA: 12:00 - loss: 1.1173 - custom_metrics: 0.4937
# batch 00085: Learning rate is 0.000591.
#  87/660 [==>...........................] - ETA: 11:58 - loss: 1.1176 - custom_metrics: 0.4935
# batch 00086: Learning rate is 0.000591.
#  88/660 [===>..........................] - ETA: 11:57 - loss: 1.1179 - custom_metrics: 0.4934
# batch 00087: Learning rate is 0.000591.
#  89/660 [===>..........................] - ETA: 11:56 - loss: 1.1181 - custom_metrics: 0.4933
# batch 00088: Learning rate is 0.000591.
#  90/660 [===>..........................] - ETA: 11:54 - loss: 1.1184 - custom_metrics: 0.4932
# batch 00089: Learning rate is 0.000591.
#  91/660 [===>..........................] - ETA: 11:53 - loss: 1.1186 - custom_metrics: 0.4931
# batch 00090: Learning rate is 0.000591.
#  92/660 [===>..........................] - ETA: 11:52 - loss: 1.1189 - custom_metrics: 0.4929
# batch 00091: Learning rate is 0.000591.
#  93/660 [===>..........................] - ETA: 11:50 - loss: 1.1192 - custom_metrics: 0.4928
# batch 00092: Learning rate is 0.000591.
#  94/660 [===>..........................] - ETA: 11:49 - loss: 1.1195 - custom_metrics: 0.4927
# batch 00093: Learning rate is 0.000591.
#  95/660 [===>..........................] - ETA: 11:48 - loss: 1.1198 - custom_metrics: 0.4925
# batch 00094: Learning rate is 0.000591.
#  96/660 [===>..........................] - ETA: 11:46 - loss: 1.1200 - custom_metrics: 0.4924
# batch 00095: Learning rate is 0.000591.
#  97/660 [===>..........................] - ETA: 11:45 - loss: 1.1202 - custom_metrics: 0.4923
# batch 00096: Learning rate is 0.000591.
#  98/660 [===>..........................] - ETA: 11:44 - loss: 1.1205 - custom_metrics: 0.4922
# batch 00097: Learning rate is 0.000591.
#  99/660 [===>..........................] - ETA: 11:43 - loss: 1.1207 - custom_metrics: 0.4921
# batch 00098: Learning rate is 0.000591.
# 100/660 [===>..........................] - ETA: 11:41 - loss: 1.1210 - custom_metrics: 0.4919
# batch 00099: Learning rate is 0.000591.
# 101/660 [===>..........................] - ETA: 11:40 - loss: 1.1212 - custom_metrics: 0.4918
# batch 00100: Learning rate is 0.000591.
# 102/660 [===>..........................] - ETA: 11:39 - loss: 1.1213 - custom_metrics: 0.4917
# batch 00101: Learning rate is 0.000591.
# 103/660 [===>..........................] - ETA: 11:37 - loss: 1.1215 - custom_metrics: 0.4916
# batch 00102: Learning rate is 0.000590.
# 104/660 [===>..........................] - ETA: 11:36 - loss: 1.1217 - custom_metrics: 0.4915
# batch 00103: Learning rate is 0.000590.
# 105/660 [===>..........................] - ETA: 11:35 - loss: 1.1218 - custom_metrics: 0.4914
# batch 00104: Learning rate is 0.000590.
# 106/660 [===>..........................] - ETA: 11:33 - loss: 1.1220 - custom_metrics: 0.4913
# batch 00105: Learning rate is 0.000590.
# 107/660 [===>..........................] - ETA: 11:32 - loss: 1.1221 - custom_metrics: 0.4912
# batch 00106: Learning rate is 0.000590.
# 108/660 [===>..........................] - ETA: 11:31 - loss: 1.1222 - custom_metrics: 0.4911
# batch 00107: Learning rate is 0.000590.
# 109/660 [===>..........................] - ETA: 11:30 - loss: 1.1223 - custom_metrics: 0.4910
# batch 00108: Learning rate is 0.000590.
# 110/660 [====>.........................] - ETA: 11:28 - loss: 1.1223 - custom_metrics: 0.4910
# batch 00109: Learning rate is 0.000590.
# 111/660 [====>.........................] - ETA: 11:27 - loss: 1.1224 - custom_metrics: 0.4909
# batch 00110: Learning rate is 0.000590.
# 112/660 [====>.........................] - ETA: 11:26 - loss: 1.1225 - custom_metrics: 0.4908
# batch 00111: Learning rate is 0.000590.
# 113/660 [====>.........................] - ETA: 11:24 - loss: 1.1226 - custom_metrics: 0.4907
# batch 00112: Learning rate is 0.000590.
# 114/660 [====>.........................] - ETA: 11:23 - loss: 1.1226 - custom_metrics: 0.4907
# batch 00113: Learning rate is 0.000590.
# 115/660 [====>.........................] - ETA: 11:22 - loss: 1.1226 - custom_metrics: 0.4906
# batch 00114: Learning rate is 0.000590.
# 116/660 [====>.........................] - ETA: 11:20 - loss: 1.1227 - custom_metrics: 0.4905
# batch 00115: Learning rate is 0.000590.
# 117/660 [====>.........................] - ETA: 11:19 - loss: 1.1227 - custom_metrics: 0.4905
# batch 00116: Learning rate is 0.000590.
# 118/660 [====>.........................] - ETA: 11:18 - loss: 1.1227 - custom_metrics: 0.4904
# batch 00117: Learning rate is 0.000590.
# 119/660 [====>.........................] - ETA: 11:17 - loss: 1.1228 - custom_metrics: 0.4903
# batch 00118: Learning rate is 0.000590.
# 120/660 [====>.........................] - ETA: 11:15 - loss: 1.1228 - custom_metrics: 0.4903
# batch 00119: Learning rate is 0.000590.
# 121/660 [====>.........................] - ETA: 11:14 - loss: 1.1228 - custom_metrics: 0.4902
# batch 00120: Learning rate is 0.000590.
# 122/660 [====>.........................] - ETA: 11:13 - loss: 1.1228 - custom_metrics: 0.4901
# batch 00121: Learning rate is 0.000590.
# 123/660 [====>.........................] - ETA: 11:12 - loss: 1.1228 - custom_metrics: 0.4901
# batch 00122: Learning rate is 0.000590.
# 124/660 [====>.........................] - ETA: 11:10 - loss: 1.1228 - custom_metrics: 0.4900
# batch 00123: Learning rate is 0.000590.
# 125/660 [====>.........................] - ETA: 11:09 - loss: 1.1229 - custom_metrics: 0.4899
# batch 00124: Learning rate is 0.000590.
# 126/660 [====>.........................] - ETA: 11:08 - loss: 1.1229 - custom_metrics: 0.4898
# batch 00125: Learning rate is 0.000590.
# 127/660 [====>.........................] - ETA: 11:06 - loss: 1.1229 - custom_metrics: 0.4897
# batch 00126: Learning rate is 0.000590.
# 128/660 [====>.........................] - ETA: 11:05 - loss: 1.1229 - custom_metrics: 0.4897
# batch 00127: Learning rate is 0.000590.
# 129/660 [====>.........................] - ETA: 11:04 - loss: 1.1229 - custom_metrics: 0.4896
# batch 00128: Learning rate is 0.000590.
# 130/660 [====>.........................] - ETA: 11:02 - loss: 1.1229 - custom_metrics: 0.4895
# batch 00129: Learning rate is 0.000590.
# 131/660 [====>.........................] - ETA: 11:01 - loss: 1.1229 - custom_metrics: 0.4895
# batch 00130: Learning rate is 0.000590.
# 132/660 [=====>........................] - ETA: 11:00 - loss: 1.1228 - custom_metrics: 0.4894
# batch 00131: Learning rate is 0.000590.
# 133/660 [=====>........................] - ETA: 10:59 - loss: 1.1228 - custom_metrics: 0.4893
# batch 00132: Learning rate is 0.000590.
# 134/660 [=====>........................] - ETA: 10:57 - loss: 1.1228 - custom_metrics: 0.4893
# batch 00133: Learning rate is 0.000590.
# 135/660 [=====>........................] - ETA: 10:56 - loss: 1.1228 - custom_metrics: 0.4892
# batch 00134: Learning rate is 0.000590.
# 136/660 [=====>........................] - ETA: 10:55 - loss: 1.1227 - custom_metrics: 0.4892
# batch 00135: Learning rate is 0.000590.
# 137/660 [=====>........................] - ETA: 10:53 - loss: 1.1227 - custom_metrics: 0.4891
# batch 00136: Learning rate is 0.000589.
# 138/660 [=====>........................] - ETA: 10:52 - loss: 1.1227 - custom_metrics: 0.4891
# batch 00137: Learning rate is 0.000589.
# 139/660 [=====>........................] - ETA: 10:51 - loss: 1.1226 - custom_metrics: 0.4890
# batch 00138: Learning rate is 0.000589.
# 140/660 [=====>........................] - ETA: 10:49 - loss: 1.1226 - custom_metrics: 0.4890
# batch 00139: Learning rate is 0.000589.
# 141/660 [=====>........................] - ETA: 10:48 - loss: 1.1226 - custom_metrics: 0.4889
# batch 00140: Learning rate is 0.000589.
# 142/660 [=====>........................] - ETA: 10:47 - loss: 1.1225 - custom_metrics: 0.4889
# batch 00141: Learning rate is 0.000589.
# 143/660 [=====>........................] - ETA: 10:46 - loss: 1.1225 - custom_metrics: 0.4888
# batch 00142: Learning rate is 0.000589.
# 144/660 [=====>........................] - ETA: 10:44 - loss: 1.1225 - custom_metrics: 0.4888
# batch 00143: Learning rate is 0.000589.
# 145/660 [=====>........................] - ETA: 10:43 - loss: 1.1225 - custom_metrics: 0.4887
# batch 00144: Learning rate is 0.000589.
# 146/660 [=====>........................] - ETA: 10:42 - loss: 1.1224 - custom_metrics: 0.4887
# batch 00145: Learning rate is 0.000589.
# 147/660 [=====>........................] - ETA: 10:40 - loss: 1.1224 - custom_metrics: 0.4886
# batch 00146: Learning rate is 0.000589.
# 148/660 [=====>........................] - ETA: 10:39 - loss: 1.1224 - custom_metrics: 0.4886
# batch 00147: Learning rate is 0.000589.
# 149/660 [=====>........................] - ETA: 10:38 - loss: 1.1224 - custom_metrics: 0.4885
# batch 00148: Learning rate is 0.000589.
# 150/660 [=====>........................] - ETA: 10:37 - loss: 1.1224 - custom_metrics: 0.4885
# batch 00149: Learning rate is 0.000589.
# 151/660 [=====>........................] - ETA: 10:35 - loss: 1.1224 - custom_metrics: 0.4884
# batch 00150: Learning rate is 0.000589.
# 152/660 [=====>........................] - ETA: 10:34 - loss: 1.1224 - custom_metrics: 0.4884
# batch 00151: Learning rate is 0.000589.
# 153/660 [=====>........................] - ETA: 10:33 - loss: 1.1224 - custom_metrics: 0.4883
# batch 00152: Learning rate is 0.000589.
# 154/660 [======>.......................] - ETA: 10:31 - loss: 1.1225 - custom_metrics: 0.4883
# batch 00153: Learning rate is 0.000589.
# 155/660 [======>.......................] - ETA: 10:30 - loss: 1.1225 - custom_metrics: 0.4883
# batch 00154: Learning rate is 0.000589.
# 156/660 [======>.......................] - ETA: 10:29 - loss: 1.1225 - custom_metrics: 0.4882
# batch 00155: Learning rate is 0.000589.
# 157/660 [======>.......................] - ETA: 10:27 - loss: 1.1225 - custom_metrics: 0.4882
# batch 00156: Learning rate is 0.000589.
# 158/660 [======>.......................] - ETA: 10:26 - loss: 1.1225 - custom_metrics: 0.4881
# batch 00157: Learning rate is 0.000589.
# 159/660 [======>.......................] - ETA: 10:25 - loss: 1.1225 - custom_metrics: 0.4881
# batch 00158: Learning rate is 0.000589.
# 160/660 [======>.......................] - ETA: 10:24 - loss: 1.1225 - custom_metrics: 0.4881
# batch 00159: Learning rate is 0.000589.
# 161/660 [======>.......................] - ETA: 10:22 - loss: 1.1225 - custom_metrics: 0.4880
# batch 00160: Learning rate is 0.000589.
# 162/660 [======>.......................] - ETA: 10:21 - loss: 1.1225 - custom_metrics: 0.4880
# batch 00161: Learning rate is 0.000589.
# 163/660 [======>.......................] - ETA: 10:20 - loss: 1.1225 - custom_metrics: 0.4880
# batch 00162: Learning rate is 0.000589.
# 164/660 [======>.......................] - ETA: 10:19 - loss: 1.1225 - custom_metrics: 0.4879
# batch 00163: Learning rate is 0.000589.
# 165/660 [======>.......................] - ETA: 10:17 - loss: 1.1225 - custom_metrics: 0.4879
# batch 00164: Learning rate is 0.000589.
# 166/660 [======>.......................] - ETA: 10:16 - loss: 1.1225 - custom_metrics: 0.4879
# batch 00165: Learning rate is 0.000589.
# 167/660 [======>.......................] - ETA: 10:15 - loss: 1.1225 - custom_metrics: 0.4878
# batch 00166: Learning rate is 0.000589.
# 168/660 [======>.......................] - ETA: 10:13 - loss: 1.1225 - custom_metrics: 0.4878
# batch 00167: Learning rate is 0.000589.
# 169/660 [======>.......................] - ETA: 10:12 - loss: 1.1225 - custom_metrics: 0.4878
# batch 00168: Learning rate is 0.000589.
# 170/660 [======>.......................] - ETA: 10:11 - loss: 1.1224 - custom_metrics: 0.4877
# batch 00169: Learning rate is 0.000589.
# 171/660 [======>.......................] - ETA: 10:10 - loss: 1.1224 - custom_metrics: 0.4877
# batch 00170: Learning rate is 0.000589.
# 172/660 [======>.......................] - ETA: 10:08 - loss: 1.1224 - custom_metrics: 0.4877
# batch 00171: Learning rate is 0.000588.
# 173/660 [======>.......................] - ETA: 10:07 - loss: 1.1224 - custom_metrics: 0.4876
# batch 00172: Learning rate is 0.000588.
# 174/660 [======>.......................] - ETA: 10:06 - loss: 1.1224 - custom_metrics: 0.4876
# batch 00173: Learning rate is 0.000588.
# 175/660 [======>.......................] - ETA: 10:05 - loss: 1.1224 - custom_metrics: 0.4876
# batch 00174: Learning rate is 0.000588.
# 176/660 [=======>......................] - ETA: 10:03 - loss: 1.1224 - custom_metrics: 0.4875
# batch 00175: Learning rate is 0.000588.
# 177/660 [=======>......................] - ETA: 10:02 - loss: 1.1224 - custom_metrics: 0.4875
# batch 00176: Learning rate is 0.000588.
# 178/660 [=======>......................] - ETA: 10:01 - loss: 1.1224 - custom_metrics: 0.4875
# batch 00177: Learning rate is 0.000588.
# 179/660 [=======>......................] - ETA: 10:00 - loss: 1.1224 - custom_metrics: 0.4875
# batch 00178: Learning rate is 0.000588.
# 180/660 [=======>......................] - ETA: 9:58 - loss: 1.1224 - custom_metrics: 0.4874
# batch 00179: Learning rate is 0.000588.
# 181/660 [=======>......................] - ETA: 9:57 - loss: 1.1224 - custom_metrics: 0.4874
# batch 00180: Learning rate is 0.000588.
# 182/660 [=======>......................] - ETA: 9:56 - loss: 1.1224 - custom_metrics: 0.4874
# batch 00181: Learning rate is 0.000588.
# 183/660 [=======>......................] - ETA: 9:55 - loss: 1.1224 - custom_metrics: 0.4874
# batch 00182: Learning rate is 0.000588.
# 184/660 [=======>......................] - ETA: 9:53 - loss: 1.1224 - custom_metrics: 0.4873
# batch 00183: Learning rate is 0.000588.
# 185/660 [=======>......................] - ETA: 9:52 - loss: 1.1224 - custom_metrics: 0.4873
# batch 00184: Learning rate is 0.000588.
# 186/660 [=======>......................] - ETA: 9:51 - loss: 1.1224 - custom_metrics: 0.4873
# batch 00185: Learning rate is 0.000588.
# 187/660 [=======>......................] - ETA: 9:49 - loss: 1.1224 - custom_metrics: 0.4872
# batch 00186: Learning rate is 0.000588.
# 188/660 [=======>......................] - ETA: 9:48 - loss: 1.1224 - custom_metrics: 0.4872
# batch 00187: Learning rate is 0.000588.
# 189/660 [=======>......................] - ETA: 9:47 - loss: 1.1225 - custom_metrics: 0.4872
# batch 00188: Learning rate is 0.000588.
# 190/660 [=======>......................] - ETA: 9:46 - loss: 1.1225 - custom_metrics: 0.4871
# batch 00189: Learning rate is 0.000588.
# 191/660 [=======>......................] - ETA: 9:44 - loss: 1.1225 - custom_metrics: 0.4871
# batch 00190: Learning rate is 0.000588.
# 192/660 [=======>......................] - ETA: 9:43 - loss: 1.1225 - custom_metrics: 0.4871
# batch 00191: Learning rate is 0.000588.
# 193/660 [=======>......................] - ETA: 9:42 - loss: 1.1226 - custom_metrics: 0.4870
# batch 00192: Learning rate is 0.000588.
# 194/660 [=======>......................] - ETA: 9:41 - loss: 1.1226 - custom_metrics: 0.4870
# batch 00193: Learning rate is 0.000588.
# 195/660 [=======>......................] - ETA: 9:39 - loss: 1.1226 - custom_metrics: 0.4870
# batch 00194: Learning rate is 0.000588.
# 196/660 [=======>......................] - ETA: 9:38 - loss: 1.1226 - custom_metrics: 0.4869
# batch 00195: Learning rate is 0.000588.
# 197/660 [=======>......................] - ETA: 9:37 - loss: 1.1227 - custom_metrics: 0.4869
# batch 00196: Learning rate is 0.000588.
# 198/660 [========>.....................] - ETA: 9:36 - loss: 1.1227 - custom_metrics: 0.4869
# batch 00197: Learning rate is 0.000588.
# 199/660 [========>.....................] - ETA: 9:34 - loss: 1.1227 - custom_metrics: 0.4869
# batch 00198: Learning rate is 0.000588.
# 200/660 [========>.....................] - ETA: 9:33 - loss: 1.1227 - custom_metrics: 0.4868
# batch 00199: Learning rate is 0.000588.
# 201/660 [========>.....................] - ETA: 9:32 - loss: 1.1227 - custom_metrics: 0.4868
# batch 00200: Learning rate is 0.000588.
# 202/660 [========>.....................] - ETA: 9:31 - loss: 1.1227 - custom_metrics: 0.4868
# batch 00201: Learning rate is 0.000588.
# 203/660 [========>.....................] - ETA: 9:29 - loss: 1.1227 - custom_metrics: 0.4867
# batch 00202: Learning rate is 0.000588.
# 204/660 [========>.....................] - ETA: 9:28 - loss: 1.1228 - custom_metrics: 0.4867
# batch 00203: Learning rate is 0.000588.
# 205/660 [========>.....................] - ETA: 9:27 - loss: 1.1228 - custom_metrics: 0.4867
# batch 00204: Learning rate is 0.000588.
# 206/660 [========>.....................] - ETA: 9:26 - loss: 1.1228 - custom_metrics: 0.4867
# batch 00205: Learning rate is 0.000588.
# 207/660 [========>.....................] - ETA: 9:24 - loss: 1.1228 - custom_metrics: 0.4866
# batch 00206: Learning rate is 0.000587.
# 208/660 [========>.....................] - ETA: 9:23 - loss: 1.1228 - custom_metrics: 0.4866
# batch 00207: Learning rate is 0.000587.
# 209/660 [========>.....................] - ETA: 9:22 - loss: 1.1229 - custom_metrics: 0.4866
# batch 00208: Learning rate is 0.000587.
# 210/660 [========>.....................] - ETA: 9:21 - loss: 1.1229 - custom_metrics: 0.4865
# batch 00209: Learning rate is 0.000587.
# 211/660 [========>.....................] - ETA: 9:19 - loss: 1.1229 - custom_metrics: 0.4865
# batch 00210: Learning rate is 0.000587.
# 212/660 [========>.....................] - ETA: 9:18 - loss: 1.1229 - custom_metrics: 0.4865
# batch 00211: Learning rate is 0.000587.
# 213/660 [========>.....................] - ETA: 9:17 - loss: 1.1229 - custom_metrics: 0.4864
# batch 00212: Learning rate is 0.000587.
# 214/660 [========>.....................] - ETA: 9:15 - loss: 1.1229 - custom_metrics: 0.4864
# batch 00213: Learning rate is 0.000587.
# 215/660 [========>.....................] - ETA: 9:14 - loss: 1.1229 - custom_metrics: 0.4864
# batch 00214: Learning rate is 0.000587.
# 216/660 [========>.....................] - ETA: 9:13 - loss: 1.1230 - custom_metrics: 0.4864
# batch 00215: Learning rate is 0.000587.
# 217/660 [========>.....................] - ETA: 9:12 - loss: 1.1230 - custom_metrics: 0.4863
# batch 00216: Learning rate is 0.000587.
# 218/660 [========>.....................] - ETA: 9:10 - loss: 1.1230 - custom_metrics: 0.4863
# batch 00217: Learning rate is 0.000587.
# 219/660 [========>.....................] - ETA: 9:09 - loss: 1.1230 - custom_metrics: 0.4863
# batch 00218: Learning rate is 0.000587.
# 220/660 [=========>....................] - ETA: 9:08 - loss: 1.1230 - custom_metrics: 0.4862
# batch 00219: Learning rate is 0.000587.
# 221/660 [=========>....................] - ETA: 9:07 - loss: 1.1230 - custom_metrics: 0.4862
# batch 00220: Learning rate is 0.000587.
# 222/660 [=========>....................] - ETA: 9:05 - loss: 1.1231 - custom_metrics: 0.4862
# batch 00221: Learning rate is 0.000587.
# 223/660 [=========>....................] - ETA: 9:04 - loss: 1.1231 - custom_metrics: 0.4861
# batch 00222: Learning rate is 0.000587.
# 224/660 [=========>....................] - ETA: 9:03 - loss: 1.1231 - custom_metrics: 0.4861
# batch 00223: Learning rate is 0.000587.
# 225/660 [=========>....................] - ETA: 9:02 - loss: 1.1231 - custom_metrics: 0.4861
# batch 00224: Learning rate is 0.000587.
# 226/660 [=========>....................] - ETA: 9:00 - loss: 1.1231 - custom_metrics: 0.4860
# batch 00225: Learning rate is 0.000587.
# 227/660 [=========>....................] - ETA: 8:59 - loss: 1.1231 - custom_metrics: 0.4860
# batch 00226: Learning rate is 0.000587.
# 228/660 [=========>....................] - ETA: 8:58 - loss: 1.1231 - custom_metrics: 0.4860
# batch 00227: Learning rate is 0.000587.
# 229/660 [=========>....................] - ETA: 8:57 - loss: 1.1231 - custom_metrics: 0.4860
# batch 00228: Learning rate is 0.000587.
# 230/660 [=========>....................] - ETA: 8:55 - loss: 1.1232 - custom_metrics: 0.4859
# batch 00229: Learning rate is 0.000587.
# 231/660 [=========>....................] - ETA: 8:54 - loss: 1.1232 - custom_metrics: 0.4859
# batch 00230: Learning rate is 0.000587.
# 232/660 [=========>....................] - ETA: 8:53 - loss: 1.1232 - custom_metrics: 0.4859
# batch 00231: Learning rate is 0.000587.
# 233/660 [=========>....................] - ETA: 8:51 - loss: 1.1232 - custom_metrics: 0.4858
# batch 00232: Learning rate is 0.000587.
# 234/660 [=========>....................] - ETA: 8:50 - loss: 1.1232 - custom_metrics: 0.4858
# batch 00233: Learning rate is 0.000587.
# 235/660 [=========>....................] - ETA: 8:49 - loss: 1.1232 - custom_metrics: 0.4858
# batch 00234: Learning rate is 0.000587.
# 236/660 [=========>....................] - ETA: 8:48 - loss: 1.1232 - custom_metrics: 0.4857
# batch 00235: Learning rate is 0.000587.
# 237/660 [=========>....................] - ETA: 8:46 - loss: 1.1232 - custom_metrics: 0.4857
# batch 00236: Learning rate is 0.000587.
# 238/660 [=========>....................] - ETA: 8:45 - loss: 1.1232 - custom_metrics: 0.4857
# batch 00237: Learning rate is 0.000587.
# 239/660 [=========>....................] - ETA: 8:44 - loss: 1.1232 - custom_metrics: 0.4857
# batch 00238: Learning rate is 0.000587.
# 240/660 [=========>....................] - ETA: 8:43 - loss: 1.1232 - custom_metrics: 0.4856
# batch 00239: Learning rate is 0.000587.
# 241/660 [=========>....................] - ETA: 8:41 - loss: 1.1232 - custom_metrics: 0.4856
# batch 00240: Learning rate is 0.000586.
# 242/660 [==========>...................] - ETA: 8:40 - loss: 1.1232 - custom_metrics: 0.4856
# batch 00241: Learning rate is 0.000586.
# 243/660 [==========>...................] - ETA: 8:39 - loss: 1.1232 - custom_metrics: 0.4856
# batch 00242: Learning rate is 0.000586.
# 244/660 [==========>...................] - ETA: 8:38 - loss: 1.1232 - custom_metrics: 0.4855
# batch 00243: Learning rate is 0.000586.
# 245/660 [==========>...................] - ETA: 8:36 - loss: 1.1232 - custom_metrics: 0.4855
# batch 00244: Learning rate is 0.000586.
# 246/660 [==========>...................] - ETA: 8:35 - loss: 1.1232 - custom_metrics: 0.4855
# batch 00245: Learning rate is 0.000586.
# 247/660 [==========>...................] - ETA: 8:34 - loss: 1.1232 - custom_metrics: 0.4855
# batch 00246: Learning rate is 0.000586.
# 248/660 [==========>...................] - ETA: 8:33 - loss: 1.1231 - custom_metrics: 0.4855
# batch 00247: Learning rate is 0.000586.
# 249/660 [==========>...................] - ETA: 8:31 - loss: 1.1231 - custom_metrics: 0.4854
# batch 00248: Learning rate is 0.000586.
# 250/660 [==========>...................] - ETA: 8:30 - loss: 1.1231 - custom_metrics: 0.4854
# batch 00249: Learning rate is 0.000586.
# 251/660 [==========>...................] - ETA: 8:29 - loss: 1.1231 - custom_metrics: 0.4854
# batch 00250: Learning rate is 0.000586.
# 252/660 [==========>...................] - ETA: 8:28 - loss: 1.1231 - custom_metrics: 0.4854
# batch 00251: Learning rate is 0.000586.
# 253/660 [==========>...................] - ETA: 8:26 - loss: 1.1231 - custom_metrics: 0.4854
# batch 00252: Learning rate is 0.000586.
# 254/660 [==========>...................] - ETA: 8:25 - loss: 1.1231 - custom_metrics: 0.4853
# batch 00253: Learning rate is 0.000586.
# 255/660 [==========>...................] - ETA: 8:24 - loss: 1.1231 - custom_metrics: 0.4853
# batch 00254: Learning rate is 0.000586.
# 256/660 [==========>...................] - ETA: 8:22 - loss: 1.1231 - custom_metrics: 0.4853
# batch 00255: Learning rate is 0.000586.
# 257/660 [==========>...................] - ETA: 8:21 - loss: 1.1230 - custom_metrics: 0.4853
# batch 00256: Learning rate is 0.000586.
# 258/660 [==========>...................] - ETA: 8:20 - loss: 1.1230 - custom_metrics: 0.4853
# batch 00257: Learning rate is 0.000586.
# 259/660 [==========>...................] - ETA: 8:19 - loss: 1.1230 - custom_metrics: 0.4853
# batch 00258: Learning rate is 0.000586.
# 260/660 [==========>...................] - ETA: 8:17 - loss: 1.1230 - custom_metrics: 0.4852
# batch 00259: Learning rate is 0.000586.
# 261/660 [==========>...................] - ETA: 8:16 - loss: 1.1230 - custom_metrics: 0.4852
# batch 00260: Learning rate is 0.000586.
# 262/660 [==========>...................] - ETA: 8:15 - loss: 1.1230 - custom_metrics: 0.4852
# batch 00261: Learning rate is 0.000586.
# 263/660 [==========>...................] - ETA: 8:14 - loss: 1.1229 - custom_metrics: 0.4852
# batch 00262: Learning rate is 0.000586.
# 264/660 [===========>..................] - ETA: 8:12 - loss: 1.1229 - custom_metrics: 0.4852
# batch 00263: Learning rate is 0.000586.
# 265/660 [===========>..................] - ETA: 8:11 - loss: 1.1229 - custom_metrics: 0.4852
# batch 00264: Learning rate is 0.000586.
# 266/660 [===========>..................] - ETA: 8:10 - loss: 1.1229 - custom_metrics: 0.4851
# batch 00265: Learning rate is 0.000586.
# 267/660 [===========>..................] - ETA: 8:09 - loss: 1.1229 - custom_metrics: 0.4851
# batch 00266: Learning rate is 0.000586.
# 268/660 [===========>..................] - ETA: 8:08 - loss: 1.1228 - custom_metrics: 0.4851
# batch 00267: Learning rate is 0.000586.
# 269/660 [===========>..................] - ETA: 8:06 - loss: 1.1228 - custom_metrics: 0.4851
# batch 00268: Learning rate is 0.000586.
# 270/660 [===========>..................] - ETA: 8:05 - loss: 1.1228 - custom_metrics: 0.4851
# batch 00269: Learning rate is 0.000586.
# 271/660 [===========>..................] - ETA: 8:04 - loss: 1.1228 - custom_metrics: 0.4851
# batch 00270: Learning rate is 0.000586.
# 272/660 [===========>..................] - ETA: 8:03 - loss: 1.1227 - custom_metrics: 0.4850
# batch 00271: Learning rate is 0.000586.
# 273/660 [===========>..................] - ETA: 8:01 - loss: 1.1227 - custom_metrics: 0.4850
# batch 00272: Learning rate is 0.000586.
# 274/660 [===========>..................] - ETA: 8:00 - loss: 1.1227 - custom_metrics: 0.4850
# batch 00273: Learning rate is 0.000586.
# 275/660 [===========>..................] - ETA: 7:59 - loss: 1.1226 - custom_metrics: 0.4850
# batch 00274: Learning rate is 0.000586.
# 276/660 [===========>..................] - ETA: 7:58 - loss: 1.1226 - custom_metrics: 0.4850
# batch 00275: Learning rate is 0.000585.
# 277/660 [===========>..................] - ETA: 7:56 - loss: 1.1226 - custom_metrics: 0.4850
# batch 00276: Learning rate is 0.000585.
# 278/660 [===========>..................] - ETA: 7:55 - loss: 1.1226 - custom_metrics: 0.4850
# batch 00277: Learning rate is 0.000585.
# 279/660 [===========>..................] - ETA: 7:54 - loss: 1.1225 - custom_metrics: 0.4850
# batch 00278: Learning rate is 0.000585.
# 280/660 [===========>..................] - ETA: 7:53 - loss: 1.1225 - custom_metrics: 0.4850
# batch 00279: Learning rate is 0.000585.
# 281/660 [===========>..................] - ETA: 7:51 - loss: 1.1225 - custom_metrics: 0.4850
# batch 00280: Learning rate is 0.000585.
# 282/660 [===========>..................] - ETA: 7:50 - loss: 1.1225 - custom_metrics: 0.4849
# batch 00281: Learning rate is 0.000585.
# 283/660 [===========>..................] - ETA: 7:49 - loss: 1.1224 - custom_metrics: 0.4849
# batch 00282: Learning rate is 0.000585.
# 284/660 [===========>..................] - ETA: 7:48 - loss: 1.1224 - custom_metrics: 0.4849
# batch 00283: Learning rate is 0.000585.
# 285/660 [===========>..................] - ETA: 7:46 - loss: 1.1224 - custom_metrics: 0.4849
# batch 00284: Learning rate is 0.000585.
# 286/660 [============>.................] - ETA: 7:45 - loss: 1.1224 - custom_metrics: 0.4849
# batch 00285: Learning rate is 0.000585.
# 287/660 [============>.................] - ETA: 7:44 - loss: 1.1223 - custom_metrics: 0.4849
# batch 00286: Learning rate is 0.000585.
# 288/660 [============>.................] - ETA: 7:43 - loss: 1.1223 - custom_metrics: 0.4849
# batch 00287: Learning rate is 0.000585.
# 289/660 [============>.................] - ETA: 7:41 - loss: 1.1223 - custom_metrics: 0.4849
# batch 00288: Learning rate is 0.000585.
# 290/660 [============>.................] - ETA: 7:40 - loss: 1.1223 - custom_metrics: 0.4849
# batch 00289: Learning rate is 0.000585.
# 291/660 [============>.................] - ETA: 7:39 - loss: 1.1222 - custom_metrics: 0.4849
# batch 00290: Learning rate is 0.000585.
# 292/660 [============>.................] - ETA: 7:38 - loss: 1.1222 - custom_metrics: 0.4849
# batch 00291: Learning rate is 0.000585.
# 293/660 [============>.................] - ETA: 7:36 - loss: 1.1222 - custom_metrics: 0.4849
# batch 00292: Learning rate is 0.000585.
# 294/660 [============>.................] - ETA: 7:35 - loss: 1.1222 - custom_metrics: 0.4849
# batch 00293: Learning rate is 0.000585.
# 295/660 [============>.................] - ETA: 7:34 - loss: 1.1222 - custom_metrics: 0.4848
# batch 00294: Learning rate is 0.000585.
# 296/660 [============>.................] - ETA: 7:33 - loss: 1.1221 - custom_metrics: 0.4848
# batch 00295: Learning rate is 0.000585.
# 297/660 [============>.................] - ETA: 7:31 - loss: 1.1221 - custom_metrics: 0.4848
# batch 00296: Learning rate is 0.000585.
# 298/660 [============>.................] - ETA: 7:30 - loss: 1.1221 - custom_metrics: 0.4848
# batch 00297: Learning rate is 0.000585.
# 299/660 [============>.................] - ETA: 7:29 - loss: 1.1221 - custom_metrics: 0.4848
# batch 00298: Learning rate is 0.000585.
# 300/660 [============>.................] - ETA: 7:28 - loss: 1.1220 - custom_metrics: 0.4848
# batch 00299: Learning rate is 0.000585.
# 301/660 [============>.................] - ETA: 7:26 - loss: 1.1220 - custom_metrics: 0.4848
# batch 00300: Learning rate is 0.000585.
# 302/660 [============>.................] - ETA: 7:25 - loss: 1.1220 - custom_metrics: 0.4848
# batch 00301: Learning rate is 0.000585.
# 303/660 [============>.................] - ETA: 7:24 - loss: 1.1219 - custom_metrics: 0.4848
# batch 00302: Learning rate is 0.000585.
# 304/660 [============>.................] - ETA: 7:23 - loss: 1.1219 - custom_metrics: 0.4848
# batch 00303: Learning rate is 0.000585.
# 305/660 [============>.................] - ETA: 7:21 - loss: 1.1219 - custom_metrics: 0.4848
# batch 00304: Learning rate is 0.000585.
# 306/660 [============>.................] - ETA: 7:20 - loss: 1.1219 - custom_metrics: 0.4848
# batch 00305: Learning rate is 0.000585.
# 307/660 [============>.................] - ETA: 7:19 - loss: 1.1218 - custom_metrics: 0.4848
# batch 00306: Learning rate is 0.000585.
# 308/660 [=============>................] - ETA: 7:18 - loss: 1.1218 - custom_metrics: 0.4848
# batch 00307: Learning rate is 0.000585.
# 309/660 [=============>................] - ETA: 7:16 - loss: 1.1218 - custom_metrics: 0.4848
# batch 00308: Learning rate is 0.000585.
# 310/660 [=============>................] - ETA: 7:15 - loss: 1.1217 - custom_metrics: 0.4848
# batch 00309: Learning rate is 0.000584.
# 311/660 [=============>................] - ETA: 7:14 - loss: 1.1217 - custom_metrics: 0.4848
# batch 00310: Learning rate is 0.000584.
# 312/660 [=============>................] - ETA: 7:13 - loss: 1.1217 - custom_metrics: 0.4847
# batch 00311: Learning rate is 0.000584.
# 313/660 [=============>................] - ETA: 7:11 - loss: 1.1217 - custom_metrics: 0.4847
# batch 00312: Learning rate is 0.000584.
# 314/660 [=============>................] - ETA: 7:10 - loss: 1.1216 - custom_metrics: 0.4847
# batch 00313: Learning rate is 0.000584.
# 315/660 [=============>................] - ETA: 7:09 - loss: 1.1216 - custom_metrics: 0.4847
# batch 00314: Learning rate is 0.000584.
# 316/660 [=============>................] - ETA: 7:08 - loss: 1.1216 - custom_metrics: 0.4847
# batch 00315: Learning rate is 0.000584.
# 317/660 [=============>................] - ETA: 7:06 - loss: 1.1216 - custom_metrics: 0.4847
# batch 00316: Learning rate is 0.000584.
# 318/660 [=============>................] - ETA: 7:05 - loss: 1.1215 - custom_metrics: 0.4847
# batch 00317: Learning rate is 0.000584.
# 319/660 [=============>................] - ETA: 7:04 - loss: 1.1215 - custom_metrics: 0.4847
# batch 00318: Learning rate is 0.000584.
# 320/660 [=============>................] - ETA: 7:02 - loss: 1.1215 - custom_metrics: 0.4847
# batch 00319: Learning rate is 0.000584.
# 321/660 [=============>................] - ETA: 7:01 - loss: 1.1215 - custom_metrics: 0.4847
# batch 00320: Learning rate is 0.000584.
# 322/660 [=============>................] - ETA: 7:00 - loss: 1.1214 - custom_metrics: 0.4847
# batch 00321: Learning rate is 0.000584.
# 323/660 [=============>................] - ETA: 6:59 - loss: 1.1214 - custom_metrics: 0.4847
# batch 00322: Learning rate is 0.000584.
# 324/660 [=============>................] - ETA: 6:57 - loss: 1.1214 - custom_metrics: 0.4847
# batch 00323: Learning rate is 0.000584.
# 325/660 [=============>................] - ETA: 6:56 - loss: 1.1214 - custom_metrics: 0.4847
# batch 00324: Learning rate is 0.000584.
# 326/660 [=============>................] - ETA: 6:55 - loss: 1.1213 - custom_metrics: 0.4847
# batch 00325: Learning rate is 0.000584.
# 327/660 [=============>................] - ETA: 6:54 - loss: 1.1213 - custom_metrics: 0.4847
# batch 00326: Learning rate is 0.000584.
# 328/660 [=============>................] - ETA: 6:52 - loss: 1.1213 - custom_metrics: 0.4847
# batch 00327: Learning rate is 0.000584.
# 329/660 [=============>................] - ETA: 6:51 - loss: 1.1213 - custom_metrics: 0.4847
# batch 00328: Learning rate is 0.000584.
# 330/660 [==============>...............] - ETA: 6:50 - loss: 1.1212 - custom_metrics: 0.4847
# batch 00329: Learning rate is 0.000584.
# 331/660 [==============>...............] - ETA: 6:49 - loss: 1.1212 - custom_metrics: 0.4846
# batch 00330: Learning rate is 0.000584.
# 332/660 [==============>...............] - ETA: 6:47 - loss: 1.1212 - custom_metrics: 0.4846
# batch 00331: Learning rate is 0.000584.
# 333/660 [==============>...............] - ETA: 6:46 - loss: 1.1212 - custom_metrics: 0.4846
# batch 00332: Learning rate is 0.000584.
# 334/660 [==============>...............] - ETA: 6:45 - loss: 1.1211 - custom_metrics: 0.4846
# batch 00333: Learning rate is 0.000584.
# 335/660 [==============>...............] - ETA: 6:44 - loss: 1.1211 - custom_metrics: 0.4846
# batch 00334: Learning rate is 0.000584.
# 336/660 [==============>...............] - ETA: 6:42 - loss: 1.1211 - custom_metrics: 0.4846
# batch 00335: Learning rate is 0.000584.
# 337/660 [==============>...............] - ETA: 6:41 - loss: 1.1210 - custom_metrics: 0.4846
# batch 00336: Learning rate is 0.000584.
# 338/660 [==============>...............] - ETA: 6:40 - loss: 1.1210 - custom_metrics: 0.4846
# batch 00337: Learning rate is 0.000584.
# 339/660 [==============>...............] - ETA: 6:39 - loss: 1.1209 - custom_metrics: 0.4846
# batch 00338: Learning rate is 0.000584.
# 340/660 [==============>...............] - ETA: 6:37 - loss: 1.1209 - custom_metrics: 0.4846
# batch 00339: Learning rate is 0.000584.
# 341/660 [==============>...............] - ETA: 6:36 - loss: 1.1209 - custom_metrics: 0.4846
# batch 00340: Learning rate is 0.000584.
# 342/660 [==============>...............] - ETA: 6:35 - loss: 1.1208 - custom_metrics: 0.4846
# batch 00341: Learning rate is 0.000584.
# 343/660 [==============>...............] - ETA: 6:34 - loss: 1.1208 - custom_metrics: 0.4847
# batch 00342: Learning rate is 0.000584.
# 344/660 [==============>...............] - ETA: 6:33 - loss: 1.1207 - custom_metrics: 0.4847
# batch 00343: Learning rate is 0.000584.
# 345/660 [==============>...............] - ETA: 6:31 - loss: 1.1207 - custom_metrics: 0.4847
# batch 00344: Learning rate is 0.000583.
# 346/660 [==============>...............] - ETA: 6:30 - loss: 1.1207 - custom_metrics: 0.4847
# batch 00345: Learning rate is 0.000583.
# 347/660 [==============>...............] - ETA: 6:29 - loss: 1.1206 - custom_metrics: 0.4847
# batch 00346: Learning rate is 0.000583.
# 348/660 [==============>...............] - ETA: 6:28 - loss: 1.1206 - custom_metrics: 0.4847
# batch 00347: Learning rate is 0.000583.
# 349/660 [==============>...............] - ETA: 6:26 - loss: 1.1206 - custom_metrics: 0.4847
# batch 00348: Learning rate is 0.000583.
# 350/660 [==============>...............] - ETA: 6:25 - loss: 1.1205 - custom_metrics: 0.4847
# batch 00349: Learning rate is 0.000583.
# 351/660 [==============>...............] - ETA: 6:24 - loss: 1.1205 - custom_metrics: 0.4846
# batch 00350: Learning rate is 0.000583.
# 352/660 [===============>..............] - ETA: 6:22 - loss: 1.1205 - custom_metrics: 0.4846
# batch 00351: Learning rate is 0.000583.
# 353/660 [===============>..............] - ETA: 6:21 - loss: 1.1204 - custom_metrics: 0.4846
# batch 00352: Learning rate is 0.000583.
# 354/660 [===============>..............] - ETA: 6:20 - loss: 1.1204 - custom_metrics: 0.4846
# batch 00353: Learning rate is 0.000583.
# 355/660 [===============>..............] - ETA: 6:19 - loss: 1.1204 - custom_metrics: 0.4846
# batch 00354: Learning rate is 0.000583.
# 356/660 [===============>..............] - ETA: 6:17 - loss: 1.1204 - custom_metrics: 0.4846
# batch 00355: Learning rate is 0.000583.
# 357/660 [===============>..............] - ETA: 6:16 - loss: 1.1203 - custom_metrics: 0.4846
# batch 00356: Learning rate is 0.000583.
# 358/660 [===============>..............] - ETA: 6:15 - loss: 1.1203 - custom_metrics: 0.4846
# batch 00357: Learning rate is 0.000583.
# 359/660 [===============>..............] - ETA: 6:14 - loss: 1.1203 - custom_metrics: 0.4846
# batch 00358: Learning rate is 0.000583.
# ...
# batch 00499: Learning rate is 0.000560.
# 501/660 [=====================>........] - ETA: 3:17 - loss: 1.1200 - custom_metrics: 0.4828
# batch 00500: Learning rate is 0.000560.
# 502/660 [=====================>........] - ETA: 3:16 - loss: 1.1200 - custom_metrics: 0.4828
# batch 00501: Learning rate is 0.000560.
# 503/660 [=====================>........] - ETA: 3:15 - loss: 1.1200 - custom_metrics: 0.4828
# batch 00502: Learning rate is 0.000560.
# 504/660 [=====================>........] - ETA: 3:13 - loss: 1.1200 - custom_metrics: 0.4828
# batch 00503: Learning rate is 0.000560.
# 505/660 [=====================>........] - ETA: 3:12 - loss: 1.1199 - custom_metrics: 0.4828
# batch 00504: Learning rate is 0.000560.
# 506/660 [======================>.......] - ETA: 3:11 - loss: 1.1199 - custom_metrics: 0.4828
# batch 00505: Learning rate is 0.000560.
# 507/660 [======================>.......] - ETA: 3:10 - loss: 1.1199 - custom_metrics: 0.4828
# batch 00506: Learning rate is 0.000560.
# 508/660 [======================>.......] - ETA: 3:08 - loss: 1.1199 - custom_metrics: 0.4828
# batch 00507: Learning rate is 0.000560.
# 509/660 [======================>.......] - ETA: 3:07 - loss: 1.1198 - custom_metrics: 0.4828
# batch 00508: Learning rate is 0.000560.
# 510/660 [======================>.......] - ETA: 3:06 - loss: 1.1198 - custom_metrics: 0.4828
# batch 00509: Learning rate is 0.000560.
# 511/660 [======================>.......] - ETA: 3:05 - loss: 1.1198 - custom_metrics: 0.4828
# batch 00510: Learning rate is 0.000560.
# 512/660 [======================>.......] - ETA: 3:03 - loss: 1.1198 - custom_metrics: 0.4828
# batch 00511: Learning rate is 0.000559.
# 513/660 [======================>.......] - ETA: 3:02 - loss: 1.1197 - custom_metrics: 0.4828
# batch 00512: Learning rate is 0.000559.
# 514/660 [======================>.......] - ETA: 3:01 - loss: 1.1197 - custom_metrics: 0.4828
# batch 00513: Learning rate is 0.000559.
# 515/660 [======================>.......] - ETA: 3:00 - loss: 1.1197 - custom_metrics: 0.4828
# batch 00514: Learning rate is 0.000559.
# 516/660 [======================>.......] - ETA: 2:58 - loss: 1.1197 - custom_metrics: 0.4828
# batch 00515: Learning rate is 0.000559.
# 517/660 [======================>.......] - ETA: 2:57 - loss: 1.1196 - custom_metrics: 0.4828
# batch 00516: Learning rate is 0.000559.
# 518/660 [======================>.......] - ETA: 2:56 - loss: 1.1196 - custom_metrics: 0.4828
# batch 00517: Learning rate is 0.000559.
# 519/660 [======================>.......] - ETA: 2:55 - loss: 1.1196 - custom_metrics: 0.4828
# batch 00518: Learning rate is 0.000559.
# 520/660 [======================>.......] - ETA: 2:53 - loss: 1.1196 - custom_metrics: 0.4828
# batch 00519: Learning rate is 0.000559.
# 521/660 [======================>.......] - ETA: 2:52 - loss: 1.1195 - custom_metrics: 0.4828
# batch 00520: Learning rate is 0.000559.
# 522/660 [======================>.......] - ETA: 2:51 - loss: 1.1195 - custom_metrics: 0.4828
# batch 00521: Learning rate is 0.000559.
# 523/660 [======================>.......] - ETA: 2:50 - loss: 1.1195 - custom_metrics: 0.4828
# batch 00522: Learning rate is 0.000559.
# 524/660 [======================>.......] - ETA: 2:48 - loss: 1.1195 - custom_metrics: 0.4828
# batch 00523: Learning rate is 0.000559.
# 525/660 [======================>.......] - ETA: 2:47 - loss: 1.1194 - custom_metrics: 0.4828
# batch 00524: Learning rate is 0.000559.
# 526/660 [======================>.......] - ETA: 2:46 - loss: 1.1194 - custom_metrics: 0.4828
# batch 00525: Learning rate is 0.000559.
# 527/660 [======================>.......] - ETA: 2:45 - loss: 1.1194 - custom_metrics: 0.4828
# batch 00526: Learning rate is 0.000559.
# 528/660 [=======================>......] - ETA: 2:43 - loss: 1.1194 - custom_metrics: 0.4828
# batch 00527: Learning rate is 0.000559.
# 529/660 [=======================>......] - ETA: 2:42 - loss: 1.1193 - custom_metrics: 0.4828
# batch 00528: Learning rate is 0.000559.
# 530/660 [=======================>......] - ETA: 2:41 - loss: 1.1193 - custom_metrics: 0.4828
# batch 00529: Learning rate is 0.000559.
# 531/660 [=======================>......] - ETA: 2:40 - loss: 1.1193 - custom_metrics: 0.4828
# batch 00530: Learning rate is 0.000559.
# 532/660 [=======================>......] - ETA: 2:39 - loss: 1.1192 - custom_metrics: 0.4828
# batch 00531: Learning rate is 0.000559.
# 533/660 [=======================>......] - ETA: 2:37 - loss: 1.1192 - custom_metrics: 0.4828
# batch 00532: Learning rate is 0.000559.
# 534/660 [=======================>......] - ETA: 2:36 - loss: 1.1192 - custom_metrics: 0.4828
# batch 00533: Learning rate is 0.000559.
# 535/660 [=======================>......] - ETA: 2:35 - loss: 1.1192 - custom_metrics: 0.4828
# batch 00534: Learning rate is 0.000559.
# 536/660 [=======================>......] - ETA: 2:34 - loss: 1.1191 - custom_metrics: 0.4828
# batch 00535: Learning rate is 0.000559.
# 537/660 [=======================>......] - ETA: 2:32 - loss: 1.1191 - custom_metrics: 0.4828
# batch 00536: Learning rate is 0.000559.
# 538/660 [=======================>......] - ETA: 2:31 - loss: 1.1191 - custom_metrics: 0.4828
# batch 00537: Learning rate is 0.000559.
# 539/660 [=======================>......] - ETA: 2:30 - loss: 1.1191 - custom_metrics: 0.4828
# batch 00538: Learning rate is 0.000559.
# 540/660 [=======================>......] - ETA: 2:29 - loss: 1.1190 - custom_metrics: 0.4828
# batch 00539: Learning rate is 0.000559.
# 541/660 [=======================>......] - ETA: 2:27 - loss: 1.1190 - custom_metrics: 0.4828
# batch 00540: Learning rate is 0.000559.
# 542/660 [=======================>......] - ETA: 2:26 - loss: 1.1190 - custom_metrics: 0.4828
# batch 00541: Learning rate is 0.000559.
# 543/660 [=======================>......] - ETA: 2:25 - loss: 1.1190 - custom_metrics: 0.4828
# batch 00542: Learning rate is 0.000559.
# 544/660 [=======================>......] - ETA: 2:24 - loss: 1.1189 - custom_metrics: 0.4828
# batch 00543: Learning rate is 0.000559.
# 545/660 [=======================>......] - ETA: 2:22 - loss: 1.1189 - custom_metrics: 0.4828
# batch 00544: Learning rate is 0.000559.
# 546/660 [=======================>......] - ETA: 2:21 - loss: 1.1189 - custom_metrics: 0.4828
# batch 00545: Learning rate is 0.000558.
# 547/660 [=======================>......] - ETA: 2:20 - loss: 1.1189 - custom_metrics: 0.4828
# batch 00546: Learning rate is 0.000558.
# 548/660 [=======================>......] - ETA: 2:19 - loss: 1.1188 - custom_metrics: 0.4828
# batch 00547: Learning rate is 0.000558.
# 549/660 [=======================>......] - ETA: 2:17 - loss: 1.1188 - custom_metrics: 0.4828
# batch 00548: Learning rate is 0.000558.
# 550/660 [========================>.....] - ETA: 2:16 - loss: 1.1188 - custom_metrics: 0.4828
# batch 00549: Learning rate is 0.000558.
# 551/660 [========================>.....] - ETA: 2:15 - loss: 1.1188 - custom_metrics: 0.4828
# batch 00550: Learning rate is 0.000558.
# 552/660 [========================>.....] - ETA: 2:14 - loss: 1.1187 - custom_metrics: 0.4828
# batch 00551: Learning rate is 0.000558.
# 553/660 [========================>.....] - ETA: 2:12 - loss: 1.1187 - custom_metrics: 0.4828
# batch 00552: Learning rate is 0.000558.
# 554/660 [========================>.....] - ETA: 2:11 - loss: 1.1187 - custom_metrics: 0.4828
# batch 00553: Learning rate is 0.000558.
# 555/660 [========================>.....] - ETA: 2:10 - loss: 1.1187 - custom_metrics: 0.4828
# batch 00554: Learning rate is 0.000558.
# 556/660 [========================>.....] - ETA: 2:09 - loss: 1.1186 - custom_metrics: 0.4828
# batch 00555: Learning rate is 0.000558.
# 557/660 [========================>.....] - ETA: 2:07 - loss: 1.1186 - custom_metrics: 0.4828
# batch 00556: Learning rate is 0.000558.
# 558/660 [========================>.....] - ETA: 2:06 - loss: 1.1186 - custom_metrics: 0.4829
# batch 00557: Learning rate is 0.000558.
# 559/660 [========================>.....] - ETA: 2:05 - loss: 1.1186 - custom_metrics: 0.4829
# batch 00558: Learning rate is 0.000558.
# 560/660 [========================>.....] - ETA: 2:04 - loss: 1.1185 - custom_metrics: 0.4829
# batch 00559: Learning rate is 0.000558.
# 561/660 [========================>.....] - ETA: 2:02 - loss: 1.1185 - custom_metrics: 0.4829
# batch 00560: Learning rate is 0.000558.
# 562/660 [========================>.....] - ETA: 2:01 - loss: 1.1185 - custom_metrics: 0.4829
# batch 00561: Learning rate is 0.000558.
# 563/660 [========================>.....] - ETA: 2:00 - loss: 1.1185 - custom_metrics: 0.4829
# batch 00562: Learning rate is 0.000558.
# 564/660 [========================>.....] - ETA: 1:59 - loss: 1.1184 - custom_metrics: 0.4829
# batch 00563: Learning rate is 0.000558.
# 565/660 [========================>.....] - ETA: 1:58 - loss: 1.1184 - custom_metrics: 0.4829
# batch 00564: Learning rate is 0.000558.
# 566/660 [========================>.....] - ETA: 1:56 - loss: 1.1184 - custom_metrics: 0.4829
# batch 00565: Learning rate is 0.000558.
# 567/660 [========================>.....] - ETA: 1:55 - loss: 1.1184 - custom_metrics: 0.4829
# batch 00566: Learning rate is 0.000558.
# 568/660 [========================>.....] - ETA: 1:54 - loss: 1.1183 - custom_metrics: 0.4829
# batch 00567: Learning rate is 0.000558.
# 569/660 [========================>.....] - ETA: 1:53 - loss: 1.1183 - custom_metrics: 0.4829
# batch 00568: Learning rate is 0.000558.
# 570/660 [========================>.....] - ETA: 1:51 - loss: 1.1183 - custom_metrics: 0.4829
# batch 00569: Learning rate is 0.000558.
# 571/660 [========================>.....] - ETA: 1:50 - loss: 1.1183 - custom_metrics: 0.4829
# batch 00570: Learning rate is 0.000558.
# 572/660 [=========================>....] - ETA: 1:49 - loss: 1.1182 - custom_metrics: 0.4829
# batch 00571: Learning rate is 0.000558.
# 573/660 [=========================>....] - ETA: 1:48 - loss: 1.1182 - custom_metrics: 0.4829
# batch 00572: Learning rate is 0.000558.
# 574/660 [=========================>....] - ETA: 1:46 - loss: 1.1182 - custom_metrics: 0.4829
# batch 00573: Learning rate is 0.000558.
# 575/660 [=========================>....] - ETA: 1:45 - loss: 1.1182 - custom_metrics: 0.4829
# batch 00574: Learning rate is 0.000558.
# 576/660 [=========================>....] - ETA: 1:44 - loss: 1.1181 - custom_metrics: 0.4829
# batch 00575: Learning rate is 0.000558.
# 577/660 [=========================>....] - ETA: 1:43 - loss: 1.1181 - custom_metrics: 0.4829
# batch 00576: Learning rate is 0.000558.
# 578/660 [=========================>....] - ETA: 1:41 - loss: 1.1181 - custom_metrics: 0.4829
# batch 00577: Learning rate is 0.000558.
# 579/660 [=========================>....] - ETA: 1:40 - loss: 1.1181 - custom_metrics: 0.4829
# batch 00578: Learning rate is 0.000558.
# 580/660 [=========================>....] - ETA: 1:39 - loss: 1.1180 - custom_metrics: 0.4829
# batch 00579: Learning rate is 0.000557.
# 581/660 [=========================>....] - ETA: 1:38 - loss: 1.1180 - custom_metrics: 0.4829
# batch 00580: Learning rate is 0.000557.
# 582/660 [=========================>....] - ETA: 1:36 - loss: 1.1180 - custom_metrics: 0.4829
# batch 00581: Learning rate is 0.000557.
# 583/660 [=========================>....] - ETA: 1:35 - loss: 1.1180 - custom_metrics: 0.4829
# batch 00582: Learning rate is 0.000557.
# 584/660 [=========================>....] - ETA: 1:34 - loss: 1.1179 - custom_metrics: 0.4829
# batch 00583: Learning rate is 0.000557.
# 585/660 [=========================>....] - ETA: 1:33 - loss: 1.1179 - custom_metrics: 0.4829
# batch 00584: Learning rate is 0.000557.
# 586/660 [=========================>....] - ETA: 1:31 - loss: 1.1179 - custom_metrics: 0.4829
# batch 00585: Learning rate is 0.000557.
# 587/660 [=========================>....] - ETA: 1:30 - loss: 1.1179 - custom_metrics: 0.4829
# batch 00586: Learning rate is 0.000557.
# 588/660 [=========================>....] - ETA: 1:29 - loss: 1.1178 - custom_metrics: 0.4829
# batch 00587: Learning rate is 0.000557.
# 589/660 [=========================>....] - ETA: 1:28 - loss: 1.1178 - custom_metrics: 0.4829
# batch 00588: Learning rate is 0.000557.
# 590/660 [=========================>....] - ETA: 1:26 - loss: 1.1178 - custom_metrics: 0.4829
# batch 00589: Learning rate is 0.000557.
# 591/660 [=========================>....] - ETA: 1:25 - loss: 1.1178 - custom_metrics: 0.4829
# batch 00590: Learning rate is 0.000557.
# 592/660 [=========================>....] - ETA: 1:24 - loss: 1.1177 - custom_metrics: 0.4829
# batch 00591: Learning rate is 0.000557.
# 593/660 [=========================>....] - ETA: 1:23 - loss: 1.1177 - custom_metrics: 0.4829
# batch 00592: Learning rate is 0.000557.
# 594/660 [==========================>...] - ETA: 1:21 - loss: 1.1177 - custom_metrics: 0.4829
# batch 00593: Learning rate is 0.000557.
# 595/660 [==========================>...] - ETA: 1:20 - loss: 1.1177 - custom_metrics: 0.4829
# batch 00594: Learning rate is 0.000557.
# 596/660 [==========================>...] - ETA: 1:19 - loss: 1.1176 - custom_metrics: 0.4829
# batch 00595: Learning rate is 0.000557.
# 597/660 [==========================>...] - ETA: 1:18 - loss: 1.1176 - custom_metrics: 0.4829
# batch 00596: Learning rate is 0.000557.
# 598/660 [==========================>...] - ETA: 1:17 - loss: 1.1176 - custom_metrics: 0.4829
# batch 00597: Learning rate is 0.000557.
# 599/660 [==========================>...] - ETA: 1:15 - loss: 1.1176 - custom_metrics: 0.4829
# batch 00598: Learning rate is 0.000557.
# 600/660 [==========================>...] - ETA: 1:14 - loss: 1.1175 - custom_metrics: 0.4829
# batch 00599: Learning rate is 0.000557.
# 601/660 [==========================>...] - ETA: 1:13 - loss: 1.1175 - custom_metrics: 0.4829
# batch 00600: Learning rate is 0.000557.
# 602/660 [==========================>...] - ETA: 1:12 - loss: 1.1175 - custom_metrics: 0.4829
# batch 00601: Learning rate is 0.000557.
# 603/660 [==========================>...] - ETA: 1:10 - loss: 1.1175 - custom_metrics: 0.4829
# batch 00602: Learning rate is 0.000557.
# 604/660 [==========================>...] - ETA: 1:09 - loss: 1.1175 - custom_metrics: 0.4829
# batch 00603: Learning rate is 0.000557.
# 605/660 [==========================>...] - ETA: 1:08 - loss: 1.1174 - custom_metrics: 0.4829
# batch 00604: Learning rate is 0.000557.
# 606/660 [==========================>...] - ETA: 1:07 - loss: 1.1174 - custom_metrics: 0.4829
# batch 00605: Learning rate is 0.000557.
# 607/660 [==========================>...] - ETA: 1:05 - loss: 1.1174 - custom_metrics: 0.4829
# batch 00606: Learning rate is 0.000557.
# 608/660 [==========================>...] - ETA: 1:04 - loss: 1.1174 - custom_metrics: 0.4829
# batch 00607: Learning rate is 0.000557.
# 609/660 [==========================>...] - ETA: 1:03 - loss: 1.1173 - custom_metrics: 0.4829
# batch 00608: Learning rate is 0.000557.
# 610/660 [==========================>...] - ETA: 1:02 - loss: 1.1173 - custom_metrics: 0.4829
# batch 00609: Learning rate is 0.000557.
# 611/660 [==========================>...] - ETA: 1:00 - loss: 1.1173 - custom_metrics: 0.4829
# batch 00610: Learning rate is 0.000557.
# 612/660 [==========================>...] - ETA: 59s - loss: 1.1173 - custom_metrics: 0.4829
# batch 00611: Learning rate is 0.000557.
# 613/660 [==========================>...] - ETA: 58s - loss: 1.1172 - custom_metrics: 0.4829
# batch 00612: Learning rate is 0.000557.
# 614/660 [==========================>...] - ETA: 57s - loss: 1.1172 - custom_metrics: 0.4829
# batch 00613: Learning rate is 0.000557.
# 615/660 [==========================>...] - ETA: 55s - loss: 1.1172 - custom_metrics: 0.4829
# batch 00614: Learning rate is 0.000556.
# 616/660 [===========================>..] - ETA: 54s - loss: 1.1172 - custom_metrics: 0.4829
# batch 00615: Learning rate is 0.000556.
# 617/660 [===========================>..] - ETA: 53s - loss: 1.1172 - custom_metrics: 0.4829
# batch 00616: Learning rate is 0.000556.
# 618/660 [===========================>..] - ETA: 52s - loss: 1.1171 - custom_metrics: 0.4829
# batch 00617: Learning rate is 0.000556.
# 619/660 [===========================>..] - ETA: 50s - loss: 1.1171 - custom_metrics: 0.4829
# batch 00618: Learning rate is 0.000556.
# 620/660 [===========================>..] - ETA: 49s - loss: 1.1171 - custom_metrics: 0.4829
# batch 00619: Learning rate is 0.000556.

# %%
def encoder(inputs):
    skip_layers = []
    model2 = ResNet18(include_top=False,weights='imagenet',input_tensor=inputs)
    x = model2.get_layer('relu1').output
    names = ['bn0','stage2_unit1_bn1','stage3_unit1_bn1','stage4_unit1_bn1']
    for name in names:
        layer = model2.get_layer(name).output
        skip_layers.append(layer)
    return x,skip_layers
def transistion_conv(x,filter=256):
    x = Conv2D(filter,(1,1), padding="same")(x)
    x = BatchNormalization()(x)
    x = UpSampling2D((2,2))(x)
    y_1=x
    return x ,y_1
def decoder_conv(x,y_1,filters = 64):
    # print(x.shape)
    y = Conv2D(filters,(3,3), padding="same")(x)
    y = BatchNormalization()(y)
    y = Activation('relu')(y)
    y = Conv2D(filters,(3,3), padding="same")(y)
    y = BatchNormalization()(y)
    y = Add()([y_1,y])
    y_1 = y
    y = Activation('relu')(y)
    return y,y_1
def decoder(x,y_1,skip_layers):
    filters  = [256,128,64,64,64]
    skip_layers.reverse()
    for i in range(len(filters)-1):
        if i in [0,1,2,3]:
            x = Add()([x,skip_layers[i]])
            x = Activation('relu')(x)
        x,y_1 = decoder_conv(x,y_1,filters[i])
        x,y_1 = decoder_conv(x,y_1,filters[i])
        x,y_1 = transistion_conv(x,filters[i+1])
        x = Activation('relu')(x)
    return x
def outputs(input):
    x = Conv2D(64,(3,3), padding="same")(input)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(38,(1,1), padding="same")(x)
    return x 
def main_model(shape):
    inputs = Input(shape)
    encoded,skip_layers = encoder(inputs)
    transistioned,y_1 = transistion_conv(encoded) 
    decoded = decoder(transistioned,y_1,skip_layers)
    output = outputs(decoded)
    model = Model(inputs,output)
    return model 
shape = (480,640,3)
model = main_model(shape)
model.summary()
