# %% [markdown]
# <a href="https://colab.research.google.com/github/sameepshrestha/segmentation_state_of_the_art/blob/main/Untitled121.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# # 
# import tensorflow as tf 
# from tensorflow.keras.layers import Input
# inputs = Input(shape=(480,640,3))
# model = tf.keras.applications.EfficientNetB7(include_top=False,weights="imagenet",input_tensor=inputs)

# %%
# model.summary()
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import matplotlib.pyplot as plt 
import numpy as np 
import cv2 as cv 
from PIL import Image, ImageDraw
import json 
import os 
import glob 
import re 
from tqdm import tqdm
import tensorflow as tf 
from tensorflow import keras 
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense, Conv2D, Reshape, Concatenate,MaxPooling2D, AveragePooling2D,Input, BatchNormalization, Activation, UpSampling2D, Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam 
#using tensorflow backend 16 so keras backend still 32bytes so no keras to be used
# from keras.layers.merge import concatenate,Concatenate
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import gc

# %%
tf.keras.mixed_precision.experimental.set_policy('mixed_float16')

# %%
category = """wall, floor, cabinet, bed, chair, sofa, table, door, window, bookshelf, picture, counter, blinds, desk, shelves, curtain, dresser
, pillow, mirror, floor mat, clothes, ceiling, books, fridge, tv, paper, towel, shower curtain, box, whiteboard, person, nightstand, toilet, sink
, lamp, bathtub, bag"""
category = category.split(r', ')
category_dict = {k.replace('\n',''):category.index(k)+1 for k in category}
print(category_dict)
reverse_map={i:k for k,i in category_dict.items()}
color_list=['#a0522d','#FF0000','#FFFF00','#0000F','#4B8BBE','#306998','#FFE873','#FFD43B','#646464','#5a0000','#003a27','#C0C0C0','#808080','#800000','#808000','#00FF00','#00FFFF','#008080','#000080','#FF00FF','#800080','#CD5C5C','#F08080','#FA8072','#E9967A','#FFA07A','#DC143C','#FF7F50','#FFD700','#ffffe0','#bdb76b','#228b22','#B0E0E6','#4169e1','#f0ffff','#d2691e','#BC8F8F']
class_color_map={k:color_list[i] for i,k in enumerate(reverse_map.keys())}
# Out:
# {'wall': 1, 'floor': 2, 'cabinet': 3, 'bed': 4, 'chair': 5, 'sofa': 6, 'table': 7, 'door': 8, 'window': 9, 'bookshelf': 10, 'picture': 11, 'counter': 12, 'blinds': 13, 'desk': 14, 'shelves': 15, 'curtain': 16, 'dresser': 17, 'pillow': 18, 'mirror': 19, 'floor mat': 20, 'clothes': 21, 'ceiling': 22, 'books': 23, 'fridge': 24, 'tv': 25, 'paper': 26, 'towel': 27, 'shower curtain': 28, 'box': 29, 'whiteboard': 30, 'person': 31, 'nightstand': 32, 'toilet': 33, 'sink': 34, 'lamp': 35, 'bathtub': 36, 'bag': 37}

# %%
AUTO = tf.data.experimental.AUTOTUNE
Image_width = 640 
Image_height = 480 
no_classes = len(category_dict)
def load_data(path, split=0.2):
    images = sorted(glob.glob(os.path.join(path, "image/*")))
    print(len(images))
    masks = sorted(glob.glob(os.path.join(path, "mask/*")))
    print(len(masks))
    total_size = 7990
    test_size = 1990
    valid_size=1000
    training_x, test_x = train_test_split(images[:7990], test_size=test_size, random_state=42)
    training_y, test_y = train_test_split(masks[:7990], test_size=test_size, random_state=42)
    train_x, valid_x = train_test_split(training_x, test_size=valid_size, random_state=42)
    train_y, valid_y = train_test_split(training_y, test_size=valid_size, random_state=42)
    return (train_x, train_y), (valid_x, valid_y),(test_x, test_y)
(train_x,train_y),(valid_x,valid_y),(test_x, test_y)=load_data('/content/drive/MyDrive/depth')
train_size=len(train_x)
valid_size=len(valid_x)

def read_image(path):
    path = path.decode()
    x = cv.imread(path, cv.IMREAD_COLOR)
    x = cv.resize(x,(640,480),interpolation=cv.INTER_AREA)
    x = x/255.0
    x=tf.cast(x,dtype=tf.float32)
    return x

def read_mask(path):
    path = path.decode()
    x = cv.imread(path, cv.IMREAD_GRAYSCALE)
    x = cv.resize(x,(640,480),interpolation=cv.INTER_NEAREST)
  
    x = to_categorical(x,num_classes=no_classes+1)
    x = x[:,:,:]
    # x = np.expand_dims(x, axis=-1)
    # x=np.concatenate([x,x],axis=-1)
    x=tf.cast(x,dtype=tf.float32)
    return x
# read_mask('/content/drive/MyDrive/depth/mask100/mask1.png')
def parser(x,y):
    def _parse(x,y):
        x=read_image(x)
        y=read_mask(y)
        return x,y
    x,y = tf.numpy_function(_parse, [x,y], [tf.float32,tf.float32])
    x.set_shape([Image_height, Image_width, 3])
    y.set_shape([Image_height, Image_width, no_classes+1])
    return x,y
    
def tf_dataset(x, y, batch):
    dataset = tf.data.Dataset.from_tensor_slices((x, y))
    dataset = dataset.map(parser)
    dataset = dataset.repeat()
    dataset = dataset.batch(batch)
    dataset = dataset.prefetch(AUTO) 
    return dataset
train_dataset=tf_dataset(train_x,train_y,batch=16)
valid_dataset=tf_dataset(valid_x,valid_y,batch=16)
valid_dataset

# %%
def conv_block(inputs,filters):
  x = Conv2D(filters, (3, 3), padding="same",kernel_initializer='he_normal')(inputs)
  x = BatchNormalization()(x)
  x = Activation('relu')(x)
  x = Conv2D(filters, (3, 3), padding="same",kernel_initializer='he_normal')(x)
  x = BatchNormalization()(x)
  x = Activation('relu')(x)
  return x 

def encoder(inputs):
  num_filters = [32,64, 128,256,256]
  x= inputs
  for i,filters  in enumerate(num_filters):
    x = conv_block(x,filters)
    x = MaxPooling2D((2, 2))(x)
  return x 
def decoder(x):
  num_filters = [32,64, 128,256,256]
  num_filters.reverse()
  for i,filters in enumerate(num_filters):
    print(filters)
    x = conv_block(x,filters)
    x = UpSampling2D((2,2))(x)
    
  return x
def output_block(inputs,classes):
    x = Conv2D(classes, (1, 1), padding="same")(inputs)
    return x
def main_model(shape):
  inputs = Input(shape)
  encoded = encoder(inputs)
  decoded = decoder(encoded)
  output = output_block(decoded,classes=38)
  model = Model(inputs,output)
  return model

model = main_model((480,640,3))
# Out:
# 256
# 256
# 128
# 64
# 32

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 480, 640, 3)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 480, 640, 32)      896
# _________________________________________________________________
# batch_normalization (BatchNo (None, 480, 640, 32)      128
# _________________________________________________________________
# activation (Activation)      (None, 480, 640, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 480, 640, 32)      9248
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 480, 640, 32)      128
# _________________________________________________________________
# activation_1 (Activation)    (None, 480, 640, 32)      0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 240, 320, 32)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 240, 320, 64)      18496
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 240, 320, 64)      256
# _________________________________________________________________
# activation_2 (Activation)    (None, 240, 320, 64)      0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 240, 320, 64)      36928
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 240, 320, 64)      256
# _________________________________________________________________
# activation_3 (Activation)    (None, 240, 320, 64)      0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 120, 160, 64)      0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 120, 160, 128)     73856
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 120, 160, 128)     512
# _________________________________________________________________
# activation_4 (Activation)    (None, 120, 160, 128)     0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 120, 160, 128)     147584
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 120, 160, 128)     512
# _________________________________________________________________
# activation_5 (Activation)    (None, 120, 160, 128)     0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 60, 80, 128)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 60, 80, 256)       295168
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 60, 80, 256)       1024
# _________________________________________________________________
# activation_6 (Activation)    (None, 60, 80, 256)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 60, 80, 256)       590080
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 60, 80, 256)       1024
# _________________________________________________________________
# activation_7 (Activation)    (None, 60, 80, 256)       0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 30, 40, 256)       0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 30, 40, 256)       590080
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 30, 40, 256)       1024
# _________________________________________________________________
# activation_8 (Activation)    (None, 30, 40, 256)       0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 30, 40, 256)       590080
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 30, 40, 256)       1024
# _________________________________________________________________
# activation_9 (Activation)    (None, 30, 40, 256)       0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 15, 20, 256)       0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 15, 20, 256)       590080
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 15, 20, 256)       1024
# _________________________________________________________________
# activation_10 (Activation)   (None, 15, 20, 256)       0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 15, 20, 256)       590080
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 15, 20, 256)       1024
# _________________________________________________________________
# activation_11 (Activation)   (None, 15, 20, 256)       0
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 30, 40, 256)       0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 30, 40, 256)       590080
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 30, 40, 256)       1024
# _________________________________________________________________
# activation_12 (Activation)   (None, 30, 40, 256)       0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 30, 40, 256)       590080
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 30, 40, 256)       1024
# _________________________________________________________________
# activation_13 (Activation)   (None, 30, 40, 256)       0
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 60, 80, 256)       0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 60, 80, 128)       295040
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 60, 80, 128)       512
# _________________________________________________________________
# activation_14 (Activation)   (None, 60, 80, 128)       0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 60, 80, 128)       147584
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 60, 80, 128)       512
# _________________________________________________________________
# activation_15 (Activation)   (None, 60, 80, 128)       0
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 120, 160, 128)     0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 120, 160, 64)      73792
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 120, 160, 64)      256
# _________________________________________________________________
# activation_16 (Activation)   (None, 120, 160, 64)      0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 120, 160, 64)      36928
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 120, 160, 64)      256
# _________________________________________________________________
# activation_17 (Activation)   (None, 120, 160, 64)      0
# _________________________________________________________________
# up_sampling2d_3 (UpSampling2 (None, 240, 320, 64)      0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 240, 320, 32)      18464
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 240, 320, 32)      128
# _________________________________________________________________
# activation_18 (Activation)   (None, 240, 320, 32)      0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 240, 320, 32)      9248
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 240, 320, 32)      128
# _________________________________________________________________
# activation_19 (Activation)   (None, 240, 320, 32)      0
# _________________________________________________________________
# up_sampling2d_4 (UpSampling2 (None, 480, 640, 32)      0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 480, 640, 38)      1254
# =================================================================
# Total params: 5,306,822
# Trainable params: 5,300,934
# Non-trainable params: 5,888
# _________________________________________________________________

# %%
#loss function 

import gc 
from tensorflow.keras.losses import binary_crossentropy
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import CSVLogger , TensorBoard, LearningRateScheduler,Callback
class ClearMemory(Callback):
    def on_epoch_end(self, epoch, logs=None):
        gc.collect()
        tf.keras.backend.clear_session()
filepath= '/content/drive/MyDrive/training-daily/june14-5000/checkpoint/'
filepath2 = '/content/drive/MyDrive/training-daily/june14-5000/tensorboard'
callbacks = [
    EarlyStopping(monitor='val_custom_metrics', patience=5),
    ModelCheckpoint(filepath, monitor='val_custom_metrics',verbose=1,mode='max',save_best_only=True),
    ClearMemory()    
    # TensorBoard(filepath2,histogram_freq=1),
    # LearningRateScheduler(lrfn, verbose = True)
    
]
def binary_loss(y_true, y_pred):
    return binary_crossentropy(y_true, y_pred)


def cross_entropy_loss(y_true,y_pred):
    # y_pred = tf.math.exp(y_pred)
    # sum = tf.math.reduce_sum(y_pred, axis = [-1],keepdims=True)
    # y_pred = tf.divide(y_pred,sum)
    loss = tf.nn.softmax_cross_entropy_with_logits(
    y_true, y_pred, axis=-1, name=None)
    return loss

def custom_metrics(y_true,y_pred,smooth=1):
    y_pred = tf.math.argmax(y_pred, axis=-1)
    # y_pred = tf.expand_dims(y_pred,axis=-1)
    y_pred = tf.one_hot(y_pred,38)
    y_true = y_true[:,:,:,1:38]
    y_pred= y_pred[:,:,:,1:38]
    intersection  = tf.math.reduce_sum((y_true*y_pred),axis = [1,2,3])
    union = tf.math.reduce_sum(y_true,axis=[1,2,3])+tf.math.reduce_sum(y_pred,axis = [1,2,3]) - intersection 
    return tf.math.reduce_mean((intersection+smooth)/(union+smooth),axis=0)
smooth = 1
def dice_coef(y_true, y_pred):
    y_true = tf.keras.layers.Flatten()(y_true)
    y_pred = tf.keras.layers.Flatten()(y_pred)
    intersection = tf.reduce_sum(y_true * y_pred)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)
model=tf.keras.models.load_model('/content/drive/MyDrive/training-daily/june14-5000/checkpoint/',custom_objects={
        'cross_entropy_loss': cross_entropy_loss ,'dice_coef': dice_coef,'custom_metrics':custom_metrics})
model.compile(loss = cross_entropy_loss,optimizer=Adam(learning_rate =.001),metrics=[custom_metrics])

# %%
t_steps=train_size//16
v_steps=valid_size//16
model.fit(train_dataset, 
                        epochs = 3,
                        steps_per_epoch = t_steps,
                        validation_data = valid_dataset,
                        validation_steps = v_steps,
                        callbacks=callbacks
                 )
# Out:
# Epoch 1/3
# 312/312 [==============================] - 1144s 4s/step - loss: 1.4722 - custom_metrics: 0.3590 - val_loss: 1.4855 - val_custom_metrics: 0.3599
#
# Epoch 00001: val_custom_metrics improved from -inf to 0.35992, saving model to /content/drive/MyDrive/training-daily/june14-5000/checkpoint/
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/training-daily/june14-5000/checkpoint/assets
# Epoch 2/3
# 312/312 [==============================] - 1105s 4s/step - loss: 1.4287 - custom_metrics: 0.3705 - val_loss: 1.5125 - val_custom_metrics: 0.3461
#
# Epoch 00002: val_custom_metrics did not improve from 0.35992
# Epoch 3/3
# 312/312 [==============================] - 1098s 4s/step - loss: 1.3967 - custom_metrics: 0.3805 - val_loss: 1.5054 - val_custom_metrics: 0.3540
#
# Epoch 00003: val_custom_metrics did not improve from 0.35992

# %%
def read_image(path):
    x = cv.imread(path, cv.IMREAD_COLOR)
    x = cv.resize(x,(640,480),interpolation=cv.INTER_AREA)
    x = x/255.0
    x=tf.cast(x,dtype=tf.float32)
    return x

def read_mask(path):
    x = cv.imread(path, cv.IMREAD_GRAYSCALE)
    x = cv.resize(x,(640,480),interpolation=cv.INTER_AREA)
    x = to_categorical(x,num_classes=no_classes+1)
    x = x[:,:,:]
    # x = np.expand_dims(x, axis=-1)
    # x=np.concatenate([x,x],axis=-1)
    x=tf.cast(x,dtype=tf.float32)
    return x
def custom_metrics(y_true,y_pred,smooth=1):
    y_pred = tf.math.argmax(y_pred, axis=-1)
    # y_pred = tf.expand_dims(y_pred,axis=-1)
    y_pred = tf.one_hot(y_pred,38)
    y_true = y_true[:,:,:,1:38]
    y_pred= y_pred[:,:,:,1:38]
    intersection  = tf.math.reduce_sum((y_true*y_pred),axis = [1,2,3])
    union = tf.math.reduce_sum(y_true,axis=[1,2,3])+tf.math.reduce_sum(y_pred,axis = [1,2,3]) - intersection 
    return tf.math.reduce_mean((intersection+smooth)/(union+smooth),axis=0)
def load_data(images,masks):
    length = 1990
    iou=0
    for i,(image,mask) in enumerate(zip(images,masks)):
    
      img = read_image(image)
      mas = read_mask(mask)
      img = np.expand_dims(img,0)
      mas = np.expand_dims(mas,0)
      prediction = model.predict(img)
      iou += custom_metrics(mas,prediction)
      print(i,iou)
    return iou/length
no_classes=37
print(len(test_x))
x=load_data(test_x,test_y)
print('*****************************************************************************************************************')
x
# Out:
# 1990
# 0 tf.Tensor(0.4558471, shape=(), dtype=float32)
# 1 tf.Tensor(0.97910917, shape=(), dtype=float32)
# 2 tf.Tensor(1.3471472, shape=(), dtype=float32)
# 3 tf.Tensor(1.8753548, shape=(), dtype=float32)
# 4 tf.Tensor(2.199679, shape=(), dtype=float32)
# 5 tf.Tensor(2.3359532, shape=(), dtype=float32)
# 6 tf.Tensor(2.9933825, shape=(), dtype=float32)
# 7 tf.Tensor(2.9933927, shape=(), dtype=float32)
# 8 tf.Tensor(3.1676202, shape=(), dtype=float32)
# 9 tf.Tensor(3.4613695, shape=(), dtype=float32)
# 10 tf.Tensor(3.5988634, shape=(), dtype=float32)
# 11 tf.Tensor(4.050014, shape=(), dtype=float32)
# 12 tf.Tensor(4.5838757, shape=(), dtype=float32)
# 13 tf.Tensor(4.9347773, shape=(), dtype=float32)
# 14 tf.Tensor(5.303016, shape=(), dtype=float32)
# 15 tf.Tensor(5.6274724, shape=(), dtype=float32)
# 16 tf.Tensor(5.970132, shape=(), dtype=float32)
# 17 tf.Tensor(6.845397, shape=(), dtype=float32)
# 18 tf.Tensor(7.220998, shape=(), dtype=float32)
# 19 tf.Tensor(7.4937806, shape=(), dtype=float32)
# 20 tf.Tensor(8.23516, shape=(), dtype=float32)
# 21 tf.Tensor(8.3366375, shape=(), dtype=float32)
# 22 tf.Tensor(8.77404, shape=(), dtype=float32)
# 23 tf.Tensor(8.871277, shape=(), dtype=float32)
# 24 tf.Tensor(9.398501, shape=(), dtype=float32)
# 25 tf.Tensor(9.659091, shape=(), dtype=float32)
# 26 tf.Tensor(10.0332365, shape=(), dtype=float32)
# 27 tf.Tensor(10.096305, shape=(), dtype=float32)
# 28 tf.Tensor(10.240771, shape=(), dtype=float32)
# 29 tf.Tensor(10.376623, shape=(), dtype=float32)
# 30 tf.Tensor(10.622612, shape=(), dtype=float32)
# 31 tf.Tensor(10.804306, shape=(), dtype=float32)
# 32 tf.Tensor(11.065664, shape=(), dtype=float32)
# 33 tf.Tensor(11.650285, shape=(), dtype=float32)
# 34 tf.Tensor(11.650306, shape=(), dtype=float32)
# 35 tf.Tensor(12.170222, shape=(), dtype=float32)
# 36 tf.Tensor(12.549205, shape=(), dtype=float32)
# 37 tf.Tensor(13.050082, shape=(), dtype=float32)
# 38 tf.Tensor(13.570599, shape=(), dtype=float32)
# 39 tf.Tensor(13.570701, shape=(), dtype=float32)
# 40 tf.Tensor(13.8534975, shape=(), dtype=float32)
# 41 tf.Tensor(14.69579, shape=(), dtype=float32)
# 42 tf.Tensor(14.761612, shape=(), dtype=float32)
# 43 tf.Tensor(14.8278675, shape=(), dtype=float32)
# 44 tf.Tensor(15.040489, shape=(), dtype=float32)
# 45 tf.Tensor(15.394357, shape=(), dtype=float32)
# 46 tf.Tensor(15.431289, shape=(), dtype=float32)
# 47 tf.Tensor(15.493682, shape=(), dtype=float32)
# 48 tf.Tensor(15.824268, shape=(), dtype=float32)
# 49 tf.Tensor(16.194225, shape=(), dtype=float32)
# 50 tf.Tensor(16.305355, shape=(), dtype=float32)
# 51 tf.Tensor(16.890871, shape=(), dtype=float32)
# 52 tf.Tensor(17.069403, shape=(), dtype=float32)
# 53 tf.Tensor(17.403065, shape=(), dtype=float32)
# 54 tf.Tensor(17.932907, shape=(), dtype=float32)
# 55 tf.Tensor(17.94329, shape=(), dtype=float32)
# 56 tf.Tensor(18.464378, shape=(), dtype=float32)
# 57 tf.Tensor(18.659348, shape=(), dtype=float32)
# 58 tf.Tensor(19.26278, shape=(), dtype=float32)
# 59 tf.Tensor(19.28567, shape=(), dtype=float32)
# 60 tf.Tensor(19.296661, shape=(), dtype=float32)
# 61 tf.Tensor(19.568779, shape=(), dtype=float32)
# 62 tf.Tensor(19.75325, shape=(), dtype=float32)
# 63 tf.Tensor(20.215479, shape=(), dtype=float32)
# 64 tf.Tensor(20.629526, shape=(), dtype=float32)
# 65 tf.Tensor(21.061941, shape=(), dtype=float32)
# 66 tf.Tensor(21.231022, shape=(), dtype=float32)
# 67 tf.Tensor(21.502209, shape=(), dtype=float32)
# 68 tf.Tensor(21.839329, shape=(), dtype=float32)
# 69 tf.Tensor(22.425919, shape=(), dtype=float32)
# 70 tf.Tensor(22.6784, shape=(), dtype=float32)
# 71 tf.Tensor(23.183292, shape=(), dtype=float32)
# 72 tf.Tensor(23.897064, shape=(), dtype=float32)
# 73 tf.Tensor(24.198174, shape=(), dtype=float32)
# 74 tf.Tensor(24.577389, shape=(), dtype=float32)
# 75 tf.Tensor(24.968296, shape=(), dtype=float32)
# 76 tf.Tensor(25.097372, shape=(), dtype=float32)
# 77 tf.Tensor(25.832394, shape=(), dtype=float32)
# 78 tf.Tensor(26.21381, shape=(), dtype=float32)
# 79 tf.Tensor(26.776455, shape=(), dtype=float32)
# 80 tf.Tensor(27.333275, shape=(), dtype=float32)
# 81 tf.Tensor(27.938416, shape=(), dtype=float32)
# 82 tf.Tensor(28.473166, shape=(), dtype=float32)
# 83 tf.Tensor(28.993483, shape=(), dtype=float32)
# 84 tf.Tensor(29.10363, shape=(), dtype=float32)
# 85 tf.Tensor(29.543407, shape=(), dtype=float32)
# 86 tf.Tensor(29.99443, shape=(), dtype=float32)
# 87 tf.Tensor(30.710688, shape=(), dtype=float32)
# 88 tf.Tensor(30.974285, shape=(), dtype=float32)
# 89 tf.Tensor(31.282377, shape=(), dtype=float32)
# 90 tf.Tensor(31.764843, shape=(), dtype=float32)
# 91 tf.Tensor(31.9926, shape=(), dtype=float32)
# 92 tf.Tensor(32.464268, shape=(), dtype=float32)
# 93 tf.Tensor(32.948353, shape=(), dtype=float32)
# 94 tf.Tensor(33.13654, shape=(), dtype=float32)
# 95 tf.Tensor(33.655544, shape=(), dtype=float32)
# 96 tf.Tensor(34.476425, shape=(), dtype=float32)
# 97 tf.Tensor(34.729855, shape=(), dtype=float32)
# 98 tf.Tensor(34.978214, shape=(), dtype=float32)
# 99 tf.Tensor(35.084118, shape=(), dtype=float32)
# 100 tf.Tensor(35.221516, shape=(), dtype=float32)
# 101 tf.Tensor(35.664764, shape=(), dtype=float32)
# 102 tf.Tensor(36.30049, shape=(), dtype=float32)
# 103 tf.Tensor(37.104, shape=(), dtype=float32)
# 104 tf.Tensor(37.367504, shape=(), dtype=float32)
# 105 tf.Tensor(37.506794, shape=(), dtype=float32)
# 106 tf.Tensor(37.95775, shape=(), dtype=float32)
# 107 tf.Tensor(38.050034, shape=(), dtype=float32)
# 108 tf.Tensor(38.31023, shape=(), dtype=float32)
# 109 tf.Tensor(38.73377, shape=(), dtype=float32)
# 110 tf.Tensor(38.875824, shape=(), dtype=float32)
# 111 tf.Tensor(39.40782, shape=(), dtype=float32)
# 112 tf.Tensor(39.707283, shape=(), dtype=float32)
# 113 tf.Tensor(40.518158, shape=(), dtype=float32)
# 114 tf.Tensor(40.905632, shape=(), dtype=float32)
# 115 tf.Tensor(41.49328, shape=(), dtype=float32)
# 116 tf.Tensor(42.109303, shape=(), dtype=float32)
# 117 tf.Tensor(42.554268, shape=(), dtype=float32)
# 118 tf.Tensor(43.32581, shape=(), dtype=float32)
# 119 tf.Tensor(43.61885, shape=(), dtype=float32)
# 120 tf.Tensor(44.31766, shape=(), dtype=float32)
# 121 tf.Tensor(44.921234, shape=(), dtype=float32)
# 122 tf.Tensor(45.434498, shape=(), dtype=float32)
# 123 tf.Tensor(45.899254, shape=(), dtype=float32)
# 124 tf.Tensor(46.45655, shape=(), dtype=float32)
# 125 tf.Tensor(47.01752, shape=(), dtype=float32)
# 126 tf.Tensor(47.16571, shape=(), dtype=float32)
# 127 tf.Tensor(47.89775, shape=(), dtype=float32)
# 128 tf.Tensor(48.458603, shape=(), dtype=float32)
# 129 tf.Tensor(48.488274, shape=(), dtype=float32)
# 130 tf.Tensor(48.736874, shape=(), dtype=float32)
# 131 tf.Tensor(48.888405, shape=(), dtype=float32)
# 132 tf.Tensor(49.082554, shape=(), dtype=float32)
# 133 tf.Tensor(49.620213, shape=(), dtype=float32)
# 134 tf.Tensor(49.620384, shape=(), dtype=float32)
# 135 tf.Tensor(50.0189, shape=(), dtype=float32)
# 136 tf.Tensor(50.165276, shape=(), dtype=float32)
# 137 tf.Tensor(50.641453, shape=(), dtype=float32)
# 138 tf.Tensor(51.122425, shape=(), dtype=float32)
# 139 tf.Tensor(51.336365, shape=(), dtype=float32)
# 140 tf.Tensor(51.59711, shape=(), dtype=float32)
# 141 tf.Tensor(52.081837, shape=(), dtype=float32)
# 142 tf.Tensor(52.519863, shape=(), dtype=float32)
# 143 tf.Tensor(52.732735, shape=(), dtype=float32)
# 144 tf.Tensor(53.096172, shape=(), dtype=float32)
# 145 tf.Tensor(53.456554, shape=(), dtype=float32)
# 146 tf.Tensor(53.50335, shape=(), dtype=float32)
# 147 tf.Tensor(53.815422, shape=(), dtype=float32)
# 148 tf.Tensor(53.815434, shape=(), dtype=float32)
# 149 tf.Tensor(53.91267, shape=(), dtype=float32)
# 150 tf.Tensor(54.30283, shape=(), dtype=float32)
# 151 tf.Tensor(54.94646, shape=(), dtype=float32)
# 152 tf.Tensor(55.634304, shape=(), dtype=float32)
# 153 tf.Tensor(55.643745, shape=(), dtype=float32)
# 154 tf.Tensor(56.617725, shape=(), dtype=float32)
# 155 tf.Tensor(57.21346, shape=(), dtype=float32)
# 156 tf.Tensor(57.389534, shape=(), dtype=float32)
# 157 tf.Tensor(57.696194, shape=(), dtype=float32)
# 158 tf.Tensor(57.839626, shape=(), dtype=float32)
# 159 tf.Tensor(58.166595, shape=(), dtype=float32)
# 160 tf.Tensor(58.546047, shape=(), dtype=float32)
# 161 tf.Tensor(58.62267, shape=(), dtype=float32)
# 162 tf.Tensor(58.83856, shape=(), dtype=float32)
# 163 tf.Tensor(59.49588, shape=(), dtype=float32)
# 164 tf.Tensor(59.701046, shape=(), dtype=float32)
# 165 tf.Tensor(60.10447, shape=(), dtype=float32)
# 166 tf.Tensor(60.299698, shape=(), dtype=float32)
# 167 tf.Tensor(60.771706, shape=(), dtype=float32)
# 168 tf.Tensor(60.771713, shape=(), dtype=float32)
# 169 tf.Tensor(61.304146, shape=(), dtype=float32)
# 170 tf.Tensor(61.532055, shape=(), dtype=float32)
# 171 tf.Tensor(62.249756, shape=(), dtype=float32)
# 172 tf.Tensor(62.755444, shape=(), dtype=float32)
# 173 tf.Tensor(62.75551, shape=(), dtype=float32)
# 174 tf.Tensor(63.49014, shape=(), dtype=float32)
# 175 tf.Tensor(63.635307, shape=(), dtype=float32)
# 176 tf.Tensor(63.911823, shape=(), dtype=float32)
# 177 tf.Tensor(64.4847, shape=(), dtype=float32)
# 178 tf.Tensor(64.70614, shape=(), dtype=float32)
# 179 tf.Tensor(65.254326, shape=(), dtype=float32)
# 180 tf.Tensor(66.002144, shape=(), dtype=float32)
# 181 tf.Tensor(66.07771, shape=(), dtype=float32)
# 182 tf.Tensor(66.55087, shape=(), dtype=float32)
# 183 tf.Tensor(66.55095, shape=(), dtype=float32)
# 184 tf.Tensor(66.66479, shape=(), dtype=float32)
# 185 tf.Tensor(66.7995, shape=(), dtype=float32)
# 186 tf.Tensor(67.387344, shape=(), dtype=float32)
# 187 tf.Tensor(67.62843, shape=(), dtype=float32)
# 188 tf.Tensor(68.07698, shape=(), dtype=float32)
# 189 tf.Tensor(68.13508, shape=(), dtype=float32)
# 190 tf.Tensor(68.77369, shape=(), dtype=float32)
# 191 tf.Tensor(68.97745, shape=(), dtype=float32)
# 192 tf.Tensor(69.50457, shape=(), dtype=float32)
# 193 tf.Tensor(69.64869, shape=(), dtype=float32)
# 194 tf.Tensor(70.09248, shape=(), dtype=float32)
# 195 tf.Tensor(70.527596, shape=(), dtype=float32)
# 196 tf.Tensor(70.678185, shape=(), dtype=float32)
# 197 tf.Tensor(70.93586, shape=(), dtype=float32)
# 198 tf.Tensor(71.55367, shape=(), dtype=float32)
# 199 tf.Tensor(71.725006, shape=(), dtype=float32)
# 200 tf.Tensor(72.347084, shape=(), dtype=float32)
# 201 tf.Tensor(72.34709, shape=(), dtype=float32)
# 202 tf.Tensor(72.74224, shape=(), dtype=float32)
# 203 tf.Tensor(72.93902, shape=(), dtype=float32)
# 204 tf.Tensor(73.56458, shape=(), dtype=float32)
# 205 tf.Tensor(73.75424, shape=(), dtype=float32)
# 206 tf.Tensor(73.88266, shape=(), dtype=float32)
# 207 tf.Tensor(73.882675, shape=(), dtype=float32)
# 208 tf.Tensor(74.00782, shape=(), dtype=float32)
# 209 tf.Tensor(74.6846, shape=(), dtype=float32)
# 210 tf.Tensor(74.80522, shape=(), dtype=float32)
# 211 tf.Tensor(75.46107, shape=(), dtype=float32)
# 212 tf.Tensor(75.85775, shape=(), dtype=float32)
# 213 tf.Tensor(75.87839, shape=(), dtype=float32)
# 214 tf.Tensor(76.09551, shape=(), dtype=float32)
# 215 tf.Tensor(76.18974, shape=(), dtype=float32)
# 216 tf.Tensor(76.68588, shape=(), dtype=float32)
# 217 tf.Tensor(76.81922, shape=(), dtype=float32)
# 218 tf.Tensor(77.11922, shape=(), dtype=float32)
# 219 tf.Tensor(77.21291, shape=(), dtype=float32)
# 220 tf.Tensor(77.88851, shape=(), dtype=float32)
# 221 tf.Tensor(78.11547, shape=(), dtype=float32)
# 222 tf.Tensor(78.446686, shape=(), dtype=float32)
# 223 tf.Tensor(79.05702, shape=(), dtype=float32)
# 224 tf.Tensor(79.36693, shape=(), dtype=float32)
# 225 tf.Tensor(79.63213, shape=(), dtype=float32)
# 226 tf.Tensor(79.79514, shape=(), dtype=float32)
# 227 tf.Tensor(80.327, shape=(), dtype=float32)
# 228 tf.Tensor(80.56986, shape=(), dtype=float32)
# 229 tf.Tensor(80.74808, shape=(), dtype=float32)
# 230 tf.Tensor(80.79872, shape=(), dtype=float32)
# 231 tf.Tensor(81.1706, shape=(), dtype=float32)
# 232 tf.Tensor(81.279366, shape=(), dtype=float32)
# 233 tf.Tensor(81.464645, shape=(), dtype=float32)
# 234 tf.Tensor(81.58975, shape=(), dtype=float32)
# 235 tf.Tensor(81.92275, shape=(), dtype=float32)
# 236 tf.Tensor(82.10423, shape=(), dtype=float32)
# 237 tf.Tensor(82.44664, shape=(), dtype=float32)
# 238 tf.Tensor(82.79361, shape=(), dtype=float32)
# 239 tf.Tensor(83.500786, shape=(), dtype=float32)
# 240 tf.Tensor(83.81476, shape=(), dtype=float32)
# 241 tf.Tensor(84.40438, shape=(), dtype=float32)
# 242 tf.Tensor(84.572174, shape=(), dtype=float32)
# 243 tf.Tensor(84.70892, shape=(), dtype=float32)
# 244 tf.Tensor(85.28685, shape=(), dtype=float32)
# 245 tf.Tensor(85.5824, shape=(), dtype=float32)
# 246 tf.Tensor(85.66881, shape=(), dtype=float32)
# 247 tf.Tensor(86.02936, shape=(), dtype=float32)
# 248 tf.Tensor(86.088196, shape=(), dtype=float32)
# 249 tf.Tensor(86.509926, shape=(), dtype=float32)
# 250 tf.Tensor(86.517105, shape=(), dtype=float32)
# 251 tf.Tensor(86.8049, shape=(), dtype=float32)
# 252 tf.Tensor(87.5615, shape=(), dtype=float32)
# 253 tf.Tensor(88.22796, shape=(), dtype=float32)
# 254 tf.Tensor(89.02735, shape=(), dtype=float32)
# 255 tf.Tensor(89.51471, shape=(), dtype=float32)
# 256 tf.Tensor(89.600815, shape=(), dtype=float32)
# 257 tf.Tensor(90.02459, shape=(), dtype=float32)
# 258 tf.Tensor(90.285126, shape=(), dtype=float32)
# 259 tf.Tensor(90.94973, shape=(), dtype=float32)
# 260 tf.Tensor(91.04677, shape=(), dtype=float32)
# 261 tf.Tensor(91.37098, shape=(), dtype=float32)
# 262 tf.Tensor(91.71077, shape=(), dtype=float32)
# 263 tf.Tensor(92.14187, shape=(), dtype=float32)
# 264 tf.Tensor(92.605644, shape=(), dtype=float32)
# 265 tf.Tensor(93.064285, shape=(), dtype=float32)
# 266 tf.Tensor(93.198456, shape=(), dtype=float32)
# 267 tf.Tensor(93.74894, shape=(), dtype=float32)
# 268 tf.Tensor(94.08879, shape=(), dtype=float32)
# 269 tf.Tensor(94.62975, shape=(), dtype=float32)
# 270 tf.Tensor(94.9331, shape=(), dtype=float32)
# 271 tf.Tensor(95.075195, shape=(), dtype=float32)
# 272 tf.Tensor(95.237785, shape=(), dtype=float32)
# 273 tf.Tensor(95.40221, shape=(), dtype=float32)
# 274 tf.Tensor(95.873276, shape=(), dtype=float32)
# 275 tf.Tensor(96.24862, shape=(), dtype=float32)
# 276 tf.Tensor(96.30562, shape=(), dtype=float32)
# 277 tf.Tensor(96.49236, shape=(), dtype=float32)
# 278 tf.Tensor(96.70043, shape=(), dtype=float32)
# 279 tf.Tensor(96.84204, shape=(), dtype=float32)
# 280 tf.Tensor(97.114235, shape=(), dtype=float32)
# 281 tf.Tensor(97.589836, shape=(), dtype=float32)
# 282 tf.Tensor(97.91263, shape=(), dtype=float32)
# 283 tf.Tensor(98.04164, shape=(), dtype=float32)
# 284 tf.Tensor(98.62057, shape=(), dtype=float32)
# 285 tf.Tensor(98.930466, shape=(), dtype=float32)
# 286 tf.Tensor(99.45841, shape=(), dtype=float32)
# 287 tf.Tensor(99.72931, shape=(), dtype=float32)
# 288 tf.Tensor(100.38463, shape=(), dtype=float32)
# 289 tf.Tensor(100.78893, shape=(), dtype=float32)
# 290 tf.Tensor(101.44311, shape=(), dtype=float32)
# 291 tf.Tensor(101.50326, shape=(), dtype=float32)
# 292 tf.Tensor(101.8191, shape=(), dtype=float32)
# 293 tf.Tensor(101.89768, shape=(), dtype=float32)
# 294 tf.Tensor(102.28032, shape=(), dtype=float32)
# 295 tf.Tensor(102.52275, shape=(), dtype=float32)
# 296 tf.Tensor(103.024506, shape=(), dtype=float32)
# 297 tf.Tensor(103.059715, shape=(), dtype=float32)
# 298 tf.Tensor(103.339584, shape=(), dtype=float32)
# 299 tf.Tensor(103.76993, shape=(), dtype=float32)
# 300 tf.Tensor(104.27385, shape=(), dtype=float32)
# 301 tf.Tensor(104.636765, shape=(), dtype=float32)
# 302 tf.Tensor(104.80653, shape=(), dtype=float32)
# 303 tf.Tensor(105.25895, shape=(), dtype=float32)
# 304 tf.Tensor(105.34439, shape=(), dtype=float32)
# 305 tf.Tensor(105.59642, shape=(), dtype=float32)
# 306 tf.Tensor(105.64661, shape=(), dtype=float32)
# 307 tf.Tensor(106.201416, shape=(), dtype=float32)
# 308 tf.Tensor(106.64569, shape=(), dtype=float32)
# 309 tf.Tensor(106.833305, shape=(), dtype=float32)
# 310 tf.Tensor(107.04347, shape=(), dtype=float32)
# 311 tf.Tensor(107.255005, shape=(), dtype=float32)
# 312 tf.Tensor(107.77957, shape=(), dtype=float32)
# 313 tf.Tensor(108.36068, shape=(), dtype=float32)
# 314 tf.Tensor(108.62378, shape=(), dtype=float32)
# 315 tf.Tensor(109.00588, shape=(), dtype=float32)
# 316 tf.Tensor(109.52902, shape=(), dtype=float32)
# 317 tf.Tensor(109.92232, shape=(), dtype=float32)
# 318 tf.Tensor(110.42531, shape=(), dtype=float32)
# 319 tf.Tensor(110.89584, shape=(), dtype=float32)
# 320 tf.Tensor(111.6109, shape=(), dtype=float32)
# 321 tf.Tensor(111.9893, shape=(), dtype=float32)
# 322 tf.Tensor(112.238914, shape=(), dtype=float32)
# 323 tf.Tensor(112.813736, shape=(), dtype=float32)
# 324 tf.Tensor(113.41188, shape=(), dtype=float32)
# 325 tf.Tensor(113.56125, shape=(), dtype=float32)
# 326 tf.Tensor(114.06438, shape=(), dtype=float32)
# 327 tf.Tensor(114.42489, shape=(), dtype=float32)
# 328 tf.Tensor(114.82077, shape=(), dtype=float32)
# 329 tf.Tensor(114.99952, shape=(), dtype=float32)
# 330 tf.Tensor(115.384026, shape=(), dtype=float32)
# 331 tf.Tensor(116.15224, shape=(), dtype=float32)
# 332 tf.Tensor(116.62578, shape=(), dtype=float32)
# 333 tf.Tensor(116.71428, shape=(), dtype=float32)
# 334 tf.Tensor(116.71573, shape=(), dtype=float32)
# 335 tf.Tensor(117.08184, shape=(), dtype=float32)
# 336 tf.Tensor(117.202286, shape=(), dtype=float32)
# 337 tf.Tensor(117.56185, shape=(), dtype=float32)
# 338 tf.Tensor(117.881775, shape=(), dtype=float32)
# 339 tf.Tensor(118.1622, shape=(), dtype=float32)
# 340 tf.Tensor(118.58494, shape=(), dtype=float32)
# 341 tf.Tensor(118.58511, shape=(), dtype=float32)
# 342 tf.Tensor(118.92891, shape=(), dtype=float32)
# 343 tf.Tensor(119.09235, shape=(), dtype=float32)
# 344 tf.Tensor(119.57962, shape=(), dtype=float32)
# 345 tf.Tensor(119.862335, shape=(), dtype=float32)
# 346 tf.Tensor(120.077286, shape=(), dtype=float32)
# 347 tf.Tensor(120.48169, shape=(), dtype=float32)
# 348 tf.Tensor(120.904205, shape=(), dtype=float32)
# 349 tf.Tensor(121.26622, shape=(), dtype=float32)
# 350 tf.Tensor(121.64327, shape=(), dtype=float32)
# 351 tf.Tensor(121.80561, shape=(), dtype=float32)
# 352 tf.Tensor(122.03564, shape=(), dtype=float32)
# 353 tf.Tensor(122.06576, shape=(), dtype=float32)
# 354 tf.Tensor(122.10143, shape=(), dtype=float32)
# 355 tf.Tensor(122.193306, shape=(), dtype=float32)
# 356 tf.Tensor(122.325226, shape=(), dtype=float32)
# 357 tf.Tensor(122.72691, shape=(), dtype=float32)
# 358 tf.Tensor(123.208405, shape=(), dtype=float32)
# 359 tf.Tensor(123.45297, shape=(), dtype=float32)
# 360 tf.Tensor(123.61515, shape=(), dtype=float32)
# 361 tf.Tensor(123.95548, shape=(), dtype=float32)
# 362 tf.Tensor(124.46682, shape=(), dtype=float32)
# 363 tf.Tensor(125.07678, shape=(), dtype=float32)
# 364 tf.Tensor(125.69013, shape=(), dtype=float32)
# 365 tf.Tensor(126.2492, shape=(), dtype=float32)
# 366 tf.Tensor(126.463486, shape=(), dtype=float32)
# 367 tf.Tensor(126.98651, shape=(), dtype=float32)
# 368 tf.Tensor(127.28161, shape=(), dtype=float32)
# 369 tf.Tensor(127.6354, shape=(), dtype=float32)
# 370 tf.Tensor(128.14537, shape=(), dtype=float32)
# 371 tf.Tensor(128.26163, shape=(), dtype=float32)
# 372 tf.Tensor(128.64778, shape=(), dtype=float32)
# 373 tf.Tensor(128.76506, shape=(), dtype=float32)
# 374 tf.Tensor(129.24144, shape=(), dtype=float32)
# 375 tf.Tensor(129.27118, shape=(), dtype=float32)
# 376 tf.Tensor(129.52806, shape=(), dtype=float32)
# 377 tf.Tensor(130.02356, shape=(), dtype=float32)
# 378 tf.Tensor(130.44917, shape=(), dtype=float32)
# 379 tf.Tensor(130.44936, shape=(), dtype=float32)
# 380 tf.Tensor(131.20143, shape=(), dtype=float32)
# 381 tf.Tensor(131.58723, shape=(), dtype=float32)
# 382 tf.Tensor(131.7258, shape=(), dtype=float32)
# 383 tf.Tensor(131.72775, shape=(), dtype=float32)
# 384 tf.Tensor(131.89284, shape=(), dtype=float32)
# 385 tf.Tensor(132.28941, shape=(), dtype=float32)
# 386 tf.Tensor(132.682, shape=(), dtype=float32)
# 387 tf.Tensor(133.2048, shape=(), dtype=float32)
# 388 tf.Tensor(133.83894, shape=(), dtype=float32)
# 389 tf.Tensor(134.29712, shape=(), dtype=float32)
# 390 tf.Tensor(134.60043, shape=(), dtype=float32)
# 391 tf.Tensor(135.0241, shape=(), dtype=float32)
# 392 tf.Tensor(135.44144, shape=(), dtype=float32)
# 393 tf.Tensor(136.00703, shape=(), dtype=float32)
# 394 tf.Tensor(136.39815, shape=(), dtype=float32)
# 395 tf.Tensor(136.69312, shape=(), dtype=float32)
# 396 tf.Tensor(137.0016, shape=(), dtype=float32)
# 397 tf.Tensor(137.31503, shape=(), dtype=float32)
# 398 tf.Tensor(137.47937, shape=(), dtype=float32)
# 399 tf.Tensor(138.22607, shape=(), dtype=float32)
# 400 tf.Tensor(138.41168, shape=(), dtype=float32)
# 401 tf.Tensor(138.80789, shape=(), dtype=float32)
# 402 tf.Tensor(139.00662, shape=(), dtype=float32)
# 403 tf.Tensor(139.12352, shape=(), dtype=float32)
# 404 tf.Tensor(139.7762, shape=(), dtype=float32)
# 405 tf.Tensor(140.24867, shape=(), dtype=float32)
# 406 tf.Tensor(140.64836, shape=(), dtype=float32)
# 407 tf.Tensor(140.73048, shape=(), dtype=float32)
# 408 tf.Tensor(141.08755, shape=(), dtype=float32)
# 409 tf.Tensor(141.47836, shape=(), dtype=float32)
# 410 tf.Tensor(141.93716, shape=(), dtype=float32)
# 411 tf.Tensor(142.7225, shape=(), dtype=float32)
# 412 tf.Tensor(142.9813, shape=(), dtype=float32)
# 413 tf.Tensor(143.04697, shape=(), dtype=float32)
# 414 tf.Tensor(143.4755, shape=(), dtype=float32)
# 415 tf.Tensor(143.94392, shape=(), dtype=float32)
# 416 tf.Tensor(144.50867, shape=(), dtype=float32)
# 417 tf.Tensor(144.7314, shape=(), dtype=float32)
# 418 tf.Tensor(144.96721, shape=(), dtype=float32)
# 419 tf.Tensor(144.96721, shape=(), dtype=float32)
# 420 tf.Tensor(145.19762, shape=(), dtype=float32)
# 421 tf.Tensor(145.53394, shape=(), dtype=float32)
# 422 tf.Tensor(145.65318, shape=(), dtype=float32)
# 423 tf.Tensor(145.77095, shape=(), dtype=float32)
# 424 tf.Tensor(146.20117, shape=(), dtype=float32)
# 425 tf.Tensor(146.59993, shape=(), dtype=float32)
# 426 tf.Tensor(146.70215, shape=(), dtype=float32)
# 427 tf.Tensor(146.73506, shape=(), dtype=float32)
# 428 tf.Tensor(147.0233, shape=(), dtype=float32)
# 429 tf.Tensor(147.15512, shape=(), dtype=float32)
# 430 tf.Tensor(147.48952, shape=(), dtype=float32)
# 431 tf.Tensor(147.76614, shape=(), dtype=float32)
# 432 tf.Tensor(148.45096, shape=(), dtype=float32)
# 433 tf.Tensor(148.81636, shape=(), dtype=float32)
# 434 tf.Tensor(149.2909, shape=(), dtype=float32)
# 435 tf.Tensor(149.65115, shape=(), dtype=float32)
# 436 tf.Tensor(149.92876, shape=(), dtype=float32)
# 437 tf.Tensor(150.17073, shape=(), dtype=float32)
# 438 tf.Tensor(150.49449, shape=(), dtype=float32)
# 439 tf.Tensor(150.72137, shape=(), dtype=float32)
# 440 tf.Tensor(150.95824, shape=(), dtype=float32)
# 441 tf.Tensor(151.91646, shape=(), dtype=float32)
# 442 tf.Tensor(152.05293, shape=(), dtype=float32)
# 443 tf.Tensor(152.6333, shape=(), dtype=float32)
# 444 tf.Tensor(153.20805, shape=(), dtype=float32)
# 445 tf.Tensor(153.35945, shape=(), dtype=float32)
# 446 tf.Tensor(153.77371, shape=(), dtype=float32)
# 447 tf.Tensor(154.17474, shape=(), dtype=float32)
# 448 tf.Tensor(154.40617, shape=(), dtype=float32)
# 449 tf.Tensor(154.63824, shape=(), dtype=float32)
# 450 tf.Tensor(155.34445, shape=(), dtype=float32)
# 451 tf.Tensor(155.45258, shape=(), dtype=float32)
# 452 tf.Tensor(155.66232, shape=(), dtype=float32)
# 453 tf.Tensor(155.97589, shape=(), dtype=float32)
# 454 tf.Tensor(156.54991, shape=(), dtype=float32)
# 455 tf.Tensor(157.04541, shape=(), dtype=float32)
# 456 tf.Tensor(157.49121, shape=(), dtype=float32)
# 457 tf.Tensor(158.11153, shape=(), dtype=float32)
# 458 tf.Tensor(158.39088, shape=(), dtype=float32)
# 459 tf.Tensor(159.24144, shape=(), dtype=float32)
# 460 tf.Tensor(159.25522, shape=(), dtype=float32)
# 461 tf.Tensor(159.5952, shape=(), dtype=float32)
# 462 tf.Tensor(159.68964, shape=(), dtype=float32)
# 463 tf.Tensor(160.10092, shape=(), dtype=float32)
# 464 tf.Tensor(160.44756, shape=(), dtype=float32)
# 465 tf.Tensor(160.92734, shape=(), dtype=float32)
# 466 tf.Tensor(161.5212, shape=(), dtype=float32)
# 467 tf.Tensor(162.01292, shape=(), dtype=float32)
# 468 tf.Tensor(162.3857, shape=(), dtype=float32)
# 469 tf.Tensor(162.48694, shape=(), dtype=float32)
# 470 tf.Tensor(162.49341, shape=(), dtype=float32)
# 471 tf.Tensor(162.60838, shape=(), dtype=float32)
# 472 tf.Tensor(162.74709, shape=(), dtype=float32)
# 473 tf.Tensor(163.20184, shape=(), dtype=float32)
# 474 tf.Tensor(163.6286, shape=(), dtype=float32)
# 475 tf.Tensor(163.82472, shape=(), dtype=float32)
# 476 tf.Tensor(163.95425, shape=(), dtype=float32)
# 477 tf.Tensor(164.26505, shape=(), dtype=float32)
# 478 tf.Tensor(164.41437, shape=(), dtype=float32)
# 479 tf.Tensor(164.87033, shape=(), dtype=float32)
# 480 tf.Tensor(165.23047, shape=(), dtype=float32)
# 481 tf.Tensor(165.63885, shape=(), dtype=float32)
# 482 tf.Tensor(166.12498, shape=(), dtype=float32)
# 483 tf.Tensor(166.5271, shape=(), dtype=float32)
# 484 tf.Tensor(166.5963, shape=(), dtype=float32)
# 485 tf.Tensor(166.7644, shape=(), dtype=float32)
# 486 tf.Tensor(167.05418, shape=(), dtype=float32)
# 487 tf.Tensor(167.1887, shape=(), dtype=float32)
# 488 tf.Tensor(167.18878, shape=(), dtype=float32)
# 489 tf.Tensor(167.61617, shape=(), dtype=float32)
# 490 tf.Tensor(167.82224, shape=(), dtype=float32)
# 491 tf.Tensor(168.25099, shape=(), dtype=float32)
# 492 tf.Tensor(168.45436, shape=(), dtype=float32)
# 493 tf.Tensor(168.63759, shape=(), dtype=float32)
# 494 tf.Tensor(168.82628, shape=(), dtype=float32)
# 495 tf.Tensor(169.17656, shape=(), dtype=float32)
# 496 tf.Tensor(169.8415, shape=(), dtype=float32)
# 497 tf.Tensor(170.22643, shape=(), dtype=float32)
# 498 tf.Tensor(170.38237, shape=(), dtype=float32)
# 499 tf.Tensor(170.4033, shape=(), dtype=float32)
# 500 tf.Tensor(170.766, shape=(), dtype=float32)
# 501 tf.Tensor(171.45757, shape=(), dtype=float32)
# 502 tf.Tensor(171.82907, shape=(), dtype=float32)
# 503 tf.Tensor(172.18675, shape=(), dtype=float32)
# 504 tf.Tensor(172.61043, shape=(), dtype=float32)
# 505 tf.Tensor(173.1282, shape=(), dtype=float32)
# 506 tf.Tensor(173.2054, shape=(), dtype=float32)
# 507 tf.Tensor(173.60265, shape=(), dtype=float32)
# 508 tf.Tensor(174.08754, shape=(), dtype=float32)
# 509 tf.Tensor(174.35333, shape=(), dtype=float32)
# 510 tf.Tensor(174.50182, shape=(), dtype=float32)
# 511 tf.Tensor(174.91006, shape=(), dtype=float32)
# 512 tf.Tensor(175.26082, shape=(), dtype=float32)
# 513 tf.Tensor(175.81113, shape=(), dtype=float32)
# 514 tf.Tensor(176.15799, shape=(), dtype=float32)
# 515 tf.Tensor(176.6695, shape=(), dtype=float32)
# 516 tf.Tensor(177.0699, shape=(), dtype=float32)
# 517 tf.Tensor(177.16048, shape=(), dtype=float32)
# 518 tf.Tensor(177.41525, shape=(), dtype=float32)
# 519 tf.Tensor(178.17548, shape=(), dtype=float32)
# 520 tf.Tensor(178.43246, shape=(), dtype=float32)
# 521 tf.Tensor(178.47038, shape=(), dtype=float32)
# 522 tf.Tensor(178.56187, shape=(), dtype=float32)
# 523 tf.Tensor(178.94759, shape=(), dtype=float32)
# 524 tf.Tensor(179.11047, shape=(), dtype=float32)
# 525 tf.Tensor(179.3279, shape=(), dtype=float32)
# 526 tf.Tensor(179.91257, shape=(), dtype=float32)
# 527 tf.Tensor(180.38641, shape=(), dtype=float32)
# 528 tf.Tensor(181.0028, shape=(), dtype=float32)
# 529 tf.Tensor(181.57501, shape=(), dtype=float32)
# 530 tf.Tensor(181.5778, shape=(), dtype=float32)
# 531 tf.Tensor(182.12434, shape=(), dtype=float32)
# 532 tf.Tensor(182.38828, shape=(), dtype=float32)
# 533 tf.Tensor(182.81662, shape=(), dtype=float32)
# 534 tf.Tensor(183.50134, shape=(), dtype=float32)
# 535 tf.Tensor(184.23538, shape=(), dtype=float32)
# 536 tf.Tensor(184.99768, shape=(), dtype=float32)
# 537 tf.Tensor(185.06888, shape=(), dtype=float32)
# 538 tf.Tensor(185.07014, shape=(), dtype=float32)
# 539 tf.Tensor(185.1015, shape=(), dtype=float32)
# 540 tf.Tensor(185.42958, shape=(), dtype=float32)
# 541 tf.Tensor(185.73805, shape=(), dtype=float32)
# 542 tf.Tensor(186.07845, shape=(), dtype=float32)
# 543 tf.Tensor(186.551, shape=(), dtype=float32)
# 544 tf.Tensor(186.63217, shape=(), dtype=float32)
# 545 tf.Tensor(186.73378, shape=(), dtype=float32)
# 546 tf.Tensor(186.86787, shape=(), dtype=float32)
# 547 tf.Tensor(187.40396, shape=(), dtype=float32)
# 548 tf.Tensor(187.7599, shape=(), dtype=float32)
# 549 tf.Tensor(188.06786, shape=(), dtype=float32)
# 550 tf.Tensor(188.40323, shape=(), dtype=float32)
# 551 tf.Tensor(188.65509, shape=(), dtype=float32)
# 552 tf.Tensor(189.24612, shape=(), dtype=float32)
# 553 tf.Tensor(189.78273, shape=(), dtype=float32)
# 554 tf.Tensor(190.35898, shape=(), dtype=float32)
# 555 tf.Tensor(191.20172, shape=(), dtype=float32)
# 556 tf.Tensor(191.54276, shape=(), dtype=float32)
# 557 tf.Tensor(191.54277, shape=(), dtype=float32)
# 558 tf.Tensor(192.19418, shape=(), dtype=float32)
# 559 tf.Tensor(192.59862, shape=(), dtype=float32)
# 560 tf.Tensor(192.97063, shape=(), dtype=float32)
# 561 tf.Tensor(193.09558, shape=(), dtype=float32)
# 562 tf.Tensor(193.33565, shape=(), dtype=float32)
# 563 tf.Tensor(193.74725, shape=(), dtype=float32)
# 564 tf.Tensor(193.91902, shape=(), dtype=float32)
# 565 tf.Tensor(193.93657, shape=(), dtype=float32)
# 566 tf.Tensor(194.40178, shape=(), dtype=float32)
# 567 tf.Tensor(195.0553, shape=(), dtype=float32)
# 568 tf.Tensor(195.55313, shape=(), dtype=float32)
# 569 tf.Tensor(196.35548, shape=(), dtype=float32)
# 570 tf.Tensor(196.75404, shape=(), dtype=float32)
# 571 tf.Tensor(197.44226, shape=(), dtype=float32)
# 572 tf.Tensor(197.9081, shape=(), dtype=float32)
# 573 tf.Tensor(198.01344, shape=(), dtype=float32)
# 574 tf.Tensor(198.1625, shape=(), dtype=float32)
# 575 tf.Tensor(198.29977, shape=(), dtype=float32)
# 576 tf.Tensor(198.57014, shape=(), dtype=float32)
# 577 tf.Tensor(199.154, shape=(), dtype=float32)
# 578 tf.Tensor(199.5394, shape=(), dtype=float32)
# 579 tf.Tensor(199.93614, shape=(), dtype=float32)
# 580 tf.Tensor(200.13037, shape=(), dtype=float32)
# 581 tf.Tensor(200.20483, shape=(), dtype=float32)
# 582 tf.Tensor(200.31622, shape=(), dtype=float32)
# 583 tf.Tensor(200.98907, shape=(), dtype=float32)
# 584 tf.Tensor(201.00226, shape=(), dtype=float32)
# 585 tf.Tensor(201.28886, shape=(), dtype=float32)
# 586 tf.Tensor(201.3228, shape=(), dtype=float32)
# 587 tf.Tensor(201.48619, shape=(), dtype=float32)
# 588 tf.Tensor(201.54895, shape=(), dtype=float32)
# 589 tf.Tensor(201.67203, shape=(), dtype=float32)
# 590 tf.Tensor(202.33652, shape=(), dtype=float32)
# 591 tf.Tensor(202.6726, shape=(), dtype=float32)
# 592 tf.Tensor(202.98958, shape=(), dtype=float32)
# 593 tf.Tensor(202.98997, shape=(), dtype=float32)
# 594 tf.Tensor(203.3123, shape=(), dtype=float32)
# 595 tf.Tensor(203.91481, shape=(), dtype=float32)
# 596 tf.Tensor(204.10495, shape=(), dtype=float32)
# 597 tf.Tensor(204.24538, shape=(), dtype=float32)
# 598 tf.Tensor(204.61873, shape=(), dtype=float32)
# 599 tf.Tensor(205.19737, shape=(), dtype=float32)
# 600 tf.Tensor(205.77159, shape=(), dtype=float32)
# 601 tf.Tensor(206.25984, shape=(), dtype=float32)
# 602 tf.Tensor(206.26445, shape=(), dtype=float32)
# 603 tf.Tensor(206.54543, shape=(), dtype=float32)
# 604 tf.Tensor(207.02072, shape=(), dtype=float32)
# 605 tf.Tensor(207.35626, shape=(), dtype=float32)
# 606 tf.Tensor(207.83301, shape=(), dtype=float32)
# 607 tf.Tensor(208.22696, shape=(), dtype=float32)
# 608 tf.Tensor(208.76036, shape=(), dtype=float32)
# 609 tf.Tensor(208.93655, shape=(), dtype=float32)
# 610 tf.Tensor(209.02672, shape=(), dtype=float32)
# 611 tf.Tensor(209.4466, shape=(), dtype=float32)
# 612 tf.Tensor(209.55696, shape=(), dtype=float32)
# 613 tf.Tensor(210.0169, shape=(), dtype=float32)
# 614 tf.Tensor(210.38521, shape=(), dtype=float32)
# 615 tf.Tensor(210.7894, shape=(), dtype=float32)
# 616 tf.Tensor(211.29709, shape=(), dtype=float32)
# 617 tf.Tensor(211.54796, shape=(), dtype=float32)
# 618 tf.Tensor(212.29099, shape=(), dtype=float32)
# 619 tf.Tensor(212.72104, shape=(), dtype=float32)
# 620 tf.Tensor(213.0881, shape=(), dtype=float32)
# 621 tf.Tensor(213.35068, shape=(), dtype=float32)
# 622 tf.Tensor(213.74898, shape=(), dtype=float32)
# 623 tf.Tensor(214.07077, shape=(), dtype=float32)
# 624 tf.Tensor(214.24889, shape=(), dtype=float32)
# 625 tf.Tensor(214.79309, shape=(), dtype=float32)
# 626 tf.Tensor(215.47173, shape=(), dtype=float32)
# 627 tf.Tensor(215.82408, shape=(), dtype=float32)
# 628 tf.Tensor(216.18503, shape=(), dtype=float32)
# 629 tf.Tensor(216.18503, shape=(), dtype=float32)
# 630 tf.Tensor(216.81886, shape=(), dtype=float32)
# 631 tf.Tensor(216.81926, shape=(), dtype=float32)
# 632 tf.Tensor(217.04854, shape=(), dtype=float32)
# 633 tf.Tensor(217.43547, shape=(), dtype=float32)
# 634 tf.Tensor(217.98247, shape=(), dtype=float32)
# 635 tf.Tensor(218.33714, shape=(), dtype=float32)
# 636 tf.Tensor(218.73863, shape=(), dtype=float32)
# 637 tf.Tensor(218.97455, shape=(), dtype=float32)
# 638 tf.Tensor(219.04897, shape=(), dtype=float32)
# 639 tf.Tensor(219.5368, shape=(), dtype=float32)
# 640 tf.Tensor(219.7814, shape=(), dtype=float32)
# 641 tf.Tensor(219.88165, shape=(), dtype=float32)
# 642 tf.Tensor(219.88194, shape=(), dtype=float32)
# 643 tf.Tensor(219.95978, shape=(), dtype=float32)
# 644 tf.Tensor(220.42412, shape=(), dtype=float32)
# 645 tf.Tensor(220.99977, shape=(), dtype=float32)
# 646 tf.Tensor(221.71263, shape=(), dtype=float32)
# 647 tf.Tensor(221.91298, shape=(), dtype=float32)
# 648 tf.Tensor(222.28557, shape=(), dtype=float32)
# 649 tf.Tensor(223.03308, shape=(), dtype=float32)
# 650 tf.Tensor(223.62984, shape=(), dtype=float32)
# 651 tf.Tensor(224.16946, shape=(), dtype=float32)
# 652 tf.Tensor(224.51225, shape=(), dtype=float32)
# 653 tf.Tensor(224.70288, shape=(), dtype=float32)
# 654 tf.Tensor(225.14503, shape=(), dtype=float32)
# 655 tf.Tensor(225.63747, shape=(), dtype=float32)
# 656 tf.Tensor(225.832, shape=(), dtype=float32)
# 657 tf.Tensor(226.15463, shape=(), dtype=float32)
# 658 tf.Tensor(226.82426, shape=(), dtype=float32)
# 659 tf.Tensor(227.08101, shape=(), dtype=float32)
# 660 tf.Tensor(227.39719, shape=(), dtype=float32)
# 661 tf.Tensor(227.677, shape=(), dtype=float32)
# 662 tf.Tensor(227.69174, shape=(), dtype=float32)
# 663 tf.Tensor(228.32826, shape=(), dtype=float32)
# 664 tf.Tensor(228.71236, shape=(), dtype=float32)
# 665 tf.Tensor(229.28143, shape=(), dtype=float32)
# 666 tf.Tensor(230.10663, shape=(), dtype=float32)
# 667 tf.Tensor(230.36061, shape=(), dtype=float32)
# 668 tf.Tensor(230.68576, shape=(), dtype=float32)
# 669 tf.Tensor(231.10457, shape=(), dtype=float32)
# 670 tf.Tensor(231.37723, shape=(), dtype=float32)
# 671 tf.Tensor(231.50015, shape=(), dtype=float32)
# 672 tf.Tensor(231.8477, shape=(), dtype=float32)
# 673 tf.Tensor(232.25545, shape=(), dtype=float32)
# 674 tf.Tensor(232.65947, shape=(), dtype=float32)
# 675 tf.Tensor(232.84615, shape=(), dtype=float32)
# 676 tf.Tensor(233.22057, shape=(), dtype=float32)
# 677 tf.Tensor(233.29251, shape=(), dtype=float32)
# 678 tf.Tensor(233.65314, shape=(), dtype=float32)
# 679 tf.Tensor(233.6994, shape=(), dtype=float32)
# 680 tf.Tensor(233.746, shape=(), dtype=float32)
# 681 tf.Tensor(234.21883, shape=(), dtype=float32)
# 682 tf.Tensor(234.55388, shape=(), dtype=float32)
# 683 tf.Tensor(234.76881, shape=(), dtype=float32)
# 684 tf.Tensor(235.37373, shape=(), dtype=float32)
# 685 tf.Tensor(235.77188, shape=(), dtype=float32)
# 686 tf.Tensor(236.36961, shape=(), dtype=float32)
# 687 tf.Tensor(236.39851, shape=(), dtype=float32)
# 688 tf.Tensor(236.82904, shape=(), dtype=float32)
# 689 tf.Tensor(237.4249, shape=(), dtype=float32)
# 690 tf.Tensor(237.75542, shape=(), dtype=float32)
# 691 tf.Tensor(238.47275, shape=(), dtype=float32)
# 692 tf.Tensor(238.52809, shape=(), dtype=float32)
# 693 tf.Tensor(239.05923, shape=(), dtype=float32)
# 694 tf.Tensor(239.83662, shape=(), dtype=float32)
# 695 tf.Tensor(240.40175, shape=(), dtype=float32)
# 696 tf.Tensor(241.05737, shape=(), dtype=float32)
# 697 tf.Tensor(241.16232, shape=(), dtype=float32)
# 698 tf.Tensor(241.86192, shape=(), dtype=float32)
# 699 tf.Tensor(241.87863, shape=(), dtype=float32)
# 700 tf.Tensor(242.68526, shape=(), dtype=float32)
# 701 tf.Tensor(243.3152, shape=(), dtype=float32)
# 702 tf.Tensor(243.64255, shape=(), dtype=float32)
# 703 tf.Tensor(243.88965, shape=(), dtype=float32)
# 704 tf.Tensor(243.99763, shape=(), dtype=float32)
# 705 tf.Tensor(244.03064, shape=(), dtype=float32)
# 706 tf.Tensor(244.49162, shape=(), dtype=float32)
# 707 tf.Tensor(244.9845, shape=(), dtype=float32)
# 708 tf.Tensor(245.15213, shape=(), dtype=float32)
# 709 tf.Tensor(245.29433, shape=(), dtype=float32)
# 710 tf.Tensor(245.61598, shape=(), dtype=float32)
# 711 tf.Tensor(246.18561, shape=(), dtype=float32)
# 712 tf.Tensor(246.74295, shape=(), dtype=float32)
# 713 tf.Tensor(247.1288, shape=(), dtype=float32)
# 714 tf.Tensor(247.59929, shape=(), dtype=float32)
# 715 tf.Tensor(248.08104, shape=(), dtype=float32)
# 716 tf.Tensor(248.15042, shape=(), dtype=float32)
# 717 tf.Tensor(248.5699, shape=(), dtype=float32)
# 718 tf.Tensor(249.25282, shape=(), dtype=float32)
# 719 tf.Tensor(249.3541, shape=(), dtype=float32)
# 720 tf.Tensor(249.64491, shape=(), dtype=float32)
# 721 tf.Tensor(249.93347, shape=(), dtype=float32)
# 722 tf.Tensor(250.48506, shape=(), dtype=float32)
# 723 tf.Tensor(250.7698, shape=(), dtype=float32)
# 724 tf.Tensor(250.80597, shape=(), dtype=float32)
# 725 tf.Tensor(250.93233, shape=(), dtype=float32)
# 726 tf.Tensor(251.50737, shape=(), dtype=float32)
# 727 tf.Tensor(251.79932, shape=(), dtype=float32)
# 728 tf.Tensor(251.87056, shape=(), dtype=float32)
# 729 tf.Tensor(252.1595, shape=(), dtype=float32)
# 730 tf.Tensor(252.30495, shape=(), dtype=float32)
# 731 tf.Tensor(252.81155, shape=(), dtype=float32)
# 732 tf.Tensor(253.11816, shape=(), dtype=float32)
# 733 tf.Tensor(253.18152, shape=(), dtype=float32)
# 734 tf.Tensor(253.21744, shape=(), dtype=float32)
# 735 tf.Tensor(253.4922, shape=(), dtype=float32)
# 736 tf.Tensor(253.95062, shape=(), dtype=float32)
# 737 tf.Tensor(254.13693, shape=(), dtype=float32)
# 738 tf.Tensor(254.40286, shape=(), dtype=float32)
# 739 tf.Tensor(254.70512, shape=(), dtype=float32)
# 740 tf.Tensor(255.22017, shape=(), dtype=float32)
# 741 tf.Tensor(255.31401, shape=(), dtype=float32)
# 742 tf.Tensor(255.57034, shape=(), dtype=float32)
# 743 tf.Tensor(255.74095, shape=(), dtype=float32)
# 744 tf.Tensor(256.11465, shape=(), dtype=float32)
# 745 tf.Tensor(256.47464, shape=(), dtype=float32)
# 746 tf.Tensor(256.79257, shape=(), dtype=float32)
# 747 tf.Tensor(257.33612, shape=(), dtype=float32)
# 748 tf.Tensor(257.70273, shape=(), dtype=float32)
# 749 tf.Tensor(257.80585, shape=(), dtype=float32)
# 750 tf.Tensor(258.33313, shape=(), dtype=float32)
# 751 tf.Tensor(258.6039, shape=(), dtype=float32)
# 752 tf.Tensor(259.15793, shape=(), dtype=float32)
# 753 tf.Tensor(259.50894, shape=(), dtype=float32)
# 754 tf.Tensor(259.57648, shape=(), dtype=float32)
# 755 tf.Tensor(260.23563, shape=(), dtype=float32)
# 756 tf.Tensor(260.86893, shape=(), dtype=float32)
# 757 tf.Tensor(260.97888, shape=(), dtype=float32)
# 758 tf.Tensor(261.4002, shape=(), dtype=float32)
# 759 tf.Tensor(262.05774, shape=(), dtype=float32)
# 760 tf.Tensor(262.2325, shape=(), dtype=float32)
# 761 tf.Tensor(262.65936, shape=(), dtype=float32)
# 762 tf.Tensor(262.72305, shape=(), dtype=float32)
# 763 tf.Tensor(262.81616, shape=(), dtype=float32)
# 764 tf.Tensor(263.18884, shape=(), dtype=float32)
# 765 tf.Tensor(263.91806, shape=(), dtype=float32)
# 766 tf.Tensor(264.108, shape=(), dtype=float32)
# 767 tf.Tensor(264.3347, shape=(), dtype=float32)
# 768 tf.Tensor(264.97516, shape=(), dtype=float32)
# 769 tf.Tensor(264.9753, shape=(), dtype=float32)
# 770 tf.Tensor(265.654, shape=(), dtype=float32)
# 771 tf.Tensor(266.01428, shape=(), dtype=float32)
# 772 tf.Tensor(266.30264, shape=(), dtype=float32)
# 773 tf.Tensor(266.55997, shape=(), dtype=float32)
# 774 tf.Tensor(266.87015, shape=(), dtype=float32)
# 775 tf.Tensor(266.93683, shape=(), dtype=float32)
# 776 tf.Tensor(267.27243, shape=(), dtype=float32)
# 777 tf.Tensor(267.58588, shape=(), dtype=float32)
# 778 tf.Tensor(267.9457, shape=(), dtype=float32)
# 779 tf.Tensor(268.62555, shape=(), dtype=float32)
# 780 tf.Tensor(268.89883, shape=(), dtype=float32)
# 781 tf.Tensor(269.35843, shape=(), dtype=float32)
# 782 tf.Tensor(269.79068, shape=(), dtype=float32)
# 783 tf.Tensor(270.54803, shape=(), dtype=float32)
# 784 tf.Tensor(270.76816, shape=(), dtype=float32)
# 785 tf.Tensor(270.9726, shape=(), dtype=float32)
# 786 tf.Tensor(271.3622, shape=(), dtype=float32)
# 787 tf.Tensor(271.46692, shape=(), dtype=float32)
# 788 tf.Tensor(272.08688, shape=(), dtype=float32)
# 789 tf.Tensor(272.27774, shape=(), dtype=float32)
# 790 tf.Tensor(272.36432, shape=(), dtype=float32)
# 791 tf.Tensor(272.55005, shape=(), dtype=float32)
# 792 tf.Tensor(272.73166, shape=(), dtype=float32)
# 793 tf.Tensor(273.16605, shape=(), dtype=float32)
# 794 tf.Tensor(273.6159, shape=(), dtype=float32)
# 795 tf.Tensor(273.70786, shape=(), dtype=float32)
# 796 tf.Tensor(274.0813, shape=(), dtype=float32)
# 797 tf.Tensor(274.15292, shape=(), dtype=float32)
# 798 tf.Tensor(274.56476, shape=(), dtype=float32)
# 799 tf.Tensor(274.63098, shape=(), dtype=float32)
# 800 tf.Tensor(274.99356, shape=(), dtype=float32)
# 801 tf.Tensor(275.82712, shape=(), dtype=float32)
# 802 tf.Tensor(276.04675, shape=(), dtype=float32)
# 803 tf.Tensor(276.316, shape=(), dtype=float32)
# 804 tf.Tensor(276.52887, shape=(), dtype=float32)
# 805 tf.Tensor(276.7981, shape=(), dtype=float32)
# 806 tf.Tensor(276.8675, shape=(), dtype=float32)
# 807 tf.Tensor(277.16174, shape=(), dtype=float32)
# 808 tf.Tensor(277.7303, shape=(), dtype=float32)
# 809 tf.Tensor(278.28363, shape=(), dtype=float32)
# 810 tf.Tensor(278.8775, shape=(), dtype=float32)
# 811 tf.Tensor(278.90213, shape=(), dtype=float32)
# 812 tf.Tensor(278.9099, shape=(), dtype=float32)
# 813 tf.Tensor(279.5675, shape=(), dtype=float32)
# 814 tf.Tensor(279.6042, shape=(), dtype=float32)
# 815 tf.Tensor(280.22647, shape=(), dtype=float32)
# 816 tf.Tensor(280.34836, shape=(), dtype=float32)
# 817 tf.Tensor(280.34836, shape=(), dtype=float32)
# 818 tf.Tensor(280.68536, shape=(), dtype=float32)
# 819 tf.Tensor(281.22546, shape=(), dtype=float32)
# 820 tf.Tensor(281.82166, shape=(), dtype=float32)
# 821 tf.Tensor(281.9151, shape=(), dtype=float32)
# 822 tf.Tensor(281.91565, shape=(), dtype=float32)
# 823 tf.Tensor(282.41357, shape=(), dtype=float32)
# 824 tf.Tensor(282.58362, shape=(), dtype=float32)
# 825 tf.Tensor(283.20193, shape=(), dtype=float32)
# 826 tf.Tensor(283.48935, shape=(), dtype=float32)
# 827 tf.Tensor(283.9921, shape=(), dtype=float32)
# 828 tf.Tensor(284.48267, shape=(), dtype=float32)
# 829 tf.Tensor(284.674, shape=(), dtype=float32)
# 830 tf.Tensor(285.0152, shape=(), dtype=float32)
# 831 tf.Tensor(285.49896, shape=(), dtype=float32)
# 832 tf.Tensor(285.95206, shape=(), dtype=float32)
# 833 tf.Tensor(286.66165, shape=(), dtype=float32)
# 834 tf.Tensor(287.16678, shape=(), dtype=float32)
# 835 tf.Tensor(287.49588, shape=(), dtype=float32)
# 836 tf.Tensor(287.66644, shape=(), dtype=float32)
# 837 tf.Tensor(288.20242, shape=(), dtype=float32)
# 838 tf.Tensor(288.77368, shape=(), dtype=float32)
# 839 tf.Tensor(289.3483, shape=(), dtype=float32)
# 840 tf.Tensor(289.60645, shape=(), dtype=float32)
# 841 tf.Tensor(289.75235, shape=(), dtype=float32)
# 842 tf.Tensor(289.7593, shape=(), dtype=float32)
# 843 tf.Tensor(290.5819, shape=(), dtype=float32)
# 844 tf.Tensor(290.94473, shape=(), dtype=float32)
# 845 tf.Tensor(291.25177, shape=(), dtype=float32)
# 846 tf.Tensor(291.67264, shape=(), dtype=float32)
# 847 tf.Tensor(292.22214, shape=(), dtype=float32)
# 848 tf.Tensor(292.24948, shape=(), dtype=float32)
# 849 tf.Tensor(292.2496, shape=(), dtype=float32)
# 850 tf.Tensor(292.3965, shape=(), dtype=float32)
# 851 tf.Tensor(292.73175, shape=(), dtype=float32)
# 852 tf.Tensor(292.9108, shape=(), dtype=float32)
# 853 tf.Tensor(293.52155, shape=(), dtype=float32)
# 854 tf.Tensor(293.60352, shape=(), dtype=float32)
# 855 tf.Tensor(294.02264, shape=(), dtype=float32)
# 856 tf.Tensor(294.4495, shape=(), dtype=float32)
# 857 tf.Tensor(295.10394, shape=(), dtype=float32)
# 858 tf.Tensor(295.5401, shape=(), dtype=float32)
# 859 tf.Tensor(295.9372, shape=(), dtype=float32)
# 860 tf.Tensor(296.28763, shape=(), dtype=float32)
# 861 tf.Tensor(296.63693, shape=(), dtype=float32)
# 862 tf.Tensor(296.64352, shape=(), dtype=float32)
# 863 tf.Tensor(296.64355, shape=(), dtype=float32)
# 864 tf.Tensor(297.3434, shape=(), dtype=float32)
# 865 tf.Tensor(297.79938, shape=(), dtype=float32)
# 866 tf.Tensor(298.15295, shape=(), dtype=float32)
# 867 tf.Tensor(298.5061, shape=(), dtype=float32)
# 868 tf.Tensor(299.0358, shape=(), dtype=float32)
# 869 tf.Tensor(299.26102, shape=(), dtype=float32)
# 870 tf.Tensor(299.5197, shape=(), dtype=float32)
# 871 tf.Tensor(300.3354, shape=(), dtype=float32)
# 872 tf.Tensor(300.6739, shape=(), dtype=float32)
# 873 tf.Tensor(301.05585, shape=(), dtype=float32)
# 874 tf.Tensor(301.6455, shape=(), dtype=float32)
# 875 tf.Tensor(301.91513, shape=(), dtype=float32)
# 876 tf.Tensor(302.1819, shape=(), dtype=float32)
# 877 tf.Tensor(302.38754, shape=(), dtype=float32)
# 878 tf.Tensor(302.67316, shape=(), dtype=float32)
# 879 tf.Tensor(303.05197, shape=(), dtype=float32)
# 880 tf.Tensor(303.57153, shape=(), dtype=float32)
# 881 tf.Tensor(303.64792, shape=(), dtype=float32)
# 882 tf.Tensor(303.98642, shape=(), dtype=float32)
# 883 tf.Tensor(304.30405, shape=(), dtype=float32)
# 884 tf.Tensor(304.58392, shape=(), dtype=float32)
# 885 tf.Tensor(304.92737, shape=(), dtype=float32)
# 886 tf.Tensor(305.26428, shape=(), dtype=float32)
# 887 tf.Tensor(305.6556, shape=(), dtype=float32)
# 888 tf.Tensor(306.10822, shape=(), dtype=float32)
# 889 tf.Tensor(306.14536, shape=(), dtype=float32)
# 890 tf.Tensor(306.47775, shape=(), dtype=float32)
# 891 tf.Tensor(306.955, shape=(), dtype=float32)
# 892 tf.Tensor(306.96088, shape=(), dtype=float32)
# 893 tf.Tensor(307.06445, shape=(), dtype=float32)
# 894 tf.Tensor(307.33353, shape=(), dtype=float32)
# 895 tf.Tensor(308.00986, shape=(), dtype=float32)
# 896 tf.Tensor(308.58765, shape=(), dtype=float32)
# 897 tf.Tensor(308.6937, shape=(), dtype=float32)
# 898 tf.Tensor(309.03998, shape=(), dtype=float32)
# 899 tf.Tensor(309.84683, shape=(), dtype=float32)
# 900 tf.Tensor(309.89526, shape=(), dtype=float32)
# 901 tf.Tensor(310.29025, shape=(), dtype=float32)
# 902 tf.Tensor(310.4094, shape=(), dtype=float32)
# 903 tf.Tensor(310.5164, shape=(), dtype=float32)
# 904 tf.Tensor(311.07208, shape=(), dtype=float32)
# 905 tf.Tensor(311.47635, shape=(), dtype=float32)
# 906 tf.Tensor(312.04596, shape=(), dtype=float32)
# 907 tf.Tensor(312.10028, shape=(), dtype=float32)
# 908 tf.Tensor(312.7968, shape=(), dtype=float32)
# 909 tf.Tensor(313.41248, shape=(), dtype=float32)
# 910 tf.Tensor(313.88116, shape=(), dtype=float32)
# 911 tf.Tensor(314.3015, shape=(), dtype=float32)
# 912 tf.Tensor(314.87125, shape=(), dtype=float32)
# 913 tf.Tensor(314.9335, shape=(), dtype=float32)
# 914 tf.Tensor(315.2003, shape=(), dtype=float32)
# 915 tf.Tensor(315.21698, shape=(), dtype=float32)
# 916 tf.Tensor(315.6234, shape=(), dtype=float32)
# 917 tf.Tensor(316.2641, shape=(), dtype=float32)
# 918 tf.Tensor(316.72324, shape=(), dtype=float32)
# 919 tf.Tensor(316.90656, shape=(), dtype=float32)
# 920 tf.Tensor(317.1072, shape=(), dtype=float32)
# 921 tf.Tensor(317.10858, shape=(), dtype=float32)
# 922 tf.Tensor(317.3139, shape=(), dtype=float32)
# 923 tf.Tensor(317.49933, shape=(), dtype=float32)
# 924 tf.Tensor(318.30435, shape=(), dtype=float32)
# 925 tf.Tensor(318.34686, shape=(), dtype=float32)
# 926 tf.Tensor(318.73022, shape=(), dtype=float32)
# 927 tf.Tensor(318.98682, shape=(), dtype=float32)
# 928 tf.Tensor(318.9919, shape=(), dtype=float32)
# 929 tf.Tensor(319.7698, shape=(), dtype=float32)
# 930 tf.Tensor(319.78583, shape=(), dtype=float32)
# 931 tf.Tensor(320.1396, shape=(), dtype=float32)
# 932 tf.Tensor(320.77985, shape=(), dtype=float32)
# 933 tf.Tensor(321.24353, shape=(), dtype=float32)
# 934 tf.Tensor(321.43912, shape=(), dtype=float32)
# 935 tf.Tensor(321.8997, shape=(), dtype=float32)
# 936 tf.Tensor(321.98563, shape=(), dtype=float32)
# 937 tf.Tensor(322.40466, shape=(), dtype=float32)
# 938 tf.Tensor(322.55814, shape=(), dtype=float32)
# 939 tf.Tensor(323.1861, shape=(), dtype=float32)
# 940 tf.Tensor(323.5428, shape=(), dtype=float32)
# 941 tf.Tensor(323.93304, shape=(), dtype=float32)
# 942 tf.Tensor(324.2772, shape=(), dtype=float32)
# 943 tf.Tensor(324.27942, shape=(), dtype=float32)
# 944 tf.Tensor(324.47903, shape=(), dtype=float32)
# 945 tf.Tensor(324.79947, shape=(), dtype=float32)
# 946 tf.Tensor(325.06833, shape=(), dtype=float32)
# 947 tf.Tensor(325.28348, shape=(), dtype=float32)
# 948 tf.Tensor(325.61838, shape=(), dtype=float32)
# 949 tf.Tensor(325.72324, shape=(), dtype=float32)
# 950 tf.Tensor(325.92, shape=(), dtype=float32)
# 951 tf.Tensor(326.38782, shape=(), dtype=float32)
# 952 tf.Tensor(326.56998, shape=(), dtype=float32)
# 953 tf.Tensor(327.04565, shape=(), dtype=float32)
# 954 tf.Tensor(327.79953, shape=(), dtype=float32)
# 955 tf.Tensor(328.06317, shape=(), dtype=float32)
# 956 tf.Tensor(328.18488, shape=(), dtype=float32)
# 957 tf.Tensor(328.2618, shape=(), dtype=float32)
# 958 tf.Tensor(328.28464, shape=(), dtype=float32)
# 959 tf.Tensor(328.40936, shape=(), dtype=float32)
# 960 tf.Tensor(329.0109, shape=(), dtype=float32)
# 961 tf.Tensor(329.13742, shape=(), dtype=float32)
# 962 tf.Tensor(329.73383, shape=(), dtype=float32)
# 963 tf.Tensor(330.40207, shape=(), dtype=float32)
# 964 tf.Tensor(330.86194, shape=(), dtype=float32)
# 965 tf.Tensor(331.00696, shape=(), dtype=float32)
# 966 tf.Tensor(331.277, shape=(), dtype=float32)
# ...
# 1676 tf.Tensor(570.5337, shape=(), dtype=float32)
# 1677 tf.Tensor(570.64825, shape=(), dtype=float32)
# 1678 tf.Tensor(571.0979, shape=(), dtype=float32)
# 1679 tf.Tensor(571.11127, shape=(), dtype=float32)
# 1680 tf.Tensor(571.12164, shape=(), dtype=float32)
# 1681 tf.Tensor(571.67554, shape=(), dtype=float32)
# 1682 tf.Tensor(572.0101, shape=(), dtype=float32)
# 1683 tf.Tensor(572.66797, shape=(), dtype=float32)
# 1684 tf.Tensor(573.0453, shape=(), dtype=float32)
# 1685 tf.Tensor(573.4961, shape=(), dtype=float32)
# 1686 tf.Tensor(574.07446, shape=(), dtype=float32)
# 1687 tf.Tensor(574.07495, shape=(), dtype=float32)
# 1688 tf.Tensor(574.33716, shape=(), dtype=float32)
# 1689 tf.Tensor(574.7521, shape=(), dtype=float32)
# 1690 tf.Tensor(575.1381, shape=(), dtype=float32)
# 1691 tf.Tensor(575.6477, shape=(), dtype=float32)
# 1692 tf.Tensor(575.674, shape=(), dtype=float32)
# 1693 tf.Tensor(575.8673, shape=(), dtype=float32)
# 1694 tf.Tensor(576.62274, shape=(), dtype=float32)
# 1695 tf.Tensor(577.09235, shape=(), dtype=float32)
# 1696 tf.Tensor(577.3541, shape=(), dtype=float32)
# 1697 tf.Tensor(577.8012, shape=(), dtype=float32)
# 1698 tf.Tensor(578.05066, shape=(), dtype=float32)
# 1699 tf.Tensor(578.571, shape=(), dtype=float32)
# 1700 tf.Tensor(578.89044, shape=(), dtype=float32)
# 1701 tf.Tensor(579.26746, shape=(), dtype=float32)
# 1702 tf.Tensor(579.82776, shape=(), dtype=float32)
# 1703 tf.Tensor(579.8856, shape=(), dtype=float32)
# 1704 tf.Tensor(580.24506, shape=(), dtype=float32)
# 1705 tf.Tensor(580.62256, shape=(), dtype=float32)
# 1706 tf.Tensor(580.9278, shape=(), dtype=float32)
# 1707 tf.Tensor(581.1369, shape=(), dtype=float32)
# 1708 tf.Tensor(581.69324, shape=(), dtype=float32)
# 1709 tf.Tensor(582.1704, shape=(), dtype=float32)
# 1710 tf.Tensor(582.6521, shape=(), dtype=float32)
# 1711 tf.Tensor(583.53827, shape=(), dtype=float32)
# 1712 tf.Tensor(583.64264, shape=(), dtype=float32)
# 1713 tf.Tensor(583.67126, shape=(), dtype=float32)
# 1714 tf.Tensor(584.162, shape=(), dtype=float32)
# 1715 tf.Tensor(584.1898, shape=(), dtype=float32)
# 1716 tf.Tensor(584.56067, shape=(), dtype=float32)
# 1717 tf.Tensor(585.30444, shape=(), dtype=float32)
# 1718 tf.Tensor(585.4212, shape=(), dtype=float32)
# 1719 tf.Tensor(585.64264, shape=(), dtype=float32)
# 1720 tf.Tensor(586.06726, shape=(), dtype=float32)
# 1721 tf.Tensor(586.6373, shape=(), dtype=float32)
# 1722 tf.Tensor(586.809, shape=(), dtype=float32)
# 1723 tf.Tensor(587.48627, shape=(), dtype=float32)
# 1724 tf.Tensor(587.52966, shape=(), dtype=float32)
# 1725 tf.Tensor(587.8541, shape=(), dtype=float32)
# 1726 tf.Tensor(588.1081, shape=(), dtype=float32)
# 1727 tf.Tensor(588.2567, shape=(), dtype=float32)
# 1728 tf.Tensor(588.57684, shape=(), dtype=float32)
# 1729 tf.Tensor(589.1386, shape=(), dtype=float32)
# 1730 tf.Tensor(589.6471, shape=(), dtype=float32)
# 1731 tf.Tensor(589.7293, shape=(), dtype=float32)
# 1732 tf.Tensor(589.94196, shape=(), dtype=float32)
# 1733 tf.Tensor(590.1221, shape=(), dtype=float32)
# 1734 tf.Tensor(590.66833, shape=(), dtype=float32)
# 1735 tf.Tensor(591.0454, shape=(), dtype=float32)
# 1736 tf.Tensor(591.5102, shape=(), dtype=float32)
# 1737 tf.Tensor(591.7425, shape=(), dtype=float32)
# 1738 tf.Tensor(592.03326, shape=(), dtype=float32)
# 1739 tf.Tensor(592.1761, shape=(), dtype=float32)
# 1740 tf.Tensor(592.54175, shape=(), dtype=float32)
# 1741 tf.Tensor(593.1769, shape=(), dtype=float32)
# 1742 tf.Tensor(593.416, shape=(), dtype=float32)
# 1743 tf.Tensor(593.59985, shape=(), dtype=float32)
# 1744 tf.Tensor(593.7961, shape=(), dtype=float32)
# 1745 tf.Tensor(593.9442, shape=(), dtype=float32)
# 1746 tf.Tensor(594.19666, shape=(), dtype=float32)
# 1747 tf.Tensor(594.78156, shape=(), dtype=float32)
# 1748 tf.Tensor(595.56854, shape=(), dtype=float32)
# 1749 tf.Tensor(595.88763, shape=(), dtype=float32)
# 1750 tf.Tensor(596.33704, shape=(), dtype=float32)
# 1751 tf.Tensor(596.47174, shape=(), dtype=float32)
# 1752 tf.Tensor(596.91504, shape=(), dtype=float32)
# 1753 tf.Tensor(597.3741, shape=(), dtype=float32)
# 1754 tf.Tensor(597.5219, shape=(), dtype=float32)
# 1755 tf.Tensor(597.64575, shape=(), dtype=float32)
# 1756 tf.Tensor(598.126, shape=(), dtype=float32)
# 1757 tf.Tensor(598.3381, shape=(), dtype=float32)
# 1758 tf.Tensor(598.5359, shape=(), dtype=float32)
# 1759 tf.Tensor(598.9075, shape=(), dtype=float32)
# 1760 tf.Tensor(599.6038, shape=(), dtype=float32)
# 1761 tf.Tensor(599.7342, shape=(), dtype=float32)
# 1762 tf.Tensor(599.9443, shape=(), dtype=float32)
# 1763 tf.Tensor(600.51764, shape=(), dtype=float32)
# 1764 tf.Tensor(600.969, shape=(), dtype=float32)
# 1765 tf.Tensor(601.5834, shape=(), dtype=float32)
# 1766 tf.Tensor(601.6992, shape=(), dtype=float32)
# 1767 tf.Tensor(601.8239, shape=(), dtype=float32)
# 1768 tf.Tensor(602.24976, shape=(), dtype=float32)
# 1769 tf.Tensor(602.8054, shape=(), dtype=float32)
# 1770 tf.Tensor(603.2565, shape=(), dtype=float32)
# 1771 tf.Tensor(603.54614, shape=(), dtype=float32)
# 1772 tf.Tensor(604.26587, shape=(), dtype=float32)
# 1773 tf.Tensor(604.79626, shape=(), dtype=float32)
# 1774 tf.Tensor(604.9379, shape=(), dtype=float32)
# 1775 tf.Tensor(605.203, shape=(), dtype=float32)
# 1776 tf.Tensor(605.62354, shape=(), dtype=float32)
# 1777 tf.Tensor(606.06506, shape=(), dtype=float32)
# 1778 tf.Tensor(606.1595, shape=(), dtype=float32)
# 1779 tf.Tensor(606.35785, shape=(), dtype=float32)
# 1780 tf.Tensor(607.1485, shape=(), dtype=float32)
# 1781 tf.Tensor(607.1488, shape=(), dtype=float32)
# 1782 tf.Tensor(607.60364, shape=(), dtype=float32)
# 1783 tf.Tensor(608.16815, shape=(), dtype=float32)
# 1784 tf.Tensor(608.65753, shape=(), dtype=float32)
# 1785 tf.Tensor(608.6813, shape=(), dtype=float32)
# 1786 tf.Tensor(608.84796, shape=(), dtype=float32)
# 1787 tf.Tensor(608.9436, shape=(), dtype=float32)
# 1788 tf.Tensor(609.3805, shape=(), dtype=float32)
# 1789 tf.Tensor(609.8776, shape=(), dtype=float32)
# 1790 tf.Tensor(610.09546, shape=(), dtype=float32)
# 1791 tf.Tensor(610.5018, shape=(), dtype=float32)
# 1792 tf.Tensor(610.68713, shape=(), dtype=float32)
# 1793 tf.Tensor(610.92096, shape=(), dtype=float32)
# 1794 tf.Tensor(611.6185, shape=(), dtype=float32)
# 1795 tf.Tensor(612.00464, shape=(), dtype=float32)
# 1796 tf.Tensor(612.42316, shape=(), dtype=float32)
# 1797 tf.Tensor(612.60144, shape=(), dtype=float32)
# 1798 tf.Tensor(612.8243, shape=(), dtype=float32)
# 1799 tf.Tensor(613.26306, shape=(), dtype=float32)
# 1800 tf.Tensor(613.637, shape=(), dtype=float32)
# 1801 tf.Tensor(613.9085, shape=(), dtype=float32)
# 1802 tf.Tensor(614.186, shape=(), dtype=float32)
# 1803 tf.Tensor(614.6878, shape=(), dtype=float32)
# 1804 tf.Tensor(614.8552, shape=(), dtype=float32)
# 1805 tf.Tensor(615.08673, shape=(), dtype=float32)
# 1806 tf.Tensor(615.5049, shape=(), dtype=float32)
# 1807 tf.Tensor(615.8069, shape=(), dtype=float32)
# 1808 tf.Tensor(615.9222, shape=(), dtype=float32)
# 1809 tf.Tensor(616.29346, shape=(), dtype=float32)
# 1810 tf.Tensor(616.39795, shape=(), dtype=float32)
# 1811 tf.Tensor(616.54785, shape=(), dtype=float32)
# 1812 tf.Tensor(616.7428, shape=(), dtype=float32)
# 1813 tf.Tensor(617.1504, shape=(), dtype=float32)
# 1814 tf.Tensor(617.1761, shape=(), dtype=float32)
# 1815 tf.Tensor(617.646, shape=(), dtype=float32)
# 1816 tf.Tensor(617.8774, shape=(), dtype=float32)
# 1817 tf.Tensor(618.4612, shape=(), dtype=float32)
# 1818 tf.Tensor(618.8883, shape=(), dtype=float32)
# 1819 tf.Tensor(619.4691, shape=(), dtype=float32)
# 1820 tf.Tensor(619.5046, shape=(), dtype=float32)
# 1821 tf.Tensor(619.94525, shape=(), dtype=float32)
# 1822 tf.Tensor(620.43274, shape=(), dtype=float32)
# 1823 tf.Tensor(620.8939, shape=(), dtype=float32)
# 1824 tf.Tensor(621.1628, shape=(), dtype=float32)
# 1825 tf.Tensor(621.4958, shape=(), dtype=float32)
# 1826 tf.Tensor(622.0512, shape=(), dtype=float32)
# 1827 tf.Tensor(622.1764, shape=(), dtype=float32)
# 1828 tf.Tensor(622.1805, shape=(), dtype=float32)
# 1829 tf.Tensor(623.13806, shape=(), dtype=float32)
# 1830 tf.Tensor(623.3184, shape=(), dtype=float32)
# 1831 tf.Tensor(623.4897, shape=(), dtype=float32)
# 1832 tf.Tensor(623.83246, shape=(), dtype=float32)
# 1833 tf.Tensor(624.15314, shape=(), dtype=float32)
# 1834 tf.Tensor(624.2769, shape=(), dtype=float32)
# 1835 tf.Tensor(624.9379, shape=(), dtype=float32)
# 1836 tf.Tensor(624.9853, shape=(), dtype=float32)
# 1837 tf.Tensor(625.29895, shape=(), dtype=float32)
# 1838 tf.Tensor(625.5152, shape=(), dtype=float32)
# 1839 tf.Tensor(626.08435, shape=(), dtype=float32)
# 1840 tf.Tensor(626.5567, shape=(), dtype=float32)
# 1841 tf.Tensor(626.5813, shape=(), dtype=float32)
# 1842 tf.Tensor(626.7807, shape=(), dtype=float32)
# 1843 tf.Tensor(627.1658, shape=(), dtype=float32)
# 1844 tf.Tensor(627.59015, shape=(), dtype=float32)
# 1845 tf.Tensor(628.1901, shape=(), dtype=float32)
# 1846 tf.Tensor(628.7644, shape=(), dtype=float32)
# 1847 tf.Tensor(629.0765, shape=(), dtype=float32)
# 1848 tf.Tensor(629.1608, shape=(), dtype=float32)
# 1849 tf.Tensor(629.16095, shape=(), dtype=float32)
# 1850 tf.Tensor(629.59973, shape=(), dtype=float32)
# 1851 tf.Tensor(629.9408, shape=(), dtype=float32)
# 1852 tf.Tensor(630.1538, shape=(), dtype=float32)
# 1853 tf.Tensor(630.3254, shape=(), dtype=float32)
# 1854 tf.Tensor(630.5055, shape=(), dtype=float32)
# 1855 tf.Tensor(631.0143, shape=(), dtype=float32)
# 1856 tf.Tensor(631.4893, shape=(), dtype=float32)
# 1857 tf.Tensor(631.5426, shape=(), dtype=float32)
# 1858 tf.Tensor(631.8602, shape=(), dtype=float32)
# 1859 tf.Tensor(632.2776, shape=(), dtype=float32)
# 1860 tf.Tensor(632.4087, shape=(), dtype=float32)
# 1861 tf.Tensor(632.97003, shape=(), dtype=float32)
# 1862 tf.Tensor(633.1619, shape=(), dtype=float32)
# 1863 tf.Tensor(633.5138, shape=(), dtype=float32)
# 1864 tf.Tensor(633.8922, shape=(), dtype=float32)
# 1865 tf.Tensor(634.31036, shape=(), dtype=float32)
# 1866 tf.Tensor(634.3132, shape=(), dtype=float32)
# 1867 tf.Tensor(634.6523, shape=(), dtype=float32)
# 1868 tf.Tensor(634.7904, shape=(), dtype=float32)
# 1869 tf.Tensor(635.1929, shape=(), dtype=float32)
# 1870 tf.Tensor(635.4117, shape=(), dtype=float32)
# 1871 tf.Tensor(635.6022, shape=(), dtype=float32)
# 1872 tf.Tensor(635.6828, shape=(), dtype=float32)
# 1873 tf.Tensor(636.15564, shape=(), dtype=float32)
# 1874 tf.Tensor(636.66266, shape=(), dtype=float32)
# 1875 tf.Tensor(636.8615, shape=(), dtype=float32)
# 1876 tf.Tensor(637.1967, shape=(), dtype=float32)
# 1877 tf.Tensor(637.294, shape=(), dtype=float32)
# 1878 tf.Tensor(637.5571, shape=(), dtype=float32)
# 1879 tf.Tensor(638.1111, shape=(), dtype=float32)
# 1880 tf.Tensor(638.6828, shape=(), dtype=float32)
# 1881 tf.Tensor(639.43506, shape=(), dtype=float32)
# 1882 tf.Tensor(639.77625, shape=(), dtype=float32)
# 1883 tf.Tensor(639.91437, shape=(), dtype=float32)
# 1884 tf.Tensor(640.3574, shape=(), dtype=float32)
# 1885 tf.Tensor(640.74664, shape=(), dtype=float32)
# 1886 tf.Tensor(641.2747, shape=(), dtype=float32)
# 1887 tf.Tensor(641.7172, shape=(), dtype=float32)
# 1888 tf.Tensor(641.8718, shape=(), dtype=float32)
# 1889 tf.Tensor(642.2779, shape=(), dtype=float32)
# 1890 tf.Tensor(642.92365, shape=(), dtype=float32)
# 1891 tf.Tensor(643.6083, shape=(), dtype=float32)
# 1892 tf.Tensor(644.21655, shape=(), dtype=float32)
# 1893 tf.Tensor(644.74133, shape=(), dtype=float32)
# 1894 tf.Tensor(644.82294, shape=(), dtype=float32)
# 1895 tf.Tensor(645.1334, shape=(), dtype=float32)
# 1896 tf.Tensor(645.3976, shape=(), dtype=float32)
# 1897 tf.Tensor(645.6594, shape=(), dtype=float32)
# 1898 tf.Tensor(645.77844, shape=(), dtype=float32)
# 1899 tf.Tensor(646.011, shape=(), dtype=float32)
# 1900 tf.Tensor(646.5198, shape=(), dtype=float32)
# 1901 tf.Tensor(646.8211, shape=(), dtype=float32)
# 1902 tf.Tensor(646.89136, shape=(), dtype=float32)
# 1903 tf.Tensor(647.22766, shape=(), dtype=float32)
# 1904 tf.Tensor(648.00916, shape=(), dtype=float32)
# 1905 tf.Tensor(648.1458, shape=(), dtype=float32)
# 1906 tf.Tensor(648.6449, shape=(), dtype=float32)
# 1907 tf.Tensor(649.08887, shape=(), dtype=float32)
# 1908 tf.Tensor(649.2672, shape=(), dtype=float32)
# 1909 tf.Tensor(649.48816, shape=(), dtype=float32)
# 1910 tf.Tensor(649.7844, shape=(), dtype=float32)
# 1911 tf.Tensor(649.9372, shape=(), dtype=float32)
# 1912 tf.Tensor(650.23236, shape=(), dtype=float32)
# 1913 tf.Tensor(650.4807, shape=(), dtype=float32)
# 1914 tf.Tensor(651.0714, shape=(), dtype=float32)
# 1915 tf.Tensor(651.7257, shape=(), dtype=float32)
# 1916 tf.Tensor(651.8577, shape=(), dtype=float32)
# 1917 tf.Tensor(651.8772, shape=(), dtype=float32)
# 1918 tf.Tensor(652.2007, shape=(), dtype=float32)
# 1919 tf.Tensor(652.2007, shape=(), dtype=float32)
# 1920 tf.Tensor(652.47504, shape=(), dtype=float32)
# 1921 tf.Tensor(652.89484, shape=(), dtype=float32)
# 1922 tf.Tensor(652.9529, shape=(), dtype=float32)
# 1923 tf.Tensor(653.38556, shape=(), dtype=float32)
# 1924 tf.Tensor(653.9912, shape=(), dtype=float32)
# 1925 tf.Tensor(654.39777, shape=(), dtype=float32)
# 1926 tf.Tensor(654.7481, shape=(), dtype=float32)
# 1927 tf.Tensor(655.06323, shape=(), dtype=float32)
# 1928 tf.Tensor(655.44336, shape=(), dtype=float32)
# 1929 tf.Tensor(655.6339, shape=(), dtype=float32)
# 1930 tf.Tensor(655.72644, shape=(), dtype=float32)
# 1931 tf.Tensor(656.42175, shape=(), dtype=float32)
# 1932 tf.Tensor(656.55383, shape=(), dtype=float32)
# 1933 tf.Tensor(656.9928, shape=(), dtype=float32)
# 1934 tf.Tensor(657.24805, shape=(), dtype=float32)
# 1935 tf.Tensor(657.7691, shape=(), dtype=float32)
# 1936 tf.Tensor(657.7695, shape=(), dtype=float32)
# 1937 tf.Tensor(658.0639, shape=(), dtype=float32)
# 1938 tf.Tensor(658.3064, shape=(), dtype=float32)
# 1939 tf.Tensor(658.753, shape=(), dtype=float32)
# 1940 tf.Tensor(659.3634, shape=(), dtype=float32)
# 1941 tf.Tensor(659.9208, shape=(), dtype=float32)
# 1942 tf.Tensor(659.97186, shape=(), dtype=float32)
# 1943 tf.Tensor(659.9946, shape=(), dtype=float32)
# 1944 tf.Tensor(660.5242, shape=(), dtype=float32)
# 1945 tf.Tensor(660.73267, shape=(), dtype=float32)
# 1946 tf.Tensor(660.7366, shape=(), dtype=float32)
# 1947 tf.Tensor(660.78345, shape=(), dtype=float32)
# 1948 tf.Tensor(660.87994, shape=(), dtype=float32)
# 1949 tf.Tensor(661.56964, shape=(), dtype=float32)
# 1950 tf.Tensor(661.7542, shape=(), dtype=float32)
# 1951 tf.Tensor(662.3835, shape=(), dtype=float32)
# 1952 tf.Tensor(663.07855, shape=(), dtype=float32)
# 1953 tf.Tensor(663.1964, shape=(), dtype=float32)
# 1954 tf.Tensor(663.3566, shape=(), dtype=float32)
# 1955 tf.Tensor(663.7029, shape=(), dtype=float32)
# 1956 tf.Tensor(664.22845, shape=(), dtype=float32)
# 1957 tf.Tensor(664.54596, shape=(), dtype=float32)
# 1958 tf.Tensor(664.76227, shape=(), dtype=float32)
# 1959 tf.Tensor(664.9695, shape=(), dtype=float32)
# 1960 tf.Tensor(665.3897, shape=(), dtype=float32)
# 1961 tf.Tensor(665.8226, shape=(), dtype=float32)
# 1962 tf.Tensor(666.32556, shape=(), dtype=float32)
# 1963 tf.Tensor(666.6872, shape=(), dtype=float32)
# 1964 tf.Tensor(666.8739, shape=(), dtype=float32)
# 1965 tf.Tensor(667.26624, shape=(), dtype=float32)
# 1966 tf.Tensor(667.53485, shape=(), dtype=float32)
# 1967 tf.Tensor(668.37494, shape=(), dtype=float32)
# 1968 tf.Tensor(668.7297, shape=(), dtype=float32)
# 1969 tf.Tensor(669.3483, shape=(), dtype=float32)
# 1970 tf.Tensor(669.57086, shape=(), dtype=float32)
# 1971 tf.Tensor(669.60333, shape=(), dtype=float32)
# 1972 tf.Tensor(669.69946, shape=(), dtype=float32)
# 1973 tf.Tensor(670.1234, shape=(), dtype=float32)
# 1974 tf.Tensor(670.628, shape=(), dtype=float32)
# 1975 tf.Tensor(671.0686, shape=(), dtype=float32)
# 1976 tf.Tensor(671.1213, shape=(), dtype=float32)
# 1977 tf.Tensor(671.41327, shape=(), dtype=float32)
# 1978 tf.Tensor(672.044, shape=(), dtype=float32)
# 1979 tf.Tensor(672.41895, shape=(), dtype=float32)
# 1980 tf.Tensor(672.7347, shape=(), dtype=float32)
# 1981 tf.Tensor(673.161, shape=(), dtype=float32)
# 1982 tf.Tensor(673.32654, shape=(), dtype=float32)
# 1983 tf.Tensor(673.99194, shape=(), dtype=float32)
# 1984 tf.Tensor(674.179, shape=(), dtype=float32)
# 1985 tf.Tensor(674.62573, shape=(), dtype=float32)
# 1986 tf.Tensor(674.77747, shape=(), dtype=float32)
# 1987 tf.Tensor(674.9514, shape=(), dtype=float32)
# 1988 tf.Tensor(675.48987, shape=(), dtype=float32)
# 1989 tf.Tensor(675.48987, shape=(), dtype=float32)
# *****************************************************************************************************************
# <tf.Tensor: shape=(), dtype=float32, numpy=0.33944213>

# %%
""
